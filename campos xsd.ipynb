# %%
from lxml import etree, objectify

# %%
#import pandas as pd

# %%
file = "XSDs/organismos.xsd"

# %%
file2 = "XSDs/transacciones.xsd"

# %%
file3 = "XSDs/operaciones.xsd"

# %%
file4= "XSDs/destinatarios.xsd"

# %%
file5= "XSDs/contratos.xsd"

# %%
file6 = "XSDs/transacciones_IP.xsd"

# %%
file7 = "XSDs/Modificacion_de_transacciones.xsd"

# %%
chosed_file = file3
print(chosed_file)
# Out:
# XSDs/operaciones.xsd

# %%
f = open(chosed_file, "r")
f
f.close()

# %%
#tree = etree.parse(chosed_file)
#etree.tostring(tree)

# %%
#root = tree.getroot()
#root.tag

# %%
#parser = etree.XMLParser(remove_blank_text=True)

# %%
#root = etree.XML(etree.tostring(tree), parser)

# %%
#print(etree.tostring(root, pretty_print=True))

# %%
## test 2 XSLT

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse(chosed_file)
root = tree.getroot()

# %%
root.tag
# Out:
# '{http://www.w3.org/2001/XMLSchema}schema'

# %%
root.attrib
# Out:
# {}

# %%
for child in root:
    print(child.tag)
    print(child.attrib)
# Out:
# {http://www.w3.org/2001/XMLSchema}element
# {'name': 'operaciones'}
# {http://www.w3.org/2001/XMLSchema}simpleType
# {'name': 'TImporteDecimal'}
# {http://www.w3.org/2001/XMLSchema}simpleType
# {'name': 'TImporteDecimalAmpliado'}

# %%
root[0].attrib
# Out:
# {'name': 'operaciones'}

# %%
for child in root.iter():
    print(child.attrib)
# Out:
# {}
# {'name': 'operaciones'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'operacion'}
# {}
# {}
# {'name': 'cod_poperativo'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_operacion'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '30'}
# {'name': 'cod_subvencionglobal', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'cod_eje'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '6'}
# {'name': 'cat_region'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '2'}
# {'name': 'cod_obj_tematico'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '6'}
# {'name': 'cod_prioridad'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '6'}
# {'name': 'cod_obj_especifico'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '8'}
# {'name': 'cod_organismo'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_actuacion'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '20'}
# {'name': 'nombre'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '255'}
# {'name': 'name'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '255'}
# {'name': 'descripcion'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '70000'}
# {'name': 'operation_summary', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '70000'}
# {'name': 'cod_beneficiario'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'iva_recuperable'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'P'}
# {'value': 'N'}
# {'name': 'costetotal', 'type': 'TImporteDecimal'}
# {}
# {}
# {'name': 'costetotal_subv', 'type': 'TImporteDecimal'}
# {}
# {}
# {'name': 'costepub_subv', 'type': 'TImporteDecimal'}
# {}
# {}
# {'name': 'ayuda_publica_deca', 'type': 'TImporteDecimal'}
# {}
# {}
# {'name': 'utilizacion_ocs', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'cod_base_calculo_1', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '4'}
# {'value': 'BECU'}
# {'value': 'CORE'}
# {'value': 'FIJO'}
# {'value': 'PATA'}
# {'value': 'FI68'}
# {'value': ''}
# {'name': 'cod_base_calculo_2', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '4'}
# {'value': 'BECU'}
# {'value': 'CORE'}
# {'value': 'FIJO'}
# {'value': 'PATA'}
# {'value': 'FI68'}
# {'value': ''}
# {'name': 'cod_base_calculo_3', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '4'}
# {'value': 'BECU'}
# {'value': 'CORE'}
# {'value': 'FIJO'}
# {'value': 'PATA'}
# {'value': 'FI68'}
# {'value': ''}
# {'name': 'cod_base_calculo_4', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '4'}
# {'value': 'BECU'}
# {'value': 'CORE'}
# {'value': 'FIJO'}
# {'value': 'PATA'}
# {'value': 'FI68'}
# {'value': ''}
# {'name': 'finan_costeind', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'calculo_hora', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'cod_manera_tipofijo', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '4'}
# {'value': '681a'}
# {'value': '681b'}
# {'value': '681c'}
# {'value': ''}
# {'name': 'porc_tipofijo', 'minOccurs': '0'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'finan_tipofijo_horizonte2020', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'finan_tipofijo_LIFE', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'autorizado_ocs_ag', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': 'NP'}
# {'value': ''}
# {'name': 'f_autorizado_ocs_ag', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'f_presentacion'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'f_inicio_DECA'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'f_inicio_ejecucion_real', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'f_fin'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'f_real', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'cod_org_deca'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'f_deca'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'fecha_oper_fin_2_14', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'gproyecto'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'cod_gran_proyecto', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '20'}
# {'name': 'texto_gp', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '3500'}
# {'name': 'plan_accion_conjunto'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'regimen_ayudas'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'cod_regimen_ayuda', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '30'}
# {'name': 'referencia_bdns', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '50'}
# {'name': 'proy_cooperacion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'cod_proyecto', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '40'}
# {'name': 'ayuda_estado', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'cod_tipo_ayuda', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '2'}
# {'value': '1'}
# {'value': '2'}
# {'value': '3'}
# {'value': '4'}
# {'value': ''}
# {'name': 'reglamento_minimis', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '5'}
# {'value': 'MINI'}
# {'value': 'MAGR'}
# {'value': 'MEMP'}
# {'value': 'MINI2'}
# {'value': 'MINI3'}
# {'value': ''}
# {'name': 'reglamento_exencion', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '2'}
# {'value': 'A'}
# {'value': 'B'}
# {'value': 'C'}
# {'value': 'D'}
# {'value': ''}
# {'name': 'f_comunicacion_exencion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'notificacion_autorizacion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_notificacion_autorizacion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'f_autorizacion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'publica_privada'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'cod_pubpriv', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'finan_anticipos', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'presya', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'cod_prestamo', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '50'}
# {'name': 'convenio'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'cod_convenio', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '12'}
# {'name': 'cod_iti_1', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'cod_iti_2', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'cod_iti_3', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'cod_obj_estrategia_atlantica', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'instrumento_finan'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'cod_instrumento', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '20'}
# {'name': 'costes_gestion_if', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'poperativos_ayuda', 'minOccurs': '0'}
# {}
# {}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'poperativo_ayuda'}
# {}
# {}
# {'name': 'cod_poperativo_ayuda'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_eje_ayuda'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'fondos_cargo', 'minOccurs': '0'}
# {}
# {}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'fondo_cargo'}
# {}
# {}
# {'name': 'cod_fondo'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'gastos_fuera_zona', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'gastos_fuera_ue', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'normativa_med_amb', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'contratos_publicos'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'genera_ingresos'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'genera_ingresos_netos', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'genera_ingresos_61', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'ogi_metodo', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '2'}
# {'value': '3a'}
# {'value': '3b'}
# {'value': '5'}
# {'value': '6'}
# {'value': '7'}
# {'value': '8'}
# {'value': '99'}
# {'value': ''}
# {'name': 'cod_sector', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '2'}
# {'name': 'porcentaje_615', 'minOccurs': '0'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'ingresos_netos_616', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {'name': 'reembolso_total', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'genera_ingresos_65', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'periodo_ref', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:integer'}
# {'value': '0'}
# {'value': '9999'}
# {'name': 'tasa_descuento', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'costetotal_inv', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {}
# {}
# {'name': 'valor_residual', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {}
# {}
# {'name': 'ingresos_previstos', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {}
# {}
# {'name': 'gastos_func', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {}
# {}
# {'name': 'ingresos_reales', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {}
# {}
# {'name': 'compra_terrenos'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'imp_terrenos', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {'name': 'valor_mercado_suelo', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {'name': 'valor_mercado_edif', 'type': 'TImporteDecimal', 'minOccurs': '0'}
# {'name': 'terrenos_limite_10', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'terrenos_limite_15', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'terrenos_limite_otro', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'terrenos_limite_proposito', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'terrenos_limite_realojo', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'terrenos_limite', 'minOccurs': '0'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'f_sol_compra_terrenos', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'aut_compra_terrenos', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_aut_compra_terrenos', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'contr_especie', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'campos_intervencion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'campo_intervencion'}
# {}
# {}
# {'name': 'cod_campo_intervencion'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'porcentaje'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'tipos_financiacion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'tipo_financiacion'}
# {}
# {}
# {'name': 'cod_tipo_financiacion'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'porcentaje'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'tipos_territorio', 'minOccurs': '0'}
# {}
# {}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'tipo_territorio'}
# {}
# {}
# {'name': 'cod_dimension_terr'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'porcentaje'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'mecanismos_entrega', 'minOccurs': '0'}
# {}
# {}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'mecanismo_entrega'}
# {}
# {}
# {'name': 'cod_mecanismo_entrega'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'porcentaje'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'actividades_economicas', 'minOccurs': '0'}
# {}
# {}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'actividad_economica'}
# {}
# {}
# {'name': 'cod_actividad'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'porcentaje'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'localizaciones_operacion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'localizacion_operacion'}
# {}
# {}
# {'name': 'cod_nut'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'porcentaje'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'contratos', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'contrato'}
# {}
# {}
# {'name': 'cod_contrato'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '30'}
# {'name': 'baremos', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'baremo'}
# {}
# {}
# {'name': 'texto'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '1000'}
# {'name': 'importe', 'type': 'TImporteDecimal'}
# {'name': 'pagos', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'pago'}
# {}
# {}
# {'name': 'texto'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '1000'}
# {'name': 'importe', 'type': 'TImporteDecimal'}
# {'name': 'cod_municipio'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '5'}
# {'name': 'municipios', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'municipio'}
# {}
# {}
# {'name': 'cod_municipio'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '5'}
# {'name': 'cod_postal', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'coordenadas', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'coordenada'}
# {}
# {}
# {'name': 'coord_1'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '50'}
# {'name': 'coord_2'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '50'}
# {'name': 'cod_org_intermedio', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'cod_org_certifica'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_org_aprueba'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_org_verifica'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_org_firma'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_org_conserva_doc'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_org_ayuda', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'doc_benef', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'doc_emplazamiento', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '250'}
# {'name': 'gestion_red_natura', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'operacion_2007', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'cod_operacion_2007', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '50'}
# {'name': 'buena_practica', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'porc_comunicacion'}
# {}
# {'base': 'xs:decimal'}
# {'value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}
# {'name': 'indicadores_resultados', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'indicador_resultado'}
# {}
# {}
# {'name': 'cod_ind_resultado', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'indicadores_productividad', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'indicador_productividad'}
# {}
# {}
# {'name': 'cod_ind_productividad'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'val_2014', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2015', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2016', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2017', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2018', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2019', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2020', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2021', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2022', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'val_2023', 'type': 'TImporteDecimalAmpliado', 'minOccurs': '0'}
# {'name': 'art_53b_ley_21_2013', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'eia_articulo7_21_2013', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'procedimiento_eia', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '1'}
# {'value': 'O'}
# {'value': 'S'}
# {'value': ''}
# {'name': 'dia_favorable', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'coherencia_dia', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_aut_dia', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '10'}
# {'name': 'iia_favorable', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'coherencia_iia', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_aut_iia', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '10'}
# {'name': 'operaciones_pub_dia_iia', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'operacion_pub_dia_iia'}
# {}
# {}
# {'name': 'cod_medio_pub'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '5'}
# {'name': 'f_publicacion'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '10'}
# {'value': '10'}
# {'name': 'texto', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '500'}
# {'name': 'afecta_rn2000', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'relacion_gestion_rn2000', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_proc_amb', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'dia', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_dia', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'f_no_dia', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'aut_amb_int', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_aut_amb_int', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'sospecha_fraude', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_sospecha_fraude', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'fraude_constatado', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'f_fraude_constatado', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'limitada_sobreprogramacion', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'cod_etiqueta', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'COVID'}
# {'value': ''}
# {'name': 'cod_iaf', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'RS'}
# {'value': 'SC'}
# {'value': ''}
# {'name': 'documentos', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'documento'}
# {}
# {}
# {'name': 'nombre_documento'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '200'}
# {'name': 'descripcion'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '500'}
# {'name': 'contenido_documento', 'type': 'xs:base64Binary'}
# {}
# {}
# {'name': 'TImporteDecimal'}
# {}
# {}
# {'base': 'xs:decimal'}
# {'value': '[\\-+]?\\d{0,12}|[\\-+]?\\d{1,12}\\.\\d{1,2}'}
# {'name': 'TImporteDecimalAmpliado'}
# {}
# {}
# {'base': 'xs:decimal'}
# {'value': '[\\-+]?\\d{0,12}|[\\-+]?\\d{1,12}\\.\\d{1,10}'}

# %%
import xmlschema
schema = xmlschema.XMLSchema(chosed_file)
dir(schema)
# Out:
# ['BASE_SCHEMAS',
#  'BUILDERS',
#  'BUILDERS_MAP',
#  'XSD_VERSION',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_get_xpath_namespaces',
#  '_global_views',
#  '_import_namespace',
#  '_locations',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_root_elements',
#  '_validate_references',
#  '_xpath_lock',
#  '_xpath_parse',
#  '_xpath_parser',
#  'all_errors',
#  'allow',
#  'attrib',
#  'attribute_form_default',
#  'attribute_groups',
#  'attributes',
#  'base_url',
#  'block_default',
#  'build',
#  'built',
#  'builtin_types',
#  'check_schema',
#  'check_validator',
#  'clear',
#  'complex_types',
#  'converter',
#  'copy',
#  'count',
#  'create_any_attribute_group',
#  'create_any_content_group',
#  'create_any_type',
#  'create_bindings',
#  'create_element',
#  'create_empty_attribute_group',
#  'create_empty_content_group',
#  'create_meta_schema',
#  'decode',
#  'default_attributes',
#  'default_namespace',
#  'default_open_content',
#  'defuse',
#  'elem',
#  'element_form_default',
#  'elements',
#  'encode',
#  'errors',
#  'export',
#  'fallback_locations',
#  'final_default',
#  'find',
#  'findall',
#  'get',
#  'get_converter',
#  'get_element',
#  'get_locations',
#  'get_schema',
#  'get_text',
#  'groups',
#  'id',
#  'identities',
#  'import_schema',
#  'imports',
#  'include_schema',
#  'includes',
#  'index',
#  'is_valid',
#  'iter',
#  'iter_components',
#  'iter_decode',
#  'iter_encode',
#  'iter_errors',
#  'iter_globals',
#  'iterchildren',
#  'iterfind',
#  'locations',
#  'maps',
#  'meta_schema',
#  'name',
#  'namespaces',
#  'no_namespace_schema_location',
#  'notations',
#  'override',
#  'parse_error',
#  'raw_decoder',
#  'redefine',
#  'resolve_qname',
#  'root',
#  'root_elements',
#  'schema_location',
#  'simple_types',
#  'source',
#  'substitution_groups',
#  'tag',
#  'tail',
#  'target_namespace',
#  'target_prefix',
#  'text',
#  'timeout',
#  'to_dict',
#  'to_etree',
#  'to_objects',
#  'types',
#  'url',
#  'use_meta',
#  'validate',
#  'validation',
#  'validation_attempted',
#  'validation_error',
#  'validity',
#  'version',
#  'version_check',
#  'warnings',
#  'xpath_default_namespace',
#  'xpath_proxy',
#  'xpath_tokens',
#  'xsd_version']

# %%
schema.types
# Out:
# NamespaceView({'TImporteDecimal': XsdAtomicRestriction(name='TImporteDecimal'), 'TImporteDecimalAmpliado': XsdAtomicRestriction(name='TImporteDecimalAmpliado')})

# %%
for xsd_component in schema.iter():
    print(type(xsd_component))
    print(dir(xsd_component))
    #print(xsd_component.get_type())
    print("-----")
# Out:
# <class 'xmlschema.validators.schema.XMLSchema10'>
# ['BASE_SCHEMAS', 'BUILDERS', 'BUILDERS_MAP', 'XSD_VERSION', '__abstractmethods__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_get_xpath_namespaces', '_global_views', '_import_namespace', '_locations', '_parse_imports', '_parse_inclusions', '_parse_xpath_default_namespace', '_root_elements', '_validate_references', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'all_errors', 'allow', 'attrib', 'attribute_form_default', 'attribute_groups', 'attributes', 'base_url', 'block_default', 'build', 'built', 'builtin_types', 'check_schema', 'check_validator', 'clear', 'complex_types', 'converter', 'copy', 'count', 'create_any_attribute_group', 'create_any_content_group', 'create_any_type', 'create_bindings', 'create_element', 'create_empty_attribute_group', 'create_empty_content_group', 'create_meta_schema', 'decode', 'default_attributes', 'default_namespace', 'default_open_content', 'defuse', 'elem', 'element_form_default', 'elements', 'encode', 'errors', 'export', 'fallback_locations', 'final_default', 'find', 'findall', 'get', 'get_converter', 'get_element', 'get_locations', 'get_schema', 'get_text', 'groups', 'id', 'identities', 'import_schema', 'imports', 'include_schema', 'includes', 'index', 'is_valid', 'iter', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_globals', 'iterchildren', 'iterfind', 'locations', 'maps', 'meta_schema', 'name', 'namespaces', 'no_namespace_schema_location', 'notations', 'override', 'parse_error', 'raw_decoder', 'redefine', 'resolve_qname', 'root', 'root_elements', 'schema_location', 'simple_types', 'source', 'substitution_groups', 'tag', 'tail', 'target_namespace', 'target_prefix', 'text', 'timeout', 'to_dict', 'to_etree', 'to_objects', 'types', 'url', 'use_meta', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'version', 'version_check', 'warnings', 'xpath_default_namespace', 'xpath_proxy', 'xpath_tokens', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ...
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----

# %%
#dir(xsd_component)
method_list = [func for func in dir(schema) if callable(getattr(schema, func)) and not func.startswith("__")]

# %%
method_list
# Out:
# ['_get_xpath_namespaces',
#  '_import_namespace',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_validate_references',
#  '_xpath_parse',
#  'build',
#  'builtin_types',
#  'check_schema',
#  'check_validator',
#  'clear',
#  'converter',
#  'copy',
#  'count',
#  'create_any_attribute_group',
#  'create_any_content_group',
#  'create_any_type',
#  'create_bindings',
#  'create_element',
#  'create_empty_attribute_group',
#  'create_empty_content_group',
#  'create_meta_schema',
#  'decode',
#  'encode',
#  'export',
#  'find',
#  'findall',
#  'get',
#  'get_converter',
#  'get_element',
#  'get_locations',
#  'get_schema',
#  'get_text',
#  'import_schema',
#  'include_schema',
#  'index',
#  'is_valid',
#  'iter',
#  'iter_components',
#  'iter_decode',
#  'iter_encode',
#  'iter_errors',
#  'iter_globals',
#  'iterchildren',
#  'iterfind',
#  'parse_error',
#  'raw_decoder',
#  'resolve_qname',
#  'to_dict',
#  'to_etree',
#  'to_objects',
#  'validate',
#  'validation_error',
#  'version_check']

# %%
for item in schema.iter_components():
    print(dir(item))
    break
# Out:
# ['BASE_SCHEMAS', 'BUILDERS', 'BUILDERS_MAP', 'XSD_VERSION', '__abstractmethods__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_get_xpath_namespaces', '_global_views', '_import_namespace', '_locations', '_parse_imports', '_parse_inclusions', '_parse_xpath_default_namespace', '_root_elements', '_validate_references', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'all_errors', 'allow', 'attrib', 'attribute_form_default', 'attribute_groups', 'attributes', 'base_url', 'block_default', 'build', 'built', 'builtin_types', 'check_schema', 'check_validator', 'clear', 'complex_types', 'converter', 'copy', 'count', 'create_any_attribute_group', 'create_any_content_group', 'create_any_type', 'create_bindings', 'create_element', 'create_empty_attribute_group', 'create_empty_content_group', 'create_meta_schema', 'decode', 'default_attributes', 'default_namespace', 'default_open_content', 'defuse', 'elem', 'element_form_default', 'elements', 'encode', 'errors', 'export', 'fallback_locations', 'final_default', 'find', 'findall', 'get', 'get_converter', 'get_element', 'get_locations', 'get_schema', 'get_text', 'groups', 'id', 'identities', 'import_schema', 'imports', 'include_schema', 'includes', 'index', 'is_valid', 'iter', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_globals', 'iterchildren', 'iterfind', 'locations', 'maps', 'meta_schema', 'name', 'namespaces', 'no_namespace_schema_location', 'notations', 'override', 'parse_error', 'raw_decoder', 'redefine', 'resolve_qname', 'root', 'root_elements', 'schema_location', 'simple_types', 'source', 'substitution_groups', 'tag', 'tail', 'target_namespace', 'target_prefix', 'text', 'timeout', 'to_dict', 'to_etree', 'to_objects', 'types', 'url', 'use_meta', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'version', 'version_check', 'warnings', 'xpath_default_namespace', 'xpath_proxy', 'xpath_tokens', 'xsd_version']

# %%
for item in schema.iter():
    print(item)
    print(list(item.iter()))
    try:
        print(item.get_text())
    except:
        pass
    print("----")
# Out:
# XMLSchema10(name='operaciones.xsd', namespace='')
# [XMLSchema10(name='operaciones.xsd', namespace=''), XsdElement(name='operaciones', occurs=[1, 1]), XsdElement(name='operacion', occurs=[1, 1]), XsdElement(name='cod_poperativo', occurs=[1, 1]), XsdElement(name='cod_operacion', occurs=[1, 1]), XsdElement(name='cod_subvencionglobal', occurs=[0, 1]), XsdElement(name='cod_eje', occurs=[1, 1]), XsdElement(name='cat_region', occurs=[1, 1]), XsdElement(name='cod_obj_tematico', occurs=[1, 1]), XsdElement(name='cod_prioridad', occurs=[1, 1]), XsdElement(name='cod_obj_especifico', occurs=[1, 1]), XsdElement(name='cod_organismo', occurs=[1, 1]), XsdElement(name='cod_actuacion', occurs=[1, 1]), XsdElement(name='nombre', occurs=[1, 1]), XsdElement(name='name', occurs=[1, 1]), XsdElement(name='descripcion', occurs=[1, 1]), XsdElement(name='operation_summary', occurs=[0, 1]), XsdElement(name='cod_beneficiario', occurs=[1, 1]), XsdElement(name='iva_recuperable', occurs=[1, 1]), XsdElement(name='costetotal', occurs=[1, 1]), XsdElement(name='costetotal_subv', occurs=[1, 1]), XsdElement(name='costepub_subv', occurs=[1, 1]), XsdElement(name='ayuda_publica_deca', occurs=[1, 1]), XsdElement(name='utilizacion_ocs', occurs=[0, 1]), XsdElement(name='cod_base_calculo_1', occurs=[0, 1]), XsdElement(name='cod_base_calculo_2', occurs=[0, 1]), XsdElement(name='cod_base_calculo_3', occurs=[0, 1]), XsdElement(name='cod_base_calculo_4', occurs=[0, 1]), XsdElement(name='finan_costeind', occurs=[0, 1]), XsdElement(name='calculo_hora', occurs=[0, 1]), XsdElement(name='cod_manera_tipofijo', occurs=[0, 1]), XsdElement(name='porc_tipofijo', occurs=[0, 1]), XsdElement(name='finan_tipofijo_horizonte2020', occurs=[0, 1]), XsdElement(name='finan_tipofijo_LIFE', occurs=[0, 1]), XsdElement(name='autorizado_ocs_ag', occurs=[0, 1]), XsdElement(name='f_autorizado_ocs_ag', occurs=[0, 1]), XsdElement(name='f_presentacion', occurs=[1, 1]), XsdElement(name='f_inicio_DECA', occurs=[1, 1]), XsdElement(name='f_inicio_ejecucion_real', occurs=[0, 1]), XsdElement(name='f_fin', occurs=[1, 1]), XsdElement(name='f_real', occurs=[0, 1]), XsdElement(name='cod_org_deca', occurs=[1, 1]), XsdElement(name='f_deca', occurs=[1, 1]), XsdElement(name='fecha_oper_fin_2_14', occurs=[0, 1]), XsdElement(name='gproyecto', occurs=[1, 1]), XsdElement(name='cod_gran_proyecto', occurs=[0, 1]), XsdElement(name='texto_gp', occurs=[0, 1]), XsdElement(name='plan_accion_conjunto', occurs=[1, 1]), XsdElement(name='regimen_ayudas', occurs=[1, 1]), XsdElement(name='cod_regimen_ayuda', occurs=[0, 1]), XsdElement(name='referencia_bdns', occurs=[0, 1]), XsdElement(name='proy_cooperacion', occurs=[0, 1]), XsdElement(name='cod_proyecto', occurs=[0, 1]), XsdElement(name='ayuda_estado', occurs=[0, 1]), XsdElement(name='cod_tipo_ayuda', occurs=[0, 1]), XsdElement(name='reglamento_minimis', occurs=[0, 1]), XsdElement(name='reglamento_exencion', occurs=[0, 1]), XsdElement(name='f_comunicacion_exencion', occurs=[0, 1]), XsdElement(name='notificacion_autorizacion', occurs=[0, 1]), XsdElement(name='f_notificacion_autorizacion', occurs=[0, 1]), XsdElement(name='f_autorizacion', occurs=[0, 1]), XsdElement(name='publica_privada', occurs=[1, 1]), XsdElement(name='cod_pubpriv', occurs=[0, 1]), XsdElement(name='finan_anticipos', occurs=[0, 1]), XsdElement(name='presya', occurs=[0, 1]), XsdElement(name='cod_prestamo', occurs=[0, 1]), XsdElement(name='convenio', occurs=[1, 1]), XsdElement(name='cod_convenio', occurs=[0, 1]), XsdElement(name='cod_iti_1', occurs=[0, 1]), XsdElement(name='cod_iti_2', occurs=[0, 1]), XsdElement(name='cod_iti_3', occurs=[0, 1]), XsdElement(name='cod_obj_estrategia_atlantica', occurs=[0, 1]), XsdElement(name='instrumento_finan', occurs=[1, 1]), XsdElement(name='cod_instrumento', occurs=[0, 1]), XsdElement(name='costes_gestion_if', occurs=[0, 1]), XsdElement(name='poperativos_ayuda', occurs=[0, 1]), XsdElement(name='poperativo_ayuda', occurs=[1, 1]), XsdElement(name='cod_poperativo_ayuda', occurs=[1, 1]), XsdElement(name='cod_eje_ayuda', occurs=[1, 1]), Xsd ...
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- edited with XMLSpy v2010 rel. 2 (http://www.altova.com) by IGAE Intervención Gral. de la Admón. Del Estado (IGAE Intervención Gral. de la Admón. Del Estado) -->
# <!--W3C Schema generated by XMLSpy v2010 rel. 2 (http://www.altova.com)-->
# <!-- Fecha última actualización: 20/05/2020 -->
# <!-- Se añade la nueva estructura <presya> -->
# <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
# 	<xs:element name="operaciones">
# 		<xs:complexType>
# 			<xs:sequence maxOccurs="unbounded">
# 				<xs:element name="operacion">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<!-- PROGRAMA OPERATIVO -->
# 							<xs:element name="cod_poperativo">
# 								<xs:annotation>
# 									<xs:documentation>Campo (1) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- CÓDIGO DE LA OPERACIÓN -->
# 							<xs:element name="cod_operacion">
# 								<xs:annotation>
# 									<xs:documentation>Campo (11) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="30"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- SUBVENCIÓN GLOBAL -->
# 							<xs:element name="cod_subvencionglobal" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (3) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- EJE PRIORITARIO -->
# 							<xs:element name="cod_eje">
# 								<xs:annotation>
# 									<xs:documentation>Campo (4) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="6"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- CATEGORÍA DE REGIÓN -->
# 							<xs:element name="cat_region">
# 								<xs:annotation>
# 									<xs:documentation>Campo (5) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="2"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- OBJETIVO TEMÁTICO -->
# 							<xs:element name="cod_obj_tematico">
# 								<xs:annotation>
# 									<xs:documentation>Campo (6) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="6"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- PRIORIDAD DE INVERSIÓN -->
# 							<xs:element name="cod_prioridad">
# 								<xs:annotation>
# 									<xs:documentation>Campo (7) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="6"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- OBJETIVO ESPECÍFICO -->
# 							<xs:element name="cod_obj_especifico">
# 								<xs:annotation>
# 									<xs:documentation>Campo (8) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="8"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ORGANISMO CON SENDA FINANCIERA -->
# 							<xs:element name="cod_organismo">
# 								<xs:annotation>
# 									<xs:documentation>Campo (9) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ACTUACIÓN -->
# 							<xs:element name="cod_actuacion">
# 								<xs:annotation>
# 									<xs:documentation>Campo (10) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="20"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- NOMBRE DE LA OPERACIÓN -->
# 							<xs:element name="nombre">
# 								<xs:annotation>
# 									<xs:documentation>Campo (13) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="255"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- NOMBRE DE LA OPERACIÓN EN INGLÉS -->
# 							<xs:element name="name">
# 								<xs:annotation>
# 									<xs:documentation>Campo (13) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="255"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- BREVE DESCRIPCIÓN DE LA OPERACIÓN -->
# 							<xs:element name="descripcion">
# 								<xs:annotation>
# 									<xs:documentation>Campo Breve descripción de la operación de la pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="70000"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- OPERATION SUMMARY -->
# 							<xs:element name="operation_summary" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo Operation summary de la pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="70000"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- BENEFICIARIO -->
# 							<xs:element name="cod_beneficiario">
# 								<xs:annotation>
# 									<xs:documentation>Campo (14) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- IVA RECUPERABLE -->
# 							<xs:element name="iva_recuperable">
# 								<xs:annotation>
# 									<xs:documentation>Campo (16) en pantalla. Toma los valores S (SI), N (NO) o P (En parte)</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="P"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- COSTE TOTAL -->
# 							<xs:element name="costetotal" type="TImporteDecimal">
# 								<xs:annotation>
# 									<xs:documentation>Campo (17) en pantalla</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 							<!-- COSTE TOTAL SUBVENCIONABLE -->
# 							<xs:element name="costetotal_subv" type="TImporteDecimal">
# 								<xs:annotation>
# 									<xs:documentation>Campo (18) en pantalla</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 							<!-- COSTE PÚBLICO TOTAL SUBVENCIONABLE -->
# 							<xs:element name="costepub_subv" type="TImporteDecimal">
# 								<xs:annotation>
# 									<xs:documentation>Campo (19) en pantalla</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 							<!--AYUDA PÚBLICA DECA-->
# 							<xs:element name="ayuda_publica_deca" type="TImporteDecimal">
# 								<xs:annotation>
# 									<xs:documentation>Campo (21) en pantalla</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 							<!--UTILIZACIÓN OCS-->
# 							<xs:element name="utilizacion_ocs" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (51) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--BASE DE CÁLCULO DE LOS COSTES SUBVENCIONABLES 1-->
# 							<xs:element name="cod_base_calculo_1" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.</xs:documentation>
# 									<xs:documentation>BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)</xs:documentation>
# 									<xs:documentation>CORE: Costes reales (art 67.1.a del RDC)</xs:documentation>
# 									<xs:documentation>FIJO: Financiación a tipo fijo (art 67.1.d del RDC)</xs:documentation>
# 									<xs:documentation>PATA: Pagos a tanto alzado (art. 67.1.c del RDC)</xs:documentation>
# 									<xs:documentation>FI68: Financiación a tipo fijo (art. 68 ter del RDC)</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="4"/>
# 										<xs:enumeration value="BECU"/>
# 										<xs:enumeration value="CORE"/>
# 										<xs:enumeration value="FIJO"/>
# 										<xs:enumeration value="PATA"/>
# 										<xs:enumeration value="FI68"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--BASE DE CÁLCULO DE LOS COSTES SUBVENCIONABLES 2-->
# 							<xs:element name="cod_base_calculo_2" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.</xs:documentation>
# 									<xs:documentation>BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)</xs:documentation>
# 									<xs:documentation>CORE: Costes reales (art 67.1.a del RDC)</xs:documentation>
# 									<xs:documentation>FIJO: Financiación a tipo fijo (art 67.1.d del RDC)</xs:documentation>
# 									<xs:documentation>PATA: Pagos a tanto alzado (art. 67.1.c del RDC)</xs:documentation>
# 									<xs:documentation>FI68: Financiación a tipo fijo (art. 68 ter del RDC)</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="4"/>
# 										<xs:enumeration value="BECU"/>
# 										<xs:enumeration value="CORE"/>
# 										<xs:enumeration value="FIJO"/>
# 										<xs:enumeration value="PATA"/>
# 										<xs:enumeration value="FI68"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--BASE DE CÁLCULO DE LOS COSTES SUBVENCIONABLES 3-->
# 							<xs:element name="cod_base_calculo_3" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.</xs:documentation>
# 									<xs:documentation>BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)</xs:documentation>
# 									<xs:documentation>CORE: Costes reales (art 67.1.a del RDC)</xs:documentation>
# 									<xs:documentation>FIJO: Financiación a tipo fijo (art 67.1.d del RDC)</xs:documentation>
# 									<xs:documentation>PATA: Pagos a tanto alzado (art. 67.1.c del RDC)</xs:documentation>
# 									<xs:documentation>FI68: Financiación a tipo fijo (art. 68 ter del RDC)</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="4"/>
# 										<xs:enumeration value="BECU"/>
# 										<xs:enumeration value="CORE"/>
# 										<xs:enumeration value="FIJO"/>
# 										<xs:enumeration value="PATA"/>
# 										<xs:enumeration value="FI68"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--BASE DE CÁLCULO DE LOS COSTES SUBVENCIONABLES 4-->
# 							<xs:element name="cod_base_calculo_4" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.</xs:documentation>
# 									<xs:documentation>BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)</xs:documentation>
# 									<xs:documentation>CORE: Costes reales (art 67.1.a del RDC)</xs:documentation>
# 									<xs:documentation>FIJO: Financiación a tipo fijo (art 67.1.d del RDC)</xs:documentation>
# 									<xs:documentation>PATA: Pagos a tanto alzado (art. 67.1.c del RDC)</xs:documentation>
# 									<xs:documentation>FI68: Financiación a tipo fijo (art. 68 ter del RDC)</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="4"/>
# 										<xs:enumeration value="BECU"/>
# 										<xs:enumeration value="CORE"/>
# 										<xs:enumeration value="FIJO"/>
# 										<xs:enumeration value="PATA"/>
# 										<xs:enumeration value="FI68"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--¿SE TRATA DE FINANCIACIÓN A TIPO FIJO DE LOS COSTES  DE LA OPERACIÓN?-->
# 							<xs:element name="finan_costeind" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Puede tomar los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--¿SE TRATA DEL CÁLCULO DE LA TARIFA POR HORA PREVISTA EN EL ART. 68.2 DEL RDC?-->
# 							<xs:element name="calculo_hora" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Puede tomar los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--MANERA DE CÁLCULO DE TIPO FIJO DE COSTES INDIRECTOS-->
# 							<xs:element name="cod_manera_tipofijo" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Valores posibles: 681a, 681b, 681c.</xs:documentation>
# 									<xs:documentation>681a: Según art. 68.1.a del RDC</xs:documentation>
# 									<xs:documentation>681b: Según art. 68.1.b del RDC</xs:documentation>
# 									<xs:documentation>681c: Según art. 68.1.c del RDC</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="4"/>
# 										<xs:enumeration value="681a"/>
# 										<xs:enumeration value="681b"/>
# 										<xs:enumeration value="681c"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--PORCENTAJE DE TIPO FIJO-->
# 							<xs:element name="porc_tipofijo" minOccurs="0">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:decimal">
# 										<xs:pattern value="[+]?\d{0,3}|[+]?\d{1,3}\.\d{1,2}"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--APLICA FINANCIACIÓN A TIPO FIJO BASADA EN EL RGTO (UE) Nº1290/2013-->
# 							<xs:element name="finan_tipofijo_horizonte2020" minOccurs="0">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--APLICA FINANCIACIÓN A TIPO FIJO BASADA EN EL RGTO Nº996/2012-->
# 							<xs:element name="finan_tipofijo_LIFE" minOccurs="0">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿AG HA AUTORIZADO EL MÉTODO OCS? -->
# 							<xs:element name="autorizado_ocs_ag" minOccurs="0">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value="NP"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- FECHA DE AUTORIZACIÓN DE LA AG DEL MÉTODO OCS -->
# 							<xs:element name="f_autorizado_ocs_ag" minOccurs="0">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- FECHA DE PRESENTACION DE LA SOLICITUD DE FINANCIACIÓN -->
# 							<xs:element name="f_presentacion">
# 								<xs:annotation>
# 									<xs:documentation>Campo (26) en pantalla. Formato de fecha dd/mm/yyyy</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- FECHA DE INICIO DE LA OPERACIÓN QUE FIGURA EN EL DECA-->
# 							<xs:element name="f_inicio_DECA">
# 								<xs:annotation>
# 									<xs:documentation>Campo (27) en pantalla. Formato de fecha dd/mm/yyyy</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- FECHA DE INICIO DE EJECUCIÓN REAL DE LA OPERACIÓN QUE FIGURA EN EL DECA-->
# 							<xs:element name="f_inicio_ejecucion_real" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (28) en pantalla. Formato de fecha dd/mm/yyyy</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- FECHA DE FINALIZACION DE LA OPERACION QUE FIGURA EN EL DECA-->
# 							<xs:element name="f_fin">
# 								<xs:annotation>
# 									<xs:documentation>Campo (29) en pantalla. Formato de fecha dd/mm/yyyy</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- FECHA REAL DE CONCLUSIÓN DE LA OPERACIÓN-->
# 							<xs:element name="f_real" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (30) en pantalla. Formato de fecha dd/mm/yyyy</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ORGANISMO QUE ENTREGA EL DECA -->
# 							<xs:element name="cod_org_deca">
# 								<xs:annotation>
# 									<xs:documentation>Campo (31) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- FECHA DECA -->
# 							<xs:element name="f_deca">
# 								<xs:annotation>
# 									<xs:documentation>Campo (32) en pantalla. Formato de fecha dd/mm/yyyy</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- Fecha 2.14 “Operación Finalizada” -->
# 							<xs:element name="fecha_oper_fin_2_14" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Fecha 2.14 “Operación Finalizada”</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿GRAN PROYECTO? -->
# 							<xs:element name="gproyecto">
# 								<xs:annotation>
# 									<xs:documentation>Campo (33) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- CÓDIGO DEL GRAN PROYECTO -->
# 							<xs:element name="cod_gran_proyecto" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (34) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="20"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--TEXTO GRAN PROYECTO-->
# 							<xs:element name="texto_gp" minOccurs="0">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="3500"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿PLAN DE ACCIÓN CONJUNTO? -->
# 							<xs:element name="plan_accion_conjunto">
# 								<xs:annotation>
# 									<xs:documentation>Campo (35) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--¿RÉGIMEN DE AYUDA?-->
# 							<xs:element name="regimen_ayudas">
# 								<xs:annotation>
# 									<xs:documentation>Campo (36) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- CÓDIGO DEL RÉGIMEN DE AYUDAS DE ESTADO -->
# 							<xs:element name="cod_regimen_ayuda" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (37) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="30"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- REFERENCIA BDNS -->
# 							<xs:element name="referencia_bdns" minOccurs="0">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="50"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- PROYECTO DE COOPERACIÓN -->
# 							<xs:element name="proy_cooperacion" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (74) en pantalla. Debe rellenarse si hay código de régimen de ayudas y dicho régimen tiene proyectos en cooperación. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- CÓDIGO DE PROYECTO -->
# 							<xs:element name="cod_proyecto" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (75) en pantalla. Código de un proyecto en cooperación.</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="40"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿AYUDA DE ESTADO? -->
# 							<xs:element name="ayuda_estado" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (38) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--CÓDIGO DEL TIPO DE AYUDA-->
# 							<xs:element name="cod_tipo_ayuda" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Si se marca ayuda_estado a SI, hay que rellenar el cod_tipo_ayuda con el valor 1, 2, 3 o 4.</xs:documentation>
# 									<xs:documentation> El valor 1 corresponde a 'Ayudas de Estado incluídas en régimen de Minimis'.</xs:documentation>
# 									<xs:documentation>El valor 2 corresponde a 'Ayudas de Estado sujetas a régimen de exención'.</xs:documentation>
# 									<xs:documentation>El valor 3 corresponde a 'Ayudas de Estado que requieren autorización previa de la Comisión'.</xs:documentation>
# 									<xs:documentation>El valor 4 corresponde a ' Ayudas a org. de investigación (ops. relacionadas con actividad económica o no econ.) '.</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="2"/>
# 										<xs:enumeration value="1"/>
# 										<xs:enumeration value="2"/>
# 										<xs:enumeration value="3"/>
# 										<xs:enumeration value="4"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--REGLAMENTO - CÓDIGO DE RÉGIMEN DE MINIMIS-->
# 							<xs:element name="reglamento_minimis" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 1. Los valores posibles son MINI, MAGR, MEMP.</xs:documentation>
# 									<xs:documentation>MINI: Reglamento (UE) 1407/2013 Ayudas de Mínimis</xs:documentation>
# 									<xs:documentation>MAGR: Reglamento (UE) 1408/2013 Ayudas de Mínimis Sector Agrícola</xs:documentation>
# 									<xs:documentation>MEMP: Reglamento (UE) 360/2012 Ayudas de Mínimis a Empresas que prestan Eervicios de Interés Económico General</xs:documentation>
# 									<xs:documentation>MINI2: Reglamento (CE) 1998/2006 de la Comisión de 15 de diciembre de 2006 relativo a la aplicación de los artículos 87 y 88 del Tratado a las ayudas de minimis</xs:documentation>
# 									<xs:documentation>MINI3 - Reglamento (CE) 1535/2007 de la Comisión de 20 de diciembre de 2007 relativo a la aplicación de los artículos 87 y 88 del Tratado CE a las ayudas de minimis en el sector de la producción de productos agrícolas</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="5"/>
# 										<xs:enumeration value="MINI"/>
# 										<xs:enumeration value="MAGR"/>
# 										<xs:enumeration value="MEMP"/>
# 										<xs:enumeration value="MINI2"/>
# 										<xs:enumeration value="MINI3"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--REGLAMENTO - CÓDIGO DE RÉGIMEN DE EXENCIÓN-->
# 							<xs:element name="reglamento_exencion" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 2. Los valores posibles son A, B, C y D</xs:documentation>
# 									<xs:documentation>A: Reglamento de exención por categorías 651/2014</xs:documentation>
# 									<xs:documentation>B: Reglamento B</xs:documentation>
# 									<xs:documentation>C: Reglamento C</xs:documentation>
# 									<xs:documentation>D: Reglamento de exención 800/2008 de la Comisión</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="2"/>
# 										<xs:enumeration value="A"/>
# 										<xs:enumeration value="B"/>
# 										<xs:enumeration value="C"/>
# 										<xs:enumeration value="D"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--FECHA DE COMUNICACIÓN A LA COMISIÓN EUROPEA-->
# 							<xs:element name="f_comunicacion_exencion" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Solo se rellena si se ha elegido cod_tipo_ayuda 2.</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--¿SE REQUIERE NOTIFICACIÓN DE LA AYUDA DE ESTADO?-->
# 							<xs:element name="notificacion_autorizacion" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--FECHA DE NOTIFICACIÓN A LA COMISIÓN EUROPEA-->
# 							<xs:element name="f_notificacion_autorizacion" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3.</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--FECHA DE AUTORIZACIÓN DE LA COMISIÓN EUROPEA-->
# 							<xs:element name="f_autorizacion" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3.</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ESTRUCTURA DE ASOCIACIÓN PÚBLICA-PRIVADA -->
# 							<xs:element name="publica_privada">
# 								<xs:annotation>
# 									<xs:documentation>Campo (40) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- CÓDIGO DE LA ESTRUCTURA DE ASOCIACIÓN PÚBLICA-PRIVADA -->
# 							<xs:element name="cod_pubpriv" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (41) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿FINANCIANCIÓN ANTICIPOS?-->
# 							<xs:element name="finan_anticipos" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation/>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
#
# 							<xs:element name="presya" minOccurs="0">
# 						<xs:complexType>
# 							<xs:sequence maxOccurs="unbounded">
# 									<!--CODIGO DE PRESTAMO-->
# 							<xs:element name="cod_prestamo" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (99) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="50"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 							<!-- ¿CONVENIO?-->
# 							<xs:element name="convenio">
# 								<xs:annotation>
# 									<xs:documentation>Campo (42) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- CÓDIGO DEL CONVENIO -->
# 							<xs:element name="cod_convenio" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (43) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="12"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ITI 1 -->
# 							<xs:element name="cod_iti_1" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (44) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ITI 2 -->
# 							<xs:element name="cod_iti_2" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (44) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ITI 3 -->
# 							<xs:element name="cod_iti_3" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (44) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- OBJETIVO DE ESTRATEGIA ATLÁNTICA -->
# 							<xs:element name="cod_obj_estrategia_atlantica" minOccurs="0">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿INSTRUMENTO FINANCIERO? -->
# 							<xs:element name="instrumento_finan">
# 								<xs:annotation>
# 									<xs:documentation>Campo (45) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- CÓDIGO INSTRUMENTO FINANCIERO -->
# 							<xs:element name="cod_instrumento" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Se rellena si el campo instrumento_finan se marca a S (SI).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="0"/>
# 										<xs:maxLength value="20"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿OPERACIÓN RELATIVA A COSTES Y TASAS DE GESTIÓN DEL IF? -->
# 							<xs:element name="costes_gestion_if" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (73) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- OTROS PROGRAMAS OPERATIVOS Y EJES EN LOS QUE RECIBE AYUDAS-->
# 							<xs:element name="poperativos_ayuda" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (48) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence maxOccurs="unbounded">
# 										<xs:element name="poperativo_ayuda">
# 											<xs:complexType>
# 												<xs:sequence>
# 													<xs:element name="cod_poperativo_ayuda">
# 														<xs:simpleType>
# 															<xs:restriction base="xs:string">
# 																<xs:minLength value="1"/>
# 																<xs:maxLength value="10"/>
# 															</xs:restriction>
# 														</xs:simpleType>
# 													</xs:element>
# 													<xs:element name="cod_eje_ayuda">
# 														<xs:simpleType>
# 															<xs:restriction base="xs:string">
# 																<xs:minLength value="1"/>
# 																<xs:maxLength value="10"/>
# 															</xs:restriction>
# 														</xs:simpleType>
# 													</xs:element>
# 												</xs:sequence>
# 											</xs:complexType>
# 										</xs:element>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 							<!--FONDOS CON CARGO A LOS CUALES SE FINANCIA LA OPERACIÓN-->
# 							<xs:element name="fondos_cargo" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (49) en pantalla</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence maxOccurs="unbounded">
# 										<xs:element name="fondo_cargo">
# 											<xs:complexType>
# 												<xs:sequence>
# 													<xs:element name="cod_fondo">
# 														<xs:simpleType>
# 															<xs:restriction base="xs:string">
# 																<xs:minLength value="1"/>
# 																<xs:maxLength value="10"/>
# 															</xs:restriction>
# 														</xs:simpleType>
# 													</xs:element>
# 												</xs:sequence>
# 											</xs:complexType>
# 										</xs:element>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 							<!-- GASTOS FUERA DE ZONA -->
# 							<xs:element name="gastos_fuera_zona" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (50) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- GASTOS FUERA DE LA UE -->
# 							<xs:element name="gastos_fuera_ue" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (51) en pantalla. Toma los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- SUJETO A NORMATIVA MEDIOAMBIENTAL -->
# 							<xs:element name="normativa_med_amb" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Toma los valores S (SI) o N (NO). Deprecado cuando entren en vigor los nuevos campos de medioambiente</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿SE UTILIZAN CONTRATATOS PÚBLICOS PARA DESARROLLO DE LA OPERACIÓN? -->
# 							<xs:element name="contratos_publicos">
# 								<xs:annotation>
# 									<xs:documentation>Campo (52) en pantalla. Puede tomar los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿LA OPERACIÓN GENERA INGRESOS?-->
# 							<xs:element name="genera_ingresos">
# 								<xs:annotation>
# 									<xs:documentation>Campo (53) en pantalla.  Puede tomar los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- ¿LA OPERACIÓN GENERA INGRESOS NETOS (DEFINICIÓN ART. 61.1 RDC (53a)? -->
# 							<xs:element name="genera_ingresos_netos" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (53a) en pantalla.  Puede tomar los valores S (SI) o N (NO).</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!--¿GENERA INGRESOS COMO PREVÉ EL ARTÍCULO 61 DEL RDC?-->
# 							<xs:element name="genera_ingresos_61" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Campo (54) en pantalla.</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value="S"/>
# 										<xs:enumeration value="N"/>
# 										<xs:enumeration value=""/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<!-- MÉTODO OGI -->
# 							<xs:element name="ogi_metodo" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>Valores posibles: 3a, 3b, 5, 6, 7, 8, 99</xs:documentation>
# 									<xs:documentation>3a  => Art. 61.3.a Aplicación de un porcentaje de ingresos netos uniforme en el sector o subsector</xs:documentation>
# 									<xs:documentation>3b  => Art. 61.3.b Método de cálculo teniendo en cuenta un periodo de referencia adecuado</xs:documentation>
# 									<xs:documentation>5  => Art. 61.5 Aplicación de una reducción al porcentaje de cofinanciación del Eje prioritario del Programa operativo</xs:documentation>
# 									<xs:documentation>6  => Art. 61.6 Deducción de los ingresos netos generados en los tres años siguientes a la finalización de la operación</xs:documentation>
# 									<xs:documentation>7  => Art. 61.7. Validaciones que provocan la omisión de los apartados anteriores</xs:documentation>
# 									<xs:documentation>8  => Art. 61.8. Validaciones que provocan la omisión de los apartados anteriores</xs:documentation>
# ...
# XsdElement(name='f_sol_compra_terrenos', occurs=[0, 1])
# [XsdElement(name='f_sol_compra_terrenos', occurs=[0, 1])]
# ----
# XsdElement(name='aut_compra_terrenos', occurs=[0, 1])
# [XsdElement(name='aut_compra_terrenos', occurs=[0, 1])]
# ----
# XsdElement(name='f_aut_compra_terrenos', occurs=[0, 1])
# [XsdElement(name='f_aut_compra_terrenos', occurs=[0, 1])]
# ----
# XsdElement(name='contr_especie', occurs=[0, 1])
# [XsdElement(name='contr_especie', occurs=[0, 1])]
# ----
# XsdElement(name='campos_intervencion', occurs=[0, 1])
# [XsdElement(name='campos_intervencion', occurs=[0, 1]), XsdElement(name='campo_intervencion', occurs=[1, 1]), XsdElement(name='cod_campo_intervencion', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='campo_intervencion', occurs=[1, 1])
# [XsdElement(name='campo_intervencion', occurs=[1, 1]), XsdElement(name='cod_campo_intervencion', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='cod_campo_intervencion', occurs=[1, 1])
# [XsdElement(name='cod_campo_intervencion', occurs=[1, 1])]
# ----
# XsdElement(name='porcentaje', occurs=[1, 1])
# [XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='tipos_financiacion', occurs=[0, 1])
# [XsdElement(name='tipos_financiacion', occurs=[0, 1]), XsdElement(name='tipo_financiacion', occurs=[1, 1]), XsdElement(name='cod_tipo_financiacion', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='tipo_financiacion', occurs=[1, 1])
# [XsdElement(name='tipo_financiacion', occurs=[1, 1]), XsdElement(name='cod_tipo_financiacion', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='cod_tipo_financiacion', occurs=[1, 1])
# [XsdElement(name='cod_tipo_financiacion', occurs=[1, 1])]
# ----
# XsdElement(name='porcentaje', occurs=[1, 1])
# [XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='tipos_territorio', occurs=[0, 1])
# [XsdElement(name='tipos_territorio', occurs=[0, 1]), XsdElement(name='tipo_territorio', occurs=[1, 1]), XsdElement(name='cod_dimension_terr', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='tipo_territorio', occurs=[1, 1])
# [XsdElement(name='tipo_territorio', occurs=[1, 1]), XsdElement(name='cod_dimension_terr', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='cod_dimension_terr', occurs=[1, 1])
# [XsdElement(name='cod_dimension_terr', occurs=[1, 1])]
# ----
# XsdElement(name='porcentaje', occurs=[1, 1])
# [XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='mecanismos_entrega', occurs=[0, 1])
# [XsdElement(name='mecanismos_entrega', occurs=[0, 1]), XsdElement(name='mecanismo_entrega', occurs=[1, 1]), XsdElement(name='cod_mecanismo_entrega', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='mecanismo_entrega', occurs=[1, 1])
# [XsdElement(name='mecanismo_entrega', occurs=[1, 1]), XsdElement(name='cod_mecanismo_entrega', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='cod_mecanismo_entrega', occurs=[1, 1])
# [XsdElement(name='cod_mecanismo_entrega', occurs=[1, 1])]
# ----
# XsdElement(name='porcentaje', occurs=[1, 1])
# [XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='actividades_economicas', occurs=[0, 1])
# [XsdElement(name='actividades_economicas', occurs=[0, 1]), XsdElement(name='actividad_economica', occurs=[1, 1]), XsdElement(name='cod_actividad', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='actividad_economica', occurs=[1, 1])
# [XsdElement(name='actividad_economica', occurs=[1, 1]), XsdElement(name='cod_actividad', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='cod_actividad', occurs=[1, 1])
# [XsdElement(name='cod_actividad', occurs=[1, 1])]
# ----
# XsdElement(name='porcentaje', occurs=[1, 1])
# [XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='localizaciones_operacion', occurs=[0, 1])
# [XsdElement(name='localizaciones_operacion', occurs=[0, 1]), XsdElement(name='localizacion_operacion', occurs=[1, 1]), XsdElement(name='cod_nut', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='localizacion_operacion', occurs=[1, 1])
# [XsdElement(name='localizacion_operacion', occurs=[1, 1]), XsdElement(name='cod_nut', occurs=[1, 1]), XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='cod_nut', occurs=[1, 1])
# [XsdElement(name='cod_nut', occurs=[1, 1])]
# ----
# XsdElement(name='porcentaje', occurs=[1, 1])
# [XsdElement(name='porcentaje', occurs=[1, 1])]
# ----
# XsdElement(name='contratos', occurs=[0, 1])
# [XsdElement(name='contratos', occurs=[0, 1]), XsdElement(name='contrato', occurs=[1, 1]), XsdElement(name='cod_contrato', occurs=[1, 1])]
# ----
# XsdElement(name='contrato', occurs=[1, 1])
# [XsdElement(name='contrato', occurs=[1, 1]), XsdElement(name='cod_contrato', occurs=[1, 1])]
# ----
# XsdElement(name='cod_contrato', occurs=[1, 1])
# [XsdElement(name='cod_contrato', occurs=[1, 1])]
# ----
# XsdElement(name='baremos', occurs=[0, 1])
# [XsdElement(name='baremos', occurs=[0, 1]), XsdElement(name='baremo', occurs=[1, 1]), XsdElement(name='texto', occurs=[1, 1]), XsdElement(name='importe', occurs=[1, 1])]
# ----
# XsdElement(name='baremo', occurs=[1, 1])
# [XsdElement(name='baremo', occurs=[1, 1]), XsdElement(name='texto', occurs=[1, 1]), XsdElement(name='importe', occurs=[1, 1])]
# ----
# XsdElement(name='texto', occurs=[1, 1])
# [XsdElement(name='texto', occurs=[1, 1])]
# ----
# XsdElement(name='importe', occurs=[1, 1])
# [XsdElement(name='importe', occurs=[1, 1])]
# ----
# XsdElement(name='pagos', occurs=[0, 1])
# [XsdElement(name='pagos', occurs=[0, 1]), XsdElement(name='pago', occurs=[1, 1]), XsdElement(name='texto', occurs=[1, 1]), XsdElement(name='importe', occurs=[1, 1])]
# ----
# XsdElement(name='pago', occurs=[1, 1])
# [XsdElement(name='pago', occurs=[1, 1]), XsdElement(name='texto', occurs=[1, 1]), XsdElement(name='importe', occurs=[1, 1])]
# ----
# XsdElement(name='texto', occurs=[1, 1])
# [XsdElement(name='texto', occurs=[1, 1])]
# ----
# XsdElement(name='importe', occurs=[1, 1])
# [XsdElement(name='importe', occurs=[1, 1])]
# ----
# XsdElement(name='cod_municipio', occurs=[1, 1])
# [XsdElement(name='cod_municipio', occurs=[1, 1])]
# ----
# XsdElement(name='municipios', occurs=[0, 1])
# [XsdElement(name='municipios', occurs=[0, 1]), XsdElement(name='municipio', occurs=[1, 1]), XsdElement(name='cod_municipio', occurs=[1, 1])]
# ----
# XsdElement(name='municipio', occurs=[1, 1])
# [XsdElement(name='municipio', occurs=[1, 1]), XsdElement(name='cod_municipio', occurs=[1, 1])]
# ----
# XsdElement(name='cod_municipio', occurs=[1, 1])
# [XsdElement(name='cod_municipio', occurs=[1, 1])]
# ----
# XsdElement(name='cod_postal', occurs=[0, 1])
# [XsdElement(name='cod_postal', occurs=[0, 1])]
# ----
# XsdElement(name='coordenadas', occurs=[0, 1])
# [XsdElement(name='coordenadas', occurs=[0, 1]), XsdElement(name='coordenada', occurs=[1, 1]), XsdElement(name='coord_1', occurs=[1, 1]), XsdElement(name='coord_2', occurs=[1, 1])]
# ----
# XsdElement(name='coordenada', occurs=[1, 1])
# [XsdElement(name='coordenada', occurs=[1, 1]), XsdElement(name='coord_1', occurs=[1, 1]), XsdElement(name='coord_2', occurs=[1, 1])]
# ----
# XsdElement(name='coord_1', occurs=[1, 1])
# [XsdElement(name='coord_1', occurs=[1, 1])]
# ----
# XsdElement(name='coord_2', occurs=[1, 1])
# [XsdElement(name='coord_2', occurs=[1, 1])]
# ----
# XsdElement(name='cod_org_intermedio', occurs=[0, 1])
# [XsdElement(name='cod_org_intermedio', occurs=[0, 1])]
# ----
# XsdElement(name='cod_org_certifica', occurs=[1, 1])
# [XsdElement(name='cod_org_certifica', occurs=[1, 1])]
# ----
# XsdElement(name='cod_org_aprueba', occurs=[1, 1])
# [XsdElement(name='cod_org_aprueba', occurs=[1, 1])]
# ----
# XsdElement(name='cod_org_verifica', occurs=[1, 1])
# [XsdElement(name='cod_org_verifica', occurs=[1, 1])]
# ----
# XsdElement(name='cod_org_firma', occurs=[1, 1])
# [XsdElement(name='cod_org_firma', occurs=[1, 1])]
# ----
# XsdElement(name='cod_org_conserva_doc', occurs=[1, 1])
# [XsdElement(name='cod_org_conserva_doc', occurs=[1, 1])]
# ----
# XsdElement(name='cod_org_ayuda', occurs=[0, 1])
# [XsdElement(name='cod_org_ayuda', occurs=[0, 1])]
# ----
# XsdElement(name='doc_benef', occurs=[0, 1])
# [XsdElement(name='doc_benef', occurs=[0, 1])]
# ----
# XsdElement(name='doc_emplazamiento', occurs=[0, 1])
# [XsdElement(name='doc_emplazamiento', occurs=[0, 1])]
# ----
# XsdElement(name='gestion_red_natura', occurs=[0, 1])
# [XsdElement(name='gestion_red_natura', occurs=[0, 1])]
# ----
# XsdElement(name='operacion_2007', occurs=[0, 1])
# [XsdElement(name='operacion_2007', occurs=[0, 1])]
# ----
# XsdElement(name='cod_operacion_2007', occurs=[0, 1])
# [XsdElement(name='cod_operacion_2007', occurs=[0, 1])]
# ----
# XsdElement(name='buena_practica', occurs=[0, 1])
# [XsdElement(name='buena_practica', occurs=[0, 1])]
# ----
# XsdElement(name='porc_comunicacion', occurs=[1, 1])
# [XsdElement(name='porc_comunicacion', occurs=[1, 1])]
# ----
# XsdElement(name='indicadores_resultados', occurs=[0, 1])
# [XsdElement(name='indicadores_resultados', occurs=[0, 1]), XsdElement(name='indicador_resultado', occurs=[1, 1]), XsdElement(name='cod_ind_resultado', occurs=[0, 1])]
# ----
# XsdElement(name='indicador_resultado', occurs=[1, 1])
# [XsdElement(name='indicador_resultado', occurs=[1, 1]), XsdElement(name='cod_ind_resultado', occurs=[0, 1])]
# ----
# XsdElement(name='cod_ind_resultado', occurs=[0, 1])
# [XsdElement(name='cod_ind_resultado', occurs=[0, 1])]
# ----
# XsdElement(name='indicadores_productividad', occurs=[0, 1])
# [XsdElement(name='indicadores_productividad', occurs=[0, 1]), XsdElement(name='indicador_productividad', occurs=[1, 1]), XsdElement(name='cod_ind_productividad', occurs=[1, 1]), XsdElement(name='val_2014', occurs=[0, 1]), XsdElement(name='val_2015', occurs=[0, 1]), XsdElement(name='val_2016', occurs=[0, 1]), XsdElement(name='val_2017', occurs=[0, 1]), XsdElement(name='val_2018', occurs=[0, 1]), XsdElement(name='val_2019', occurs=[0, 1]), XsdElement(name='val_2020', occurs=[0, 1]), XsdElement(name='val_2021', occurs=[0, 1]), XsdElement(name='val_2022', occurs=[0, 1]), XsdElement(name='val_2023', occurs=[0, 1])]
# ----
# XsdElement(name='indicador_productividad', occurs=[1, 1])
# [XsdElement(name='indicador_productividad', occurs=[1, 1]), XsdElement(name='cod_ind_productividad', occurs=[1, 1]), XsdElement(name='val_2014', occurs=[0, 1]), XsdElement(name='val_2015', occurs=[0, 1]), XsdElement(name='val_2016', occurs=[0, 1]), XsdElement(name='val_2017', occurs=[0, 1]), XsdElement(name='val_2018', occurs=[0, 1]), XsdElement(name='val_2019', occurs=[0, 1]), XsdElement(name='val_2020', occurs=[0, 1]), XsdElement(name='val_2021', occurs=[0, 1]), XsdElement(name='val_2022', occurs=[0, 1]), XsdElement(name='val_2023', occurs=[0, 1])]
# ----
# XsdElement(name='cod_ind_productividad', occurs=[1, 1])
# [XsdElement(name='cod_ind_productividad', occurs=[1, 1])]
# ----
# XsdElement(name='val_2014', occurs=[0, 1])
# [XsdElement(name='val_2014', occurs=[0, 1])]
# ----
# XsdElement(name='val_2015', occurs=[0, 1])
# [XsdElement(name='val_2015', occurs=[0, 1])]
# ----
# XsdElement(name='val_2016', occurs=[0, 1])
# [XsdElement(name='val_2016', occurs=[0, 1])]
# ----
# XsdElement(name='val_2017', occurs=[0, 1])
# [XsdElement(name='val_2017', occurs=[0, 1])]
# ----
# XsdElement(name='val_2018', occurs=[0, 1])
# [XsdElement(name='val_2018', occurs=[0, 1])]
# ----
# XsdElement(name='val_2019', occurs=[0, 1])
# [XsdElement(name='val_2019', occurs=[0, 1])]
# ----
# XsdElement(name='val_2020', occurs=[0, 1])
# [XsdElement(name='val_2020', occurs=[0, 1])]
# ----
# XsdElement(name='val_2021', occurs=[0, 1])
# [XsdElement(name='val_2021', occurs=[0, 1])]
# ----
# XsdElement(name='val_2022', occurs=[0, 1])
# [XsdElement(name='val_2022', occurs=[0, 1])]
# ----
# XsdElement(name='val_2023', occurs=[0, 1])
# [XsdElement(name='val_2023', occurs=[0, 1])]
# ----
# XsdElement(name='art_53b_ley_21_2013', occurs=[0, 1])
# [XsdElement(name='art_53b_ley_21_2013', occurs=[0, 1])]
# ----
# XsdElement(name='eia_articulo7_21_2013', occurs=[0, 1])
# [XsdElement(name='eia_articulo7_21_2013', occurs=[0, 1])]
# ----
# XsdElement(name='procedimiento_eia', occurs=[0, 1])
# [XsdElement(name='procedimiento_eia', occurs=[0, 1])]
# ----
# XsdElement(name='dia_favorable', occurs=[0, 1])
# [XsdElement(name='dia_favorable', occurs=[0, 1])]
# ----
# XsdElement(name='coherencia_dia', occurs=[0, 1])
# [XsdElement(name='coherencia_dia', occurs=[0, 1])]
# ----
# XsdElement(name='f_aut_dia', occurs=[0, 1])
# [XsdElement(name='f_aut_dia', occurs=[0, 1])]
# ----
# XsdElement(name='iia_favorable', occurs=[0, 1])
# [XsdElement(name='iia_favorable', occurs=[0, 1])]
# ----
# XsdElement(name='coherencia_iia', occurs=[0, 1])
# [XsdElement(name='coherencia_iia', occurs=[0, 1])]
# ----
# XsdElement(name='f_aut_iia', occurs=[0, 1])
# [XsdElement(name='f_aut_iia', occurs=[0, 1])]
# ----
# XsdElement(name='operaciones_pub_dia_iia', occurs=[0, 1])
# [XsdElement(name='operaciones_pub_dia_iia', occurs=[0, 1]), XsdElement(name='operacion_pub_dia_iia', occurs=[1, 1]), XsdElement(name='cod_medio_pub', occurs=[1, 1]), XsdElement(name='f_publicacion', occurs=[1, 1]), XsdElement(name='texto', occurs=[0, 1])]
# ----
# XsdElement(name='operacion_pub_dia_iia', occurs=[1, 1])
# [XsdElement(name='operacion_pub_dia_iia', occurs=[1, 1]), XsdElement(name='cod_medio_pub', occurs=[1, 1]), XsdElement(name='f_publicacion', occurs=[1, 1]), XsdElement(name='texto', occurs=[0, 1])]
# ----
# XsdElement(name='cod_medio_pub', occurs=[1, 1])
# [XsdElement(name='cod_medio_pub', occurs=[1, 1])]
# ----
# XsdElement(name='f_publicacion', occurs=[1, 1])
# [XsdElement(name='f_publicacion', occurs=[1, 1])]
# ----
# XsdElement(name='texto', occurs=[0, 1])
# [XsdElement(name='texto', occurs=[0, 1])]
# ----
# XsdElement(name='afecta_rn2000', occurs=[0, 1])
# [XsdElement(name='afecta_rn2000', occurs=[0, 1])]
# ----
# XsdElement(name='relacion_gestion_rn2000', occurs=[0, 1])
# [XsdElement(name='relacion_gestion_rn2000', occurs=[0, 1])]
# ----
# XsdElement(name='f_proc_amb', occurs=[0, 1])
# [XsdElement(name='f_proc_amb', occurs=[0, 1])]
# ----
# XsdElement(name='dia', occurs=[0, 1])
# [XsdElement(name='dia', occurs=[0, 1])]
# ----
# XsdElement(name='f_dia', occurs=[0, 1])
# [XsdElement(name='f_dia', occurs=[0, 1])]
# ----
# XsdElement(name='f_no_dia', occurs=[0, 1])
# [XsdElement(name='f_no_dia', occurs=[0, 1])]
# ----
# XsdElement(name='aut_amb_int', occurs=[0, 1])
# [XsdElement(name='aut_amb_int', occurs=[0, 1])]
# ----
# XsdElement(name='f_aut_amb_int', occurs=[0, 1])
# [XsdElement(name='f_aut_amb_int', occurs=[0, 1])]
# ----
# XsdElement(name='sospecha_fraude', occurs=[0, 1])
# [XsdElement(name='sospecha_fraude', occurs=[0, 1])]
# ----
# XsdElement(name='f_sospecha_fraude', occurs=[0, 1])
# [XsdElement(name='f_sospecha_fraude', occurs=[0, 1])]
# ----
# XsdElement(name='fraude_constatado', occurs=[0, 1])
# [XsdElement(name='fraude_constatado', occurs=[0, 1])]
# ----
# XsdElement(name='f_fraude_constatado', occurs=[0, 1])
# [XsdElement(name='f_fraude_constatado', occurs=[0, 1])]
# ----
# XsdElement(name='limitada_sobreprogramacion', occurs=[0, 1])
# [XsdElement(name='limitada_sobreprogramacion', occurs=[0, 1])]
# ----
# XsdElement(name='cod_etiqueta', occurs=[0, 1])
# [XsdElement(name='cod_etiqueta', occurs=[0, 1])]
# ----
# XsdElement(name='cod_iaf', occurs=[0, 1])
# [XsdElement(name='cod_iaf', occurs=[0, 1])]
# ----
# XsdElement(name='documentos', occurs=[0, 1])
# [XsdElement(name='documentos', occurs=[0, 1]), XsdElement(name='documento', occurs=[1, 1]), XsdElement(name='nombre_documento', occurs=[1, 1]), XsdElement(name='descripcion', occurs=[1, 1]), XsdElement(name='contenido_documento', occurs=[1, 1])]
# ----
# XsdElement(name='documento', occurs=[1, 1])
# [XsdElement(name='documento', occurs=[1, 1]), XsdElement(name='nombre_documento', occurs=[1, 1]), XsdElement(name='descripcion', occurs=[1, 1]), XsdElement(name='contenido_documento', occurs=[1, 1])]
# ----
# XsdElement(name='nombre_documento', occurs=[1, 1])
# [XsdElement(name='nombre_documento', occurs=[1, 1])]
# ----
# XsdElement(name='descripcion', occurs=[1, 1])
# [XsdElement(name='descripcion', occurs=[1, 1])]
# ----
# XsdElement(name='contenido_documento', occurs=[1, 1])
# [XsdElement(name='contenido_documento', occurs=[1, 1])]
# ----

# %%
for item in schema.iter():
    try:
        print(item.to_dict)
    #print(list(item.iter()))
    #print(item.get_text())
        print("----")
    except:
        pass
# Out:
# <bound method XMLSchemaBase.decode of XMLSchema10(name='operaciones.xsd', namespace='')>
# ----

# %%
#schema.attributes()

# %%
dir(schema)
# Out:
# ['BASE_SCHEMAS',
#  'BUILDERS',
#  'BUILDERS_MAP',
#  'XSD_VERSION',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_get_xpath_namespaces',
#  '_global_views',
#  '_import_namespace',
#  '_locations',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_root_elements',
#  '_validate_references',
#  '_xpath_lock',
#  '_xpath_parse',
#  '_xpath_parser',
#  'all_errors',
#  'allow',
#  'attrib',
#  'attribute_form_default',
#  'attribute_groups',
#  'attributes',
#  'base_url',
#  'block_default',
#  'build',
#  'built',
#  'builtin_types',
#  'check_schema',
#  'check_validator',
#  'clear',
#  'complex_types',
#  'converter',
#  'copy',
#  'count',
#  'create_any_attribute_group',
#  'create_any_content_group',
#  'create_any_type',
#  'create_bindings',
#  'create_element',
#  'create_empty_attribute_group',
#  'create_empty_content_group',
#  'create_meta_schema',
#  'decode',
#  'default_attributes',
#  'default_namespace',
#  'default_open_content',
#  'defuse',
#  'elem',
#  'element_form_default',
#  'elements',
#  'encode',
#  'errors',
#  'export',
#  'fallback_locations',
#  'final_default',
#  'find',
#  'findall',
#  'get',
#  'get_converter',
#  'get_element',
#  'get_locations',
#  'get_schema',
#  'get_text',
#  'groups',
#  'id',
#  'identities',
#  'import_schema',
#  'imports',
#  'include_schema',
#  'includes',
#  'index',
#  'is_valid',
#  'iter',
#  'iter_components',
#  'iter_decode',
#  'iter_encode',
#  'iter_errors',
#  'iter_globals',
#  'iterchildren',
#  'iterfind',
#  'locations',
#  'maps',
#  'meta_schema',
#  'name',
#  'namespaces',
#  'no_namespace_schema_location',
#  'notations',
#  'override',
#  'parse_error',
#  'raw_decoder',
#  'redefine',
#  'resolve_qname',
#  'root',
#  'root_elements',
#  'schema_location',
#  'simple_types',
#  'source',
#  'substitution_groups',
#  'tag',
#  'tail',
#  'target_namespace',
#  'target_prefix',
#  'text',
#  'timeout',
#  'to_dict',
#  'to_etree',
#  'to_objects',
#  'types',
#  'url',
#  'use_meta',
#  'validate',
#  'validation',
#  'validation_attempted',
#  'validation_error',
#  'validity',
#  'version',
#  'version_check',
#  'warnings',
#  'xpath_default_namespace',
#  'xpath_proxy',
#  'xpath_tokens',
#  'xsd_version']

# %%
schema.create_meta_schema()
# Out:
# MetaXMLSchema10(name='XMLSchema.xsd', namespace='http://www.w3.org/2001/XMLSchema')

# %%
aaa =schema.to_dict(chosed_file)
aaa["xs:element"]
# Out:
# {'@name': 'operaciones',
#  '@abstract': False,
#  '@nillable': False,
#  'xs:complexType': {'@mixed': False,
#   'xs:sequence': {'@maxOccurs': 'unbounded',
#    '@minOccurs': 1,
#    'xs:element': {'@name': 'operacion',
#     '@maxOccurs': 1,
#     '@minOccurs': 1,
#     '@nillable': False,
#     'xs:complexType': {'@mixed': False,
#      'xs:sequence': {'@maxOccurs': 1,
#       '@minOccurs': 1,
#       'xs:element': [{'@name': 'cod_poperativo',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (1) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'cod_operacion',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (11) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 30, '@fixed': False}}}},
#        {'@name': 'cod_subvencionglobal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (3) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'cod_eje',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (4) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 6, '@fixed': False}}}},
#        {'@name': 'cat_region',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (5) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 2, '@fixed': False}}}},
#        {'@name': 'cod_obj_tematico',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (6) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 6, '@fixed': False}}}},
#        {'@name': 'cod_prioridad',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (7) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 6, '@fixed': False}}}},
#        {'@name': 'cod_obj_especifico',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (8) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 8, '@fixed': False}}}},
#        {'@name': 'cod_organismo',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (9) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'cod_actuacion',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (10) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#        {'@name': 'nombre',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (13) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 255, '@fixed': False}}}},
#        {'@name': 'name',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (13) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 255, '@fixed': False}}}},
#        {'@name': 'descripcion',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo Breve descripción de la operación de la pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 70000, '@fixed': False}}}},
#        {'@name': 'operation_summary',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo Operation summary de la pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 70000, '@fixed': False}}}},
#        {'@name': 'cod_beneficiario',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (14) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'iva_recuperable',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (16) en pantalla. Toma los valores S (SI), N (NO) o P (En parte)'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'P'},
#            {'@value': 'N'}]}}},
#        {'@name': 'costetotal',
#         '@type': 'TImporteDecimal',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (17) en pantalla'}]}},
#        {'@name': 'costetotal_subv',
#         '@type': 'TImporteDecimal',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (18) en pantalla'}]}},
#        {'@name': 'costepub_subv',
#         '@type': 'TImporteDecimal',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (19) en pantalla'}]}},
#        {'@name': 'ayuda_publica_deca',
#         '@type': 'TImporteDecimal',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (21) en pantalla'}]}},
#        {'@name': 'utilizacion_ocs',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (51) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_base_calculo_1',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.'},
#           {'$': 'BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)'},
#           {'$': 'CORE: Costes reales (art 67.1.a del RDC)'},
#           {'$': 'FIJO: Financiación a tipo fijo (art 67.1.d del RDC)'},
#           {'$': 'PATA: Pagos a tanto alzado (art. 67.1.c del RDC)'},
#           {'$': 'FI68: Financiación a tipo fijo (art. 68 ter del RDC)'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 4, '@fixed': False},
#           'xs:enumeration': [{'@value': 'BECU'},
#            {'@value': 'CORE'},
#            {'@value': 'FIJO'},
#            {'@value': 'PATA'},
#            {'@value': 'FI68'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_base_calculo_2',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.'},
#           {'$': 'BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)'},
#           {'$': 'CORE: Costes reales (art 67.1.a del RDC)'},
#           {'$': 'FIJO: Financiación a tipo fijo (art 67.1.d del RDC)'},
#           {'$': 'PATA: Pagos a tanto alzado (art. 67.1.c del RDC)'},
#           {'$': 'FI68: Financiación a tipo fijo (art. 68 ter del RDC)'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 4, '@fixed': False},
#           'xs:enumeration': [{'@value': 'BECU'},
#            {'@value': 'CORE'},
#            {'@value': 'FIJO'},
#            {'@value': 'PATA'},
#            {'@value': 'FI68'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_base_calculo_3',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.'},
#           {'$': 'BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)'},
#           {'$': 'CORE: Costes reales (art 67.1.a del RDC)'},
#           {'$': 'FIJO: Financiación a tipo fijo (art 67.1.d del RDC)'},
#           {'$': 'PATA: Pagos a tanto alzado (art. 67.1.c del RDC)'},
#           {'$': 'FI68: Financiación a tipo fijo (art. 68 ter del RDC)'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 4, '@fixed': False},
#           'xs:enumeration': [{'@value': 'BECU'},
#            {'@value': 'CORE'},
#            {'@value': 'FIJO'},
#            {'@value': 'PATA'},
#            {'@value': 'FI68'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_base_calculo_4',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.'},
#           {'$': 'BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)'},
#           {'$': 'CORE: Costes reales (art 67.1.a del RDC)'},
#           {'$': 'FIJO: Financiación a tipo fijo (art 67.1.d del RDC)'},
#           {'$': 'PATA: Pagos a tanto alzado (art. 67.1.c del RDC)'},
#           {'$': 'FI68: Financiación a tipo fijo (art. 68 ter del RDC)'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 4, '@fixed': False},
#           'xs:enumeration': [{'@value': 'BECU'},
#            {'@value': 'CORE'},
#            {'@value': 'FIJO'},
#            {'@value': 'PATA'},
#            {'@value': 'FI68'},
#            {'@value': ''}]}}},
#        {'@name': 'finan_costeind',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Puede tomar los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'calculo_hora',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Puede tomar los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_manera_tipofijo',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Valores posibles: 681a, 681b, 681c.'},
#           {'$': '681a: Según art. 68.1.a del RDC'},
#           {'$': '681b: Según art. 68.1.b del RDC'},
#           {'$': '681c: Según art. 68.1.c del RDC'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 4, '@fixed': False},
#           'xs:enumeration': [{'@value': '681a'},
#            {'@value': '681b'},
#            {'@value': '681c'},
#            {'@value': ''}]}}},
#        {'@name': 'porc_tipofijo',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#           'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}},
#        {'@name': 'finan_tipofijo_horizonte2020',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'finan_tipofijo_LIFE',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'autorizado_ocs_ag',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': 'NP'},
#            {'@value': ''}]}}},
#        {'@name': 'f_autorizado_ocs_ag',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'f_presentacion',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (26) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'f_inicio_DECA',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (27) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'f_inicio_ejecucion_real',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (28) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'f_fin',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (29) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'f_real',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (30) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'cod_org_deca',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (31) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'f_deca',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (32) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'fecha_oper_fin_2_14',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Fecha 2.14 “Operación Finalizada”'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'gproyecto',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (33) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'cod_gran_proyecto',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (34) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#        {'@name': 'texto_gp',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 3500, '@fixed': False}}}},
#        {'@name': 'plan_accion_conjunto',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (35) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'regimen_ayudas',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (36) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'cod_regimen_ayuda',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (37) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 30, '@fixed': False}}}},
#        {'@name': 'referencia_bdns',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 50, '@fixed': False}}}},
#        {'@name': 'proy_cooperacion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (74) en pantalla. Debe rellenarse si hay código de régimen de ayudas y dicho régimen tiene proyectos en cooperación. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_proyecto',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (75) en pantalla. Código de un proyecto en cooperación.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 40, '@fixed': False}}}},
#        {'@name': 'ayuda_estado',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (38) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_tipo_ayuda',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Si se marca ayuda_estado a SI, hay que rellenar el cod_tipo_ayuda con el valor 1, 2, 3 o 4.'},
#           {'$': "El valor 1 corresponde a 'Ayudas de Estado incluídas en régimen de Minimis'."},
#           {'$': "El valor 2 corresponde a 'Ayudas de Estado sujetas a régimen de exención'."},
#           {'$': "El valor 3 corresponde a 'Ayudas de Estado que requieren autorización previa de la Comisión'."},
#           {'$': "El valor 4 corresponde a ' Ayudas a org. de investigación (ops. relacionadas con actividad económica o no econ.) '."}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 2, '@fixed': False},
#           'xs:enumeration': [{'@value': '1'},
#            {'@value': '2'},
#            {'@value': '3'},
#            {'@value': '4'},
#            {'@value': ''}]}}},
#        {'@name': 'reglamento_minimis',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 1. Los valores posibles son MINI, MAGR, MEMP.'},
#           {'$': 'MINI: Reglamento (UE) 1407/2013 Ayudas de Mínimis'},
#           {'$': 'MAGR: Reglamento (UE) 1408/2013 Ayudas de Mínimis Sector Agrícola'},
#           {'$': 'MEMP: Reglamento (UE) 360/2012 Ayudas de Mínimis a Empresas que prestan Eervicios de Interés Económico General'},
#           {'$': 'MINI2: Reglamento (CE) 1998/2006 de la Comisión de 15 de diciembre de 2006 relativo a la aplicación de los artículos 87 y 88 del Tratado a las ayudas de minimis'},
#           {'$': 'MINI3 - Reglamento (CE) 1535/2007 de la Comisión de 20 de diciembre de 2007 relativo a la aplicación de los artículos 87 y 88 del Tratado CE a las ayudas de minimis en el sector de la producción de productos agrícolas'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 5, '@fixed': False},
#           'xs:enumeration': [{'@value': 'MINI'},
#            {'@value': 'MAGR'},
#            {'@value': 'MEMP'},
#            {'@value': 'MINI2'},
#            {'@value': 'MINI3'},
#            {'@value': ''}]}}},
#        {'@name': 'reglamento_exencion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 2. Los valores posibles son A, B, C y D'},
#           {'$': 'A: Reglamento de exención por categorías 651/2014'},
#           {'$': 'B: Reglamento B'},
#           {'$': 'C: Reglamento C'},
#           {'$': 'D: Reglamento de exención 800/2008 de la Comisión'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 2, '@fixed': False},
#           'xs:enumeration': [{'@value': 'A'},
#            {'@value': 'B'},
#            {'@value': 'C'},
#            {'@value': 'D'},
#            {'@value': ''}]}}},
#        {'@name': 'f_comunicacion_exencion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Solo se rellena si se ha elegido cod_tipo_ayuda 2.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'notificacion_autorizacion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_notificacion_autorizacion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'f_autorizacion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'publica_privada',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (40) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'cod_pubpriv',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (41) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'finan_anticipos',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [None]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'presya',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'cod_prestamo',
#            '@minOccurs': 0,
#            '@maxOccurs': 1,
#            '@nillable': False,
#            'xs:annotation': {'xs:documentation': [{'$': 'Campo (99) en pantalla'}]},
#            'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#              'xs:minLength': {'@value': 0, '@fixed': False},
#              'xs:maxLength': {'@value': 50, '@fixed': False}}}}}}},
#        {'@name': 'convenio',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (42) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'cod_convenio',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (43) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 12, '@fixed': False}}}},
#        {'@name': 'cod_iti_1',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (44) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'cod_iti_2',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (44) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'cod_iti_3',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (44) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'cod_obj_estrategia_atlantica',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'instrumento_finan',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (45) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'cod_instrumento',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Se rellena si el campo instrumento_finan se marca a S (SI).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#        {'@name': 'costes_gestion_if',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (73) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'poperativos_ayuda',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (48) en pantalla'}]},
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'poperativo_ayuda',
#            '@maxOccurs': 1,
#            '@minOccurs': 1,
#            '@nillable': False,
#            'xs:complexType': {'@mixed': False,
#             'xs:sequence': {'@maxOccurs': 1,
#              '@minOccurs': 1,
#              'xs:element': [{'@name': 'cod_poperativo_ayuda',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 1, '@fixed': False},
#                  'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#               {'@name': 'cod_eje_ayuda',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 1, '@fixed': False},
#                  'xs:maxLength': {'@value': 10, '@fixed': False}}}}]}}}}}},
#        {'@name': 'fondos_cargo',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (49) en pantalla'}]},
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'fondo_cargo',
#            '@maxOccurs': 1,
#            '@minOccurs': 1,
#            '@nillable': False,
#            'xs:complexType': {'@mixed': False,
#             'xs:sequence': {'@maxOccurs': 1,
#              '@minOccurs': 1,
#              'xs:element': {'@name': 'cod_fondo',
#               '@maxOccurs': 1,
#               '@minOccurs': 1,
#               '@nillable': False,
#               'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                 'xs:minLength': {'@value': 1, '@fixed': False},
#                 'xs:maxLength': {'@value': 10, '@fixed': False}}}}}}}}}},
#        {'@name': 'gastos_fuera_zona',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (50) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'gastos_fuera_ue',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (51) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'normativa_med_amb',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO). Deprecado cuando entren en vigor los nuevos campos de medioambiente'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'contratos_publicos',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Puede tomar los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'genera_ingresos',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (53) en pantalla.  Puede tomar los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'genera_ingresos_netos',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (53a) en pantalla.  Puede tomar los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'genera_ingresos_61',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (54) en pantalla.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'ogi_metodo',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Valores posibles: 3a, 3b, 5, 6, 7, 8, 99'},
#           {'$': '3a  => Art. 61.3.a Aplicación de un porcentaje de ingresos netos uniforme en el sector o subsector'},
#           {'$': '3b  => Art. 61.3.b Método de cálculo teniendo en cuenta un periodo de referencia adecuado'},
#           {'$': '5  => Art. 61.5 Aplicación de una reducción al porcentaje de cofinanciación del Eje prioritario del Programa operativo'},
#           {'$': '6  => Art. 61.6 Deducción de los ingresos netos generados en los tres años siguientes a la finalización de la operación'},
#           {'$': '7  => Art. 61.7. Validaciones que provocan la omisión de los apartados anteriores'},
#           {'$': '8  => Art. 61.8. Validaciones que provocan la omisión de los apartados anteriores'},
#           {'$': '99  => Incluye Art. 61.7 y Art. 61.8 (se cumplen condiciones de ambos artículos)'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 2, '@fixed': False},
#           'xs:enumeration': [{'@value': '3a'},
#            {'@value': '3b'},
#            {'@value': '5'},
#            {'@value': '6'},
#            {'@value': '7'},
#            {'@value': '8'},
#            {'@value': '99'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_sector',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 2, '@fixed': False}}}},
#        {'@name': 'porcentaje_615',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#           'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}},
#        {'@name': 'ingresos_netos_616',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False},
#        {'@name': 'reembolso_total',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'genera_ingresos_65',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (55) en pantalla.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'periodo_ref',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (51) en pantalla de Ingresos.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:integer',
#           'xs:minInclusive': {'@value': '0', '@fixed': False},
#           'xs:maxInclusive': {'@value': '9999', '@fixed': False}}}},
#        {'@name': 'tasa_descuento',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla de Ingresos.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#           'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}},
#        {'@name': 'costetotal_inv',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (53) en pantalla de Ingresos.'}]}},
#        {'@name': 'valor_residual',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (54) en pantalla de Ingresos.'}]}},
#        {'@name': 'ingresos_previstos',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (55) en pantalla de Ingresos.'}]}},
#        {'@name': 'gastos_func',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (56) en pantalla de Ingresos.'}]}},
#        {'@name': 'ingresos_reales',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (58) en pantalla de Ingresos.'}]}},
#        {'@name': 'compra_terrenos',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (56) en pantalla. Puede tomar los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#        {'@name': 'imp_terrenos',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False},
#        {'@name': 'valor_mercado_suelo',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False},
#        {'@name': 'valor_mercado_edif',
#         '@type': 'TImporteDecimal',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False},
#        {'@name': 'terrenos_limite_10',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'terrenos_limite_15',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'terrenos_limite_otro',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'terrenos_limite_proposito',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'terrenos_limite_realojo',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'terrenos_limite',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#           'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}},
#        {'@name': 'f_sol_compra_terrenos',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'aut_compra_terrenos',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_aut_compra_terrenos',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'contr_especie',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (57) en pantalla.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'campos_intervencion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (61) en pantalla'}]},
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'campo_intervencion',
#            '@maxOccurs': 1,
#            '@minOccurs': 1,
#            '@nillable': False,
#            'xs:complexType': {'@mixed': False,
#             'xs:sequence': {'@maxOccurs': 1,
#              '@minOccurs': 1,
#              'xs:element': [{'@name': 'cod_campo_intervencion',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 1, '@fixed': False},
#                  'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#               {'@name': 'porcentaje',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#                  'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}}]}}}}}},
#        {'@name': 'tipos_financiacion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (62) en pantalla'}]},
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'tipo_financiacion',
#            '@maxOccurs': 1,
#            '@minOccurs': 1,
#            '@nillable': False,
#            'xs:complexType': {'@mixed': False,
#             'xs:sequence': {'@maxOccurs': 1,
#              '@minOccurs': 1,
#              'xs:element': [{'@name': 'cod_tipo_financiacion',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 1, '@fixed': False},
#                  'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#               {'@name': 'porcentaje',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
# ...
#               '@minOccurs': 0,
#               '@maxOccurs': 1,
#               '@nillable': False,
#               'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                 'xs:minLength': {'@value': 0, '@fixed': False},
#                 'xs:maxLength': {'@value': 10, '@fixed': False}}}}}}}}}},
#        {'@name': 'indicadores_productividad',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'indicador_productividad',
#            '@maxOccurs': 1,
#            '@minOccurs': 1,
#            '@nillable': False,
#            'xs:complexType': {'@mixed': False,
#             'xs:sequence': {'@maxOccurs': 1,
#              '@minOccurs': 1,
#              'xs:element': [{'@name': 'cod_ind_productividad',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 0, '@fixed': False},
#                  'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#               {'@name': 'val_2014',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2015',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2016',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2017',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2018',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2019',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2020',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2021',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2022',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False},
#               {'@name': 'val_2023',
#                '@type': 'TImporteDecimalAmpliado',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False}]}}}}}},
#        {'@name': 'art_53b_ley_21_2013',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'eia_articulo7_21_2013',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'procedimiento_eia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Valores posibles: O, S.'},
#           {'$': 'O: Ordinario'},
#           {'$': 'S: Simplificado'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 1, '@fixed': False},
#           'xs:enumeration': [{'@value': 'O'},
#            {'@value': 'S'},
#            {'@value': ''}]}}},
#        {'@name': 'dia_favorable',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'coherencia_dia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_aut_dia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'iia_favorable',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'coherencia_iia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_aut_iia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'operaciones_pub_dia_iia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'operacion_pub_dia_iia',
#            '@maxOccurs': 1,
#            '@minOccurs': 1,
#            '@nillable': False,
#            'xs:complexType': {'@mixed': False,
#             'xs:sequence': {'@maxOccurs': 1,
#              '@minOccurs': 1,
#              'xs:element': [{'@name': 'cod_medio_pub',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:annotation': {'xs:documentation': [{'$': 'medio'}]},
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 1, '@fixed': False},
#                  'xs:maxLength': {'@value': 5, '@fixed': False}}}},
#               {'@name': 'f_publicacion',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 10, '@fixed': False},
#                  'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#               {'@name': 'texto',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False,
#                'xs:annotation': {'xs:documentation': [{'$': 'descripcion'}]},
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 0, '@fixed': False},
#                  'xs:maxLength': {'@value': 500, '@fixed': False}}}}]}}}}}},
#        {'@name': 'afecta_rn2000',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'relacion_gestion_rn2000',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_proc_amb',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy. Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'dia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO). Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_dia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy. Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'f_no_dia',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy. Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'aut_amb_int',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO). Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_aut_amb_int',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy. Quedará deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'sospecha_fraude',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_sospecha_fraude',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'fraude_constatado',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'f_fraude_constatado',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 0, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'limitada_sobreprogramacion',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (51) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'S'},
#            {'@value': 'N'},
#            {'@value': ''}]}}},
#        {'@name': 'cod_etiqueta',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'COVID'}, {'@value': ''}]}}},
#        {'@name': 'cod_iaf',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': 'RS'},
#            {'@value': 'SC'},
#            {'@value': ''}]}}},
#        {'@name': 'documentos',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'documento',
#            '@maxOccurs': 1,
#            '@minOccurs': 1,
#            '@nillable': False,
#            'xs:complexType': {'@mixed': False,
#             'xs:sequence': {'@maxOccurs': 1,
#              '@minOccurs': 1,
#              'xs:element': [{'@name': 'nombre_documento',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:annotation': {'xs:documentation': [{'$': 'Nombre del documento PDF con extension'}]},
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 1, '@fixed': False},
#                  'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#               {'@name': 'descripcion',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:annotation': {'xs:documentation': [{'$': 'Descripción del documento PDF'}]},
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 1, '@fixed': False},
#                  'xs:maxLength': {'@value': 500, '@fixed': False}}}},
#               {'@name': 'contenido_documento',
#                '@type': 'xs:base64Binary',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:annotation': {'xs:documentation': [{'$': 'Documento PDF codificado como una cadena en Base 64'}]}}]}}}}}}]}}}}}}

# %%
aaa
# Out:
# {'@xmlns:xs': 'http://www.w3.org/2001/XMLSchema',
#  '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#  '@finalDefault': [],
#  '@blockDefault': [],
#  '@attributeFormDefault': 'unqualified',
#  '@elementFormDefault': 'unqualified',
#  'xs:element': {'@name': 'operaciones',
#   '@abstract': False,
#   '@nillable': False,
#   'xs:complexType': {'@mixed': False,
#    'xs:sequence': {'@maxOccurs': 'unbounded',
#     '@minOccurs': 1,
#     'xs:element': {'@name': 'operacion',
#      '@maxOccurs': 1,
#      '@minOccurs': 1,
#      '@nillable': False,
#      'xs:complexType': {'@mixed': False,
#       'xs:sequence': {'@maxOccurs': 1,
#        '@minOccurs': 1,
#        'xs:element': [{'@name': 'cod_poperativo',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (1) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'cod_operacion',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (11) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 30, '@fixed': False}}}},
#         {'@name': 'cod_subvencionglobal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (3) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'cod_eje',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (4) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 6, '@fixed': False}}}},
#         {'@name': 'cat_region',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (5) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 2, '@fixed': False}}}},
#         {'@name': 'cod_obj_tematico',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (6) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 6, '@fixed': False}}}},
#         {'@name': 'cod_prioridad',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (7) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 6, '@fixed': False}}}},
#         {'@name': 'cod_obj_especifico',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (8) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 8, '@fixed': False}}}},
#         {'@name': 'cod_organismo',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (9) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'cod_actuacion',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (10) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#         {'@name': 'nombre',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (13) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 255, '@fixed': False}}}},
#         {'@name': 'name',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (13) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 255, '@fixed': False}}}},
#         {'@name': 'descripcion',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo Breve descripción de la operación de la pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 70000, '@fixed': False}}}},
#         {'@name': 'operation_summary',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo Operation summary de la pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 70000, '@fixed': False}}}},
#         {'@name': 'cod_beneficiario',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (14) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'iva_recuperable',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (16) en pantalla. Toma los valores S (SI), N (NO) o P (En parte)'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'P'},
#             {'@value': 'N'}]}}},
#         {'@name': 'costetotal',
#          '@type': 'TImporteDecimal',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (17) en pantalla'}]}},
#         {'@name': 'costetotal_subv',
#          '@type': 'TImporteDecimal',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (18) en pantalla'}]}},
#         {'@name': 'costepub_subv',
#          '@type': 'TImporteDecimal',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (19) en pantalla'}]}},
#         {'@name': 'ayuda_publica_deca',
#          '@type': 'TImporteDecimal',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (21) en pantalla'}]}},
#         {'@name': 'utilizacion_ocs',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (51) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_base_calculo_1',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.'},
#            {'$': 'BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)'},
#            {'$': 'CORE: Costes reales (art 67.1.a del RDC)'},
#            {'$': 'FIJO: Financiación a tipo fijo (art 67.1.d del RDC)'},
#            {'$': 'PATA: Pagos a tanto alzado (art. 67.1.c del RDC)'},
#            {'$': 'FI68: Financiación a tipo fijo (art. 68 ter del RDC)'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 4, '@fixed': False},
#            'xs:enumeration': [{'@value': 'BECU'},
#             {'@value': 'CORE'},
#             {'@value': 'FIJO'},
#             {'@value': 'PATA'},
#             {'@value': 'FI68'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_base_calculo_2',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.'},
#            {'$': 'BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)'},
#            {'$': 'CORE: Costes reales (art 67.1.a del RDC)'},
#            {'$': 'FIJO: Financiación a tipo fijo (art 67.1.d del RDC)'},
#            {'$': 'PATA: Pagos a tanto alzado (art. 67.1.c del RDC)'},
#            {'$': 'FI68: Financiación a tipo fijo (art. 68 ter del RDC)'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 4, '@fixed': False},
#            'xs:enumeration': [{'@value': 'BECU'},
#             {'@value': 'CORE'},
#             {'@value': 'FIJO'},
#             {'@value': 'PATA'},
#             {'@value': 'FI68'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_base_calculo_3',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.'},
#            {'$': 'BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)'},
#            {'$': 'CORE: Costes reales (art 67.1.a del RDC)'},
#            {'$': 'FIJO: Financiación a tipo fijo (art 67.1.d del RDC)'},
#            {'$': 'PATA: Pagos a tanto alzado (art. 67.1.c del RDC)'},
#            {'$': 'FI68: Financiación a tipo fijo (art. 68 ter del RDC)'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 4, '@fixed': False},
#            'xs:enumeration': [{'@value': 'BECU'},
#             {'@value': 'CORE'},
#             {'@value': 'FIJO'},
#             {'@value': 'PATA'},
#             {'@value': 'FI68'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_base_calculo_4',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Valores posibles: BECU, CORE, FIJO, PATA.'},
#            {'$': 'BECU: Baremos estándar de costes unitarios (art 67.1.b del RDC)'},
#            {'$': 'CORE: Costes reales (art 67.1.a del RDC)'},
#            {'$': 'FIJO: Financiación a tipo fijo (art 67.1.d del RDC)'},
#            {'$': 'PATA: Pagos a tanto alzado (art. 67.1.c del RDC)'},
#            {'$': 'FI68: Financiación a tipo fijo (art. 68 ter del RDC)'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 4, '@fixed': False},
#            'xs:enumeration': [{'@value': 'BECU'},
#             {'@value': 'CORE'},
#             {'@value': 'FIJO'},
#             {'@value': 'PATA'},
#             {'@value': 'FI68'},
#             {'@value': ''}]}}},
#         {'@name': 'finan_costeind',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Puede tomar los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'calculo_hora',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Puede tomar los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_manera_tipofijo',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Valores posibles: 681a, 681b, 681c.'},
#            {'$': '681a: Según art. 68.1.a del RDC'},
#            {'$': '681b: Según art. 68.1.b del RDC'},
#            {'$': '681c: Según art. 68.1.c del RDC'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 4, '@fixed': False},
#            'xs:enumeration': [{'@value': '681a'},
#             {'@value': '681b'},
#             {'@value': '681c'},
#             {'@value': ''}]}}},
#         {'@name': 'porc_tipofijo',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#            'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}},
#         {'@name': 'finan_tipofijo_horizonte2020',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'finan_tipofijo_LIFE',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'autorizado_ocs_ag',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': 'NP'},
#             {'@value': ''}]}}},
#         {'@name': 'f_autorizado_ocs_ag',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'f_presentacion',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (26) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'f_inicio_DECA',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (27) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'f_inicio_ejecucion_real',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (28) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'f_fin',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (29) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'f_real',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (30) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'cod_org_deca',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (31) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'f_deca',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (32) en pantalla. Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'fecha_oper_fin_2_14',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Fecha 2.14 “Operación Finalizada”'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'gproyecto',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (33) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'cod_gran_proyecto',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (34) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#         {'@name': 'texto_gp',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 3500, '@fixed': False}}}},
#         {'@name': 'plan_accion_conjunto',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (35) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'regimen_ayudas',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (36) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'cod_regimen_ayuda',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (37) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 30, '@fixed': False}}}},
#         {'@name': 'referencia_bdns',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 50, '@fixed': False}}}},
#         {'@name': 'proy_cooperacion',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (74) en pantalla. Debe rellenarse si hay código de régimen de ayudas y dicho régimen tiene proyectos en cooperación. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_proyecto',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (75) en pantalla. Código de un proyecto en cooperación.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 40, '@fixed': False}}}},
#         {'@name': 'ayuda_estado',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (38) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_tipo_ayuda',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Si se marca ayuda_estado a SI, hay que rellenar el cod_tipo_ayuda con el valor 1, 2, 3 o 4.'},
#            {'$': "El valor 1 corresponde a 'Ayudas de Estado incluídas en régimen de Minimis'."},
#            {'$': "El valor 2 corresponde a 'Ayudas de Estado sujetas a régimen de exención'."},
#            {'$': "El valor 3 corresponde a 'Ayudas de Estado que requieren autorización previa de la Comisión'."},
#            {'$': "El valor 4 corresponde a ' Ayudas a org. de investigación (ops. relacionadas con actividad económica o no econ.) '."}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 2, '@fixed': False},
#            'xs:enumeration': [{'@value': '1'},
#             {'@value': '2'},
#             {'@value': '3'},
#             {'@value': '4'},
#             {'@value': ''}]}}},
#         {'@name': 'reglamento_minimis',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 1. Los valores posibles son MINI, MAGR, MEMP.'},
#            {'$': 'MINI: Reglamento (UE) 1407/2013 Ayudas de Mínimis'},
#            {'$': 'MAGR: Reglamento (UE) 1408/2013 Ayudas de Mínimis Sector Agrícola'},
#            {'$': 'MEMP: Reglamento (UE) 360/2012 Ayudas de Mínimis a Empresas que prestan Eervicios de Interés Económico General'},
#            {'$': 'MINI2: Reglamento (CE) 1998/2006 de la Comisión de 15 de diciembre de 2006 relativo a la aplicación de los artículos 87 y 88 del Tratado a las ayudas de minimis'},
#            {'$': 'MINI3 - Reglamento (CE) 1535/2007 de la Comisión de 20 de diciembre de 2007 relativo a la aplicación de los artículos 87 y 88 del Tratado CE a las ayudas de minimis en el sector de la producción de productos agrícolas'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 5, '@fixed': False},
#            'xs:enumeration': [{'@value': 'MINI'},
#             {'@value': 'MAGR'},
#             {'@value': 'MEMP'},
#             {'@value': 'MINI2'},
#             {'@value': 'MINI3'},
#             {'@value': ''}]}}},
#         {'@name': 'reglamento_exencion',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 2. Los valores posibles son A, B, C y D'},
#            {'$': 'A: Reglamento de exención por categorías 651/2014'},
#            {'$': 'B: Reglamento B'},
#            {'$': 'C: Reglamento C'},
#            {'$': 'D: Reglamento de exención 800/2008 de la Comisión'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 2, '@fixed': False},
#            'xs:enumeration': [{'@value': 'A'},
#             {'@value': 'B'},
#             {'@value': 'C'},
#             {'@value': 'D'},
#             {'@value': ''}]}}},
#         {'@name': 'f_comunicacion_exencion',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Solo se rellena si se ha elegido cod_tipo_ayuda 2.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'notificacion_autorizacion',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_notificacion_autorizacion',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'f_autorizacion',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Se rellena siempre que se haya marcado el campo cod_tipo_ayuda a 3.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'publica_privada',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (40) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'cod_pubpriv',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (41) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'finan_anticipos',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [None]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'presya',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:complexType': {'@mixed': False,
#           'xs:sequence': {'@maxOccurs': 'unbounded',
#            '@minOccurs': 1,
#            'xs:element': {'@name': 'cod_prestamo',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:annotation': {'xs:documentation': [{'$': 'Campo (99) en pantalla'}]},
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 50, '@fixed': False}}}}}}},
#         {'@name': 'convenio',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (42) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'cod_convenio',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (43) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 12, '@fixed': False}}}},
#         {'@name': 'cod_iti_1',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (44) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'cod_iti_2',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (44) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'cod_iti_3',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (44) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'cod_obj_estrategia_atlantica',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'instrumento_finan',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (45) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'cod_instrumento',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Se rellena si el campo instrumento_finan se marca a S (SI).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#         {'@name': 'costes_gestion_if',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (73) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'poperativos_ayuda',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (48) en pantalla'}]},
#          'xs:complexType': {'@mixed': False,
#           'xs:sequence': {'@maxOccurs': 'unbounded',
#            '@minOccurs': 1,
#            'xs:element': {'@name': 'poperativo_ayuda',
#             '@maxOccurs': 1,
#             '@minOccurs': 1,
#             '@nillable': False,
#             'xs:complexType': {'@mixed': False,
#              'xs:sequence': {'@maxOccurs': 1,
#               '@minOccurs': 1,
#               'xs:element': [{'@name': 'cod_poperativo_ayuda',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 1, '@fixed': False},
#                   'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#                {'@name': 'cod_eje_ayuda',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 1, '@fixed': False},
#                   'xs:maxLength': {'@value': 10, '@fixed': False}}}}]}}}}}},
#         {'@name': 'fondos_cargo',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (49) en pantalla'}]},
#          'xs:complexType': {'@mixed': False,
#           'xs:sequence': {'@maxOccurs': 'unbounded',
#            '@minOccurs': 1,
#            'xs:element': {'@name': 'fondo_cargo',
#             '@maxOccurs': 1,
#             '@minOccurs': 1,
#             '@nillable': False,
#             'xs:complexType': {'@mixed': False,
#              'xs:sequence': {'@maxOccurs': 1,
#               '@minOccurs': 1,
#               'xs:element': {'@name': 'cod_fondo',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 1, '@fixed': False},
#                  'xs:maxLength': {'@value': 10, '@fixed': False}}}}}}}}}},
#         {'@name': 'gastos_fuera_zona',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (50) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'gastos_fuera_ue',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (51) en pantalla. Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'normativa_med_amb',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO). Deprecado cuando entren en vigor los nuevos campos de medioambiente'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'contratos_publicos',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla. Puede tomar los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'genera_ingresos',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (53) en pantalla.  Puede tomar los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'genera_ingresos_netos',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (53a) en pantalla.  Puede tomar los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'genera_ingresos_61',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (54) en pantalla.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'ogi_metodo',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Valores posibles: 3a, 3b, 5, 6, 7, 8, 99'},
#            {'$': '3a  => Art. 61.3.a Aplicación de un porcentaje de ingresos netos uniforme en el sector o subsector'},
#            {'$': '3b  => Art. 61.3.b Método de cálculo teniendo en cuenta un periodo de referencia adecuado'},
#            {'$': '5  => Art. 61.5 Aplicación de una reducción al porcentaje de cofinanciación del Eje prioritario del Programa operativo'},
#            {'$': '6  => Art. 61.6 Deducción de los ingresos netos generados en los tres años siguientes a la finalización de la operación'},
#            {'$': '7  => Art. 61.7. Validaciones que provocan la omisión de los apartados anteriores'},
#            {'$': '8  => Art. 61.8. Validaciones que provocan la omisión de los apartados anteriores'},
#            {'$': '99  => Incluye Art. 61.7 y Art. 61.8 (se cumplen condiciones de ambos artículos)'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 2, '@fixed': False},
#            'xs:enumeration': [{'@value': '3a'},
#             {'@value': '3b'},
#             {'@value': '5'},
#             {'@value': '6'},
#             {'@value': '7'},
#             {'@value': '8'},
#             {'@value': '99'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_sector',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 2, '@fixed': False}}}},
#         {'@name': 'porcentaje_615',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#            'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}},
#         {'@name': 'ingresos_netos_616',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False},
#         {'@name': 'reembolso_total',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'genera_ingresos_65',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (55) en pantalla.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'periodo_ref',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (51) en pantalla de Ingresos.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:integer',
#            'xs:minInclusive': {'@value': '0', '@fixed': False},
#            'xs:maxInclusive': {'@value': '9999', '@fixed': False}}}},
#         {'@name': 'tasa_descuento',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (52) en pantalla de Ingresos.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#            'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}},
#         {'@name': 'costetotal_inv',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (53) en pantalla de Ingresos.'}]}},
#         {'@name': 'valor_residual',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (54) en pantalla de Ingresos.'}]}},
#         {'@name': 'ingresos_previstos',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (55) en pantalla de Ingresos.'}]}},
#         {'@name': 'gastos_func',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (56) en pantalla de Ingresos.'}]}},
#         {'@name': 'ingresos_reales',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (58) en pantalla de Ingresos.'}]}},
#         {'@name': 'compra_terrenos',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (56) en pantalla. Puede tomar los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#         {'@name': 'imp_terrenos',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False},
#         {'@name': 'valor_mercado_suelo',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False},
#         {'@name': 'valor_mercado_edif',
#          '@type': 'TImporteDecimal',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False},
#         {'@name': 'terrenos_limite_10',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'terrenos_limite_15',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'terrenos_limite_otro',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'terrenos_limite_proposito',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'terrenos_limite_realojo',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'terrenos_limite',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:decimal',
#            'xs:pattern': {'@value': '[+]?\\d{0,3}|[+]?\\d{1,3}\\.\\d{1,2}'}}}},
#         {'@name': 'f_sol_compra_terrenos',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'aut_compra_terrenos',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_aut_compra_terrenos',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'contr_especie',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (57) en pantalla.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'campos_intervencion',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (61) en pantalla'}]},
#          'xs:complexType': {'@mixed': False,
#           'xs:sequence': {'@maxOccurs': 'unbounded',
#            '@minOccurs': 1,
#            'xs:element': {'@name': 'campo_intervencion',
#             '@maxOccurs': 1,
#             '@minOccurs': 1,
#             '@nillable': False,
#             'xs:complexType': {'@mixed': False,
#              'xs:sequence': {'@maxOccurs': 1,
#               '@minOccurs': 1,
#               'xs:element': [{'@name': 'cod_campo_intervencion',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 1, '@fixed': False},
#                   'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#                {'@name': 'porcentaje',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
# ...
#                   'xs:minLength': {'@value': 0, '@fixed': False},
#                   'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#                {'@name': 'val_2014',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2015',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2016',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2017',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2018',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2019',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2020',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2021',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2022',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False},
#                {'@name': 'val_2023',
#                 '@type': 'TImporteDecimalAmpliado',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False}]}}}}}},
#         {'@name': 'art_53b_ley_21_2013',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'eia_articulo7_21_2013',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'procedimiento_eia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Valores posibles: O, S.'},
#            {'$': 'O: Ordinario'},
#            {'$': 'S: Simplificado'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 1, '@fixed': False},
#            'xs:enumeration': [{'@value': 'O'},
#             {'@value': 'S'},
#             {'@value': ''}]}}},
#         {'@name': 'dia_favorable',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'coherencia_dia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_aut_dia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'iia_favorable',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'coherencia_iia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_aut_iia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'operaciones_pub_dia_iia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:complexType': {'@mixed': False,
#           'xs:sequence': {'@maxOccurs': 'unbounded',
#            '@minOccurs': 1,
#            'xs:element': {'@name': 'operacion_pub_dia_iia',
#             '@maxOccurs': 1,
#             '@minOccurs': 1,
#             '@nillable': False,
#             'xs:complexType': {'@mixed': False,
#              'xs:sequence': {'@maxOccurs': 1,
#               '@minOccurs': 1,
#               'xs:element': [{'@name': 'cod_medio_pub',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:annotation': {'xs:documentation': [{'$': 'medio'}]},
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 1, '@fixed': False},
#                   'xs:maxLength': {'@value': 5, '@fixed': False}}}},
#                {'@name': 'f_publicacion',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 10, '@fixed': False},
#                   'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#                {'@name': 'texto',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False,
#                 'xs:annotation': {'xs:documentation': [{'$': 'descripcion'}]},
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 0, '@fixed': False},
#                   'xs:maxLength': {'@value': 500, '@fixed': False}}}}]}}}}}},
#         {'@name': 'afecta_rn2000',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'relacion_gestion_rn2000',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_proc_amb',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy. Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'dia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO). Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_dia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy. Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'f_no_dia',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy. Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'aut_amb_int',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO). Deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_aut_amb_int',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy. Quedará deprecado cuando entren en vigor los nuevos campos de medioambiente.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'sospecha_fraude',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_sospecha_fraude',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'fraude_constatado',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Toma los valores S (SI) o N (NO).'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'f_fraude_constatado',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Formato de fecha dd/mm/yyyy'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 0, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'limitada_sobreprogramacion',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (51) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'S'},
#             {'@value': 'N'},
#             {'@value': ''}]}}},
#         {'@name': 'cod_etiqueta',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'COVID'}, {'@value': ''}]}}},
#         {'@name': 'cod_iaf',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': 'RS'},
#             {'@value': 'SC'},
#             {'@value': ''}]}}},
#         {'@name': 'documentos',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:complexType': {'@mixed': False,
#           'xs:sequence': {'@maxOccurs': 'unbounded',
#            '@minOccurs': 1,
#            'xs:element': {'@name': 'documento',
#             '@maxOccurs': 1,
#             '@minOccurs': 1,
#             '@nillable': False,
#             'xs:complexType': {'@mixed': False,
#              'xs:sequence': {'@maxOccurs': 1,
#               '@minOccurs': 1,
#               'xs:element': [{'@name': 'nombre_documento',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:annotation': {'xs:documentation': [{'$': 'Nombre del documento PDF con extension'}]},
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 1, '@fixed': False},
#                   'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#                {'@name': 'descripcion',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:annotation': {'xs:documentation': [{'$': 'Descripción del documento PDF'}]},
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 1, '@fixed': False},
#                   'xs:maxLength': {'@value': 500, '@fixed': False}}}},
#                {'@name': 'contenido_documento',
#                 '@type': 'xs:base64Binary',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:annotation': {'xs:documentation': [{'$': 'Documento PDF codificado como una cadena en Base 64'}]}}]}}}}}}]}}}}}},
#  'xs:simpleType': [{'@name': 'TImporteDecimal',
#    'xs:annotation': {'xs:documentation': [{'$': 'Hasta doce posiciones para enteros con dos decimales. El símbolo de separación de decimales es el punto.'}]},
#    'xs:restriction': {'@base': 'xs:decimal',
#     'xs:pattern': {'@value': '[\\-+]?\\d{0,12}|[\\-+]?\\d{1,12}\\.\\d{1,2}'}}},
#   {'@name': 'TImporteDecimalAmpliado',
#    'xs:annotation': {'xs:documentation': [{'$': 'Hasta doce posiciones para enteros con diez decimales. El símbolo de separación de decimales es el punto.'}]},
#    'xs:restriction': {'@base': 'xs:decimal',
#     'xs:pattern': {'@value': '[\\-+]?\\d{0,12}|[\\-+]?\\d{1,12}\\.\\d{1,10}'}}}]}

# %%
for xsd_component in schema.iter():
    print(type(xsd_component))
        
    print("-----")
# Out:
# <class 'xmlschema.validators.schema.XMLSchema10'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----

# %%
for xsd_component in schema.iter():
    if 'XMLSchema10' in str(type(xsd_component))  :
        pass
    else:
        #print(type(xsd_component))
        print(xsd_component.name)# , xsd_component.is_emptiable())
        #print(xsd_component.is_emptiable())
        '''
        print(list(xsd_component.iterchildren()))
        print(len(list(xsd_component.iterchildren())))
        print(xsd_component.parent)
        print(dir(xsd_component))
        #print(xsd_component.get_type)'''
        #print("-----")
# Out:
# operaciones
# operacion
# cod_poperativo
# cod_operacion
# cod_subvencionglobal
# cod_eje
# cat_region
# cod_obj_tematico
# cod_prioridad
# cod_obj_especifico
# cod_organismo
# cod_actuacion
# nombre
# name
# descripcion
# operation_summary
# cod_beneficiario
# iva_recuperable
# costetotal
# costetotal_subv
# costepub_subv
# ayuda_publica_deca
# utilizacion_ocs
# cod_base_calculo_1
# cod_base_calculo_2
# cod_base_calculo_3
# cod_base_calculo_4
# finan_costeind
# calculo_hora
# cod_manera_tipofijo
# porc_tipofijo
# finan_tipofijo_horizonte2020
# finan_tipofijo_LIFE
# autorizado_ocs_ag
# f_autorizado_ocs_ag
# f_presentacion
# f_inicio_DECA
# f_inicio_ejecucion_real
# f_fin
# f_real
# cod_org_deca
# f_deca
# fecha_oper_fin_2_14
# gproyecto
# cod_gran_proyecto
# texto_gp
# plan_accion_conjunto
# regimen_ayudas
# cod_regimen_ayuda
# referencia_bdns
# proy_cooperacion
# cod_proyecto
# ayuda_estado
# cod_tipo_ayuda
# reglamento_minimis
# reglamento_exencion
# f_comunicacion_exencion
# notificacion_autorizacion
# f_notificacion_autorizacion
# f_autorizacion
# publica_privada
# cod_pubpriv
# finan_anticipos
# presya
# cod_prestamo
# convenio
# cod_convenio
# cod_iti_1
# cod_iti_2
# cod_iti_3
# cod_obj_estrategia_atlantica
# instrumento_finan
# cod_instrumento
# costes_gestion_if
# poperativos_ayuda
# poperativo_ayuda
# cod_poperativo_ayuda
# cod_eje_ayuda
# fondos_cargo
# fondo_cargo
# cod_fondo
# gastos_fuera_zona
# gastos_fuera_ue
# normativa_med_amb
# contratos_publicos
# genera_ingresos
# genera_ingresos_netos
# genera_ingresos_61
# ogi_metodo
# cod_sector
# porcentaje_615
# ingresos_netos_616
# reembolso_total
# genera_ingresos_65
# periodo_ref
# tasa_descuento
# costetotal_inv
# valor_residual
# ingresos_previstos
# gastos_func
# ingresos_reales
# compra_terrenos
# imp_terrenos
# valor_mercado_suelo
# valor_mercado_edif
# terrenos_limite_10
# terrenos_limite_15
# terrenos_limite_otro
# terrenos_limite_proposito
# terrenos_limite_realojo
# terrenos_limite
# f_sol_compra_terrenos
# aut_compra_terrenos
# f_aut_compra_terrenos
# contr_especie
# campos_intervencion
# campo_intervencion
# cod_campo_intervencion
# porcentaje
# tipos_financiacion
# tipo_financiacion
# cod_tipo_financiacion
# porcentaje
# tipos_territorio
# tipo_territorio
# cod_dimension_terr
# porcentaje
# mecanismos_entrega
# mecanismo_entrega
# cod_mecanismo_entrega
# porcentaje
# actividades_economicas
# actividad_economica
# cod_actividad
# porcentaje
# localizaciones_operacion
# localizacion_operacion
# cod_nut
# porcentaje
# contratos
# contrato
# cod_contrato
# baremos
# baremo
# texto
# importe
# pagos
# pago
# texto
# importe
# cod_municipio
# municipios
# municipio
# cod_municipio
# cod_postal
# coordenadas
# coordenada
# coord_1
# coord_2
# cod_org_intermedio
# cod_org_certifica
# cod_org_aprueba
# cod_org_verifica
# cod_org_firma
# cod_org_conserva_doc
# cod_org_ayuda
# doc_benef
# doc_emplazamiento
# gestion_red_natura
# operacion_2007
# cod_operacion_2007
# buena_practica
# porc_comunicacion
# indicadores_resultados
# indicador_resultado
# cod_ind_resultado
# indicadores_productividad
# indicador_productividad
# cod_ind_productividad
# val_2014
# val_2015
# val_2016
# val_2017
# val_2018
# val_2019
# val_2020
# val_2021
# val_2022
# val_2023
# art_53b_ley_21_2013
# eia_articulo7_21_2013
# procedimiento_eia
# dia_favorable
# coherencia_dia
# f_aut_dia
# iia_favorable
# coherencia_iia
# f_aut_iia
# operaciones_pub_dia_iia
# operacion_pub_dia_iia
# cod_medio_pub
# f_publicacion
# texto
# afecta_rn2000
# relacion_gestion_rn2000
# f_proc_amb
# dia
# f_dia
# f_no_dia
# aut_amb_int
# f_aut_amb_int
# sospecha_fraude
# f_sospecha_fraude
# fraude_constatado
# f_fraude_constatado
# limitada_sobreprogramacion
# cod_etiqueta
# cod_iaf
# documentos
# documento
# nombre_documento
# descripcion
# contenido_documento

# %%
for xsd_component in schema.iter():
    if "XsdGroup" in str(type(xsd_component)):
        print(dir(xsd_component))
        print(xsd_component.name)
        
        print("-----")
