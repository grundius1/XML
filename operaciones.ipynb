# %%
import csv
import xml.etree.ElementTree as ET

# %%
file = "C:/Users/bllanos/Desktop/project1/prueba1/Operaciones/Masivo Excel1_operaciones_V2 relleno.csv"

print(file)
# Out:
# C:/Users/bllanos/Desktop/project1/prueba1/Operaciones/Masivo Excel1_operaciones_V2 relleno.csv

# %%
with open(file) as f:
    csv_reader = csv.DictReader(f,delimiter=";")
    root = ET.Element("operaciones")
    for row in csv_reader:
        print(row)
        operacion = ET.SubElement(root,"operacion")
        elemento = ET.SubElement(operacion,"cod_poperativo")
        elemento.text = row["cod_poperativo"]
        elemento = ET.SubElement(operacion,"cod_operacion")
        elemento.text = row["cod_operacion"]
        elemento = ET.SubElement(operacion,"cod_subvencionglobal")
        elemento.text = row["cod_subvencionglobal"]
        elemento = ET.SubElement(operacion,"cod_eje")
        elemento.text = row["cod_eje"]
        elemento = ET.SubElement(operacion,"cat_region")
        elemento.text = row["cat_region"]
        elemento = ET.SubElement(operacion,"cod_obj_tematico")
        elemento.text = row["cod_obj_tematico"]
        elemento = ET.SubElement(operacion,"cod_prioridad")
        elemento.text = row["cod_obj_tematico"]
        elemento = ET.SubElement(operacion,"cod_obj_especifico")
        elemento.text = row["cod_obj_tematico"]
        elemento = ET.SubElement(operacion,"cod_organismo")
        elemento.text = row["cod_organismo"]
        elemento = ET.SubElement(operacion,"cod_actuacion")
        elemento.text = row["cod_actuacion"]
        elemento = ET.SubElement(operacion,"nombre")
        elemento.text = row["nombre"]
        elemento = ET.SubElement(operacion,"name")
        elemento.text = row["name"]
        elemento = ET.SubElement(operacion,"descripcion")
        elemento.text = row["descripcion"]
        elemento = ET.SubElement(operacion,"operation_summary")
        elemento.text = row["operation_summary"]
        elemento = ET.SubElement(operacion,"cod_beneficiario")
        elemento.text = row["cod_beneficiario"]
        elemento = ET.SubElement(operacion,"iva_recuperable")
        elemento.text = row["iva_recuperable"]
        elemento = ET.SubElement(operacion,"costetotal")
        elemento.text = row["costetotal"]
        elemento = ET.SubElement(operacion,"costetotal_subv")
        elemento.text = row["costetotal_subv"]
        elemento = ET.SubElement(operacion,"costepub_subv")
        elemento.text = row["costepub_subv"]
        elemento = ET.SubElement(operacion,"ayuda_publica_deca")
        elemento.text = row["ayuda_publica_deca"]
        elemento = ET.SubElement(operacion,"utilizacion_ocs")
        elemento.text = row["utilizacion_ocs"]
        elemento = ET.SubElement(operacion,"cod_base_calculo_1")
        elemento.text = row["cod_base_calculo_1"]
        elemento = ET.SubElement(operacion,"cod_base_calculo_2")
        elemento.text = row["cod_base_calculo_2"]
        elemento = ET.SubElement(operacion,"cod_base_calculo_3")
        elemento.text = row["cod_base_calculo_3"]
        elemento = ET.SubElement(operacion,"cod_base_calculo_4")
        elemento.text = row["cod_base_calculo_4"]
        elemento = ET.SubElement(operacion,"finan_costeind")
        elemento.text = row["finan_costeind"]
        elemento = ET.SubElement(operacion,"calculo_hora")
        elemento.text = row["calculo_hora"]
        elemento = ET.SubElement(operacion,"cod_manera_tipofijo")
        elemento.text = row["cod_manera_tipofijo"]
        elemento = ET.SubElement(operacion,"finan_tipofijo_horizonte2020")
        elemento.text = row["finan_tipofijo_horizonte2020"]
        elemento = ET.SubElement(operacion,"finan_tipofijo_LIFE")
        elemento.text = row["finan_tipofijo_LIFE"]
        elemento = ET.SubElement(operacion,"autorizado_ocs_ag")
        elemento.text = row["autorizado_ocs_ag"]
        elemento = ET.SubElement(operacion,"f_presentacion")
        elemento.text = row["f_presentacion"]
        elemento = ET.SubElement(operacion,"f_inicio_DECA")
        elemento.text = row["f_inicio_DECA"]
        elemento = ET.SubElement(operacion,"f_inicio_ejecucion_real")
        elemento.text = row["f_inicio_ejecucion_real"]
        elemento = ET.SubElement(operacion,"f_fin")
        elemento.text = row["f_fin"]
        elemento = ET.SubElement(operacion,"f_real")
        elemento.text = row["f_real"]
        elemento = ET.SubElement(operacion,"cod_org_deca")
        elemento.text = row["cod_org_deca"]      
        elemento = ET.SubElement(operacion,"f_deca")
        elemento.text = row["f_deca"]#crear una funcion para las fechas
        elemento = ET.SubElement(operacion,"fecha_oper_fin_2_14")
        elemento.text = row["fecha_oper_fin_2_14"]
        elemento = ET.SubElement(operacion,"gproyecto")
        elemento.text = row["gproyecto"]
        elemento = ET.SubElement(operacion,"cod_gran_proyecto")
        elemento.text = row["cod_gran_proyecto"]
        elemento = ET.SubElement(operacion,"texto_gp")
        elemento.text = row["texto_gp"]
        elemento = ET.SubElement(operacion,"plan_accion_conjunto")
        elemento.text = row["plan_accion_conjunto"] 
        elemento = ET.SubElement(operacion,"regimen_ayudas")
        elemento.text = row["regimen_ayudas"]
        elemento = ET.SubElement(operacion,"referencia_bdns")
        elemento.text = row["referencia_bdns"]
        elemento = ET.SubElement(operacion,"proy_cooperacion")
        elemento.text = row["proy_cooperacion"]
        elemento = ET.SubElement(operacion,"cod_proyecto")
        elemento.text = row["cod_proyecto"]
        elemento = ET.SubElement(operacion,"ayuda_estado")
        elemento.text = row["ayuda_estado"]
        elemento = ET.SubElement(operacion,"cod_tipo_ayuda")
        elemento.text = row["cod_tipo_ayuda"]
        elemento = ET.SubElement(operacion,"reglamento_minimis")
        elemento.text = row["reglamento_minimis"]
        elemento = ET.SubElement(operacion,"reglamento_exencion")
        elemento.text = row["reglamento_exencion"]
        elemento = ET.SubElement(operacion,"f_comunicacion_exencion")
        elemento.text = row["f_comunicacion_exencion"]
        elemento = ET.SubElement(operacion,"notificacion_autorizacion")
        elemento.text = row["notificacion_autorizacion"]
        elemento = ET.SubElement(operacion,"f_notificacion_autorizacion")
        elemento.text = row["f_notificacion_autorizacion"]
        elemento = ET.SubElement(operacion,"f_autorizacion")
        elemento.text = row["f_autorizacion"]
        elemento = ET.SubElement(operacion,"publica_privada")
        elemento.text = row["publica_privada"]
        elemento = ET.SubElement(operacion,"cod_pubpriv")
        elemento.text = row["cod_pubpriv"]
        elemento = ET.SubElement(operacion,"finan_anticipos")
        elemento.text = row["finan_anticipos"]
        elemento = ET.SubElement(operacion,"convenio")
        elemento.text = row["convenio"]
        elemento = ET.SubElement(operacion,"cod_convenio")
        elemento.text = row["cod_convenio"]
        elemento = ET.SubElement(operacion,"cod_iti_1")
        elemento.text = row["cod_iti_1"]
        
        
        elemento = ET.SubElement(operacion,"cod_proyecto")
        elemento.text = row["cod_proyecto"]
        elemento = ET.SubElement(operacion,"cod_proyecto")
        elemento.text = row["cod_proyecto"]
        elemento = ET.SubElement(operacion,"cod_proyecto")
        elemento.text = row["cod_proyecto"]
# Out:
# {'cod_poperativo': 'SO-DANA', 'cod_operacion': 'ES330024_1', 'cod_subvencionglobal': '', 'cod_eje': '80', 'cat_region': '9', 'cod_obj_tematico': '80', 'cod_prioridad': '80', 'cod_obj_especifico': '80', 'cod_organismo': 'ES115007', 'cod_actuacion': 'SO_1', 'nombre': 'GASTOS DANA AYUNTAMIENTO DE ABANILLA', 'name': 'GASTOS DANA AYUNTAMIENTO DE ABANILLA', 'descripcion': 'Reparaciones urgentes de los daños producidos por las fuertes lluvias e inundaciones en el Sureste de la Península Ibérica durante Septiembre de 2019.', 'operation_summary': 'Urgent repair works of the damages produced bay the heavy rains and floodings in the South Esast of the Iberian Peninsule during Spetember 2019.', 'cod_beneficiario': 'ES330024', 'iva_recuperable': 'N', 'costetotal': '39408,90476', 'costetotal_subv': '9931,044', 'costepub_subv': '9931,044', 'ayuda_publica_deca': '8275,87', 'utilizacion_ocs': 'N', 'cod_base_calculo_1': 'CORE', 'cod_base_calculo_2': '', 'cod_base_calculo_3': '', 'cod_base_calculo_4': 
# ...
