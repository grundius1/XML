# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd

# %%
route = "C:/Users/bllanos/Desktop/project1/XML-CSV/CDTI"
for item in os.listdir(route):
    file = route + "/" +item
    print(file)
    if ".xml" in file:
        tree = ET.parse(file)
        root = tree.getroot()
        for thing in list(root):
            for question in list(thing):
                print(question.text)
# Out:
# C:/Users/bllanos/Desktop/project1/XML-CSV/CDTI/ListaOperacionesVerif_AT92_2906202163918.xml
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 1
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 2
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 3
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 4
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 5
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 6
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 7
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 8
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 9
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 10
# S
# PE
# RedIDIPersonalEnTransicion
# 25/05/2018
# VsT
# VsTv0
# 11
# S
# PE
# RedIDIPersonalEnTransicion
# 26/03/2018
# VsT
# VsTv0
# 1
# S
# PE
# RedIDIPersonalEnTransicion
# 26/03/2018
# VsT
# VsTv0
# 2
# S
# PE
# ...

# %%
for item in files:
    tree = ET.parse(item)
    root = tree.getroot()
    for thing in list(root):
        print(thing)
