# %%
import os
import csv
import pandas as pd
import re
import xml.etree.ElementTree as ET
import numpy as np

# %%
pd.set_option('display.max_rows', None)

# %%
ayuntamientos = {'ABANILLA-JOG': ['ES330024_1', 'GASTOS DANA AYUNTAMIENTO DE ABANILLA', 'ES330024', "30"],
 'ABARÁN-EBB': ['ES330031_1', 'GASTOS DANA AYUNTAMIENTO DE ABARÁN', 'ES330031', "30"],
 'AENA-MAC-EBB': ['ES117023_1', 'GASTOS DANA AENA (MITMA)', 'ES117023', "28"],
 'AGULLENT-JOG': ['ES303050_1','GASTOS DANA AYUNTAMIENTO DE AGULLENT','ES303050', "46"],
 'ALBAIDA-MAC': ['ES346012_1', 'GASTOS DANA AYUNTAMIENTO DE ALBAIDA', 'ES346012', "46"],
 'ALBATERA-JOG': ['ES303044_1','GASTOS DANA AYUNTAMIENTO DE ALBATERA','ES303044', "03"],
 #'ALCAUCÍN-RENUNCIA': ['ES329032_1','GASTOS DANA AYUNTAMIENTO DE ALCAUCÍN','ES329032', "29"],
 'ALCÁZARES-MAC': ['ES330025_1','GASTOS DANA AYUNTAMIENTO DE ALCÁZARES, LOS','ES330025', "30"],
 'ALCÓNTAR-JOG': ['ES304029_1','GASTOS DANA AYUNTAMIENTO DE ALCÓNTAR', 'ES304029', "04"],
 'ALGORFA-JOG': ['ES303016_1', 'GASTOS DANA AYUNTAMIENTO DE ALGORFA', 'ES303016', "03"],
 'ALHAURÍN DE LA TORRE-MAC': ['ES329005_1','GASTOS DANA AYUNTAMIENTO DE ALHAURÍN DE LA TORRE','ES329005', "29"],
 'ALMANSA-EBB': ['ES302002_1', 'GASTOS DANA AYUNTAMIENTO DE ALMANSA', 'ES302002', "02"],
 #'ALMERÍA-DGM': ['ES304004_1', 'GASTOS DANA AYUNTAMIENTO DE ALMERÍA', 'ES304004', "04"],
 'ALMORADÍ-DGM': ['ES303017_1','GASTOS DANA AYUNTAMIENTO DE ALMORADÍ','ES303017', "46"],
 "ALQUERIA DE AZNAR-EBB": ['ES303018_1', "GASTOS DANA AYUNTAMIENTO DE ALQUERIA D'ASNAR, L'", 'ES303018', "46"],
 'AP CARTAGENA-MAC': ['ES117025_1', 'GASTOS DANA AUTORIDAD PORTUARIA CARTAGENA (MITMA)', 'ES117025', "30"],
 'ARBOLEAS-MAC': ['ES304025_1','GASTOS DANA AYUNTAMIENTO DE ARBOLEAS','ES304025', "04"],
 'ARCHENA-MAC': ['ES330005_1', 'GASTOS DANA AYUNTAMIENTO DE ARCHENA', 'ES330005', "30"],
 'ARCHIDONA-EBB': ['ES329023_1','GASTOS DANA AYUNTAMIENTO DE ARCHIDONA','ES329023', "29"],
 'BAZA-MAC': ['ES318001_1', 'GASTOS DANA AYUNTAMIENTO DE BAZA', 'ES318001', "18"],
 'BENIEL-JOG': ['ES330013_1', 'GASTOS DANA AYUNTAMIENTO DE BENIEL', 'ES330013', "30"],
 #'BIENSERVIDA-RENUNCIA': [],
 'BIGASTRO-JOG': ['ES303051_1','GASTOS DANA AYUNTAMIENTO DE BIGASTRO', 'ES303051', "46"],
 'BLANCA-JOG': ['ES330015_1', 'GASTOS DANA AYUNTAMIENTO DE BLANCA', 'ES330015', "30"],
 'CAMPOS DEL RÍO - DGM': ['ES330030_1', 'GASTOS DANA AYUNTAMIENTO DE CAMPOS DEL RÍO', 'ES330030', "30"],
 'CARTAGENA-JOG': ['ES3300065_1','GASTOS DANA AYUNTAMIENTO DE CARTAGENA', 'ES330006', "30"],
 'CASTILLA LA MANCHA- DGM': ['ES211001_1','GASTOS DANA COMUNIDAD AUTÓNOMA DE CASTILLA-LA MANCHA','ES211001', "45"],
 'CASTRIL-DGM': ['ES318054_1', 'GASTOS DANA AYUNTAMIENTO DE CASTRIL', 'ES318054', "18"],
 'CHAUCHINA-JOG': ['ES318053_1', 'GASTOS DANA AYUNTAMIENTO DE CHAUCHINA', 'ES318053', "18"],
 'CIEZA-JOG': ['ES330002_1', 'GASTOS DANA AYUNTAMIENTO DE CIEZA', 'ES330002', "30"],
 'COCENTAINA-EBB': ['ES303025_1', 'GASTOS DANA AYUNTAMIENTO DE COCENTAINA', 'ES303025', "03"],
 'CONF.HIDRO.JÚCAR-EBB': ['ES130001_1', 'GASTOS DANA  CONFEDERACION HIDROGRAFICA DEL JÚCAR, O.A. DEL MITECO', 'ES130001', "46"],
 'CONF.HIDRO.SEGURA-MAC': ['ES130006_1', 'GASTOS DANA CONFEDERACION HIDROGRAFICA DEL SEGURA, O.A. DEL MITECO', 'ES130006', "30"],
 #'COX-RENUNCIA': ['ES303053_1', 'GASTOS DANA AYUNTAMIENTO DE COX', 'ES303053', "03"],
 'COÍN-JOG': ['ES329029_1', 'GASTOS DANA AYUNTAMIENTO DE COÍN', 'ES329029', "29"],
 'CREVILLENT-MAC': ['ES303047_1', 'GASTOS DANA AYUNTAMIENTO DE CREVILLENT', 'ES303047', "03"],
 'CUEVAS DEL CAMPO-JOG': ['ES318058_1', 'GASTOS DANA AYUNTAMIENTO DE CUEVAS DEL CAMPO', 'ES318058', "18"],
 #'CULLAR-RENUNCIA-JOG': ['ES318056_1','GASTOS DANA AYUNTAMIENTO DE CÚLLAR','ES318056', "18"],
 #'data_blp': [],
 'DAYA NUEVA-DGM': ['ES303046_1', 'GASTOS DANA AYUNTAMIENTO DE DAYA NUEVA', 'ES303046', "03"],
 'DENIA-MAC': ['ES303026_1', 'GASTOS DANA AYUNTAMIENTO DE DÉNIA', 'ES303026', "03"],
 'DGCMTM y AU-JOG': ['ES117007_1', 'GASTOS DANA DG CARRETERASV (MITMA)', 'ES117007', "30"],
 'DP ALBACETE-DGM': ['ES302026_1', 'GASTOS DANA DIPUTACIÓN PROVINCIAL DE ALBACETE', 'ES302026', "02"],
 'DP ALMERÍA- DGM': ['ES304006_1', 'GASTOS DANA DIPUTACIÓN PROVINCIAL DE ALMERÍA', 'ES304006', "04"],
 'DP GRANADA-JOG': ['ES318007_1', 'GASTOS DANA DIPUTACIÓN PROVINCIAL DE GRANADA', 'ES318007', "18"],
 'DP MÁLAGA-JOG': ['ES329003_1', 'GASTOS DANA DIPUTACIÓN PROVINCIAL DE MÁLAGA', 'ES329003', "29"],
 'FUENTE-ÁLAMO-JOG': ['ES302052_1', 'GASTOS DANA AYUNTAMIENTO DE FUENTE-ÁLAMO', 'ES302052', "30"],
 'GALLARDOS-JOG': ['ES304026_1', 'GASTOS DANA AYUNTAMIENTO DE GALLARDOS, LOS', 'ES304026', "04"],
 'GENERALITAT VALENCIANA-EBB': ['ES209001_1', 'GASTOS DANA GENERALITAT VALENCIANA', 'ES209001', "46"],
 'GRANADA-JOG': ['ES318003_1', 'GASTOS DANA AYUNTAMIENTO DE GRANADA', 'ES318003', "18"],
 'HELLÍN-DGM': ['ES302051_1', 'GASTOS DANA AYUNTAMIENTO DE HELLÍN', 'ES302051', "02"],
 'HOYA GONZALO-JOG': ['ES302058_1', 'GASTOS DANA AYUNTAMIENTO DE HOYA-GONZALO', 'ES302058', "02"],
 'HUESCAR-DGM': ['ES318042_1', 'GASTOS DANA AYUNTAMIENTO DE HUÉSCAR', 'ES318042', "18"],
 'JACARILA-JOG': ['ES303052_1', 'GASTOS DANA AYUNTAMIENTO DE JACARILLA', 'ES303052', "03"],
 'JUNTA ANDALUCÍA-JOG': ['ES204001_1', 'GASTOS DANA JUNTA DE ANDALUCÍA', 'ES204001', "41"],
 'L-OLLERIA-JOG': ['ES346056_1', "GASTOS DANA AYUNTAMIENTO DE OLLERIA, L'", 'ES346056', "46"],
 'LOJA - JOG': ['ES318055_1', 'GASTOS DANA AYUNTAMIENTO DE LOJA', 'ES318055',"18"],
 'LORCA-DGM': ['ES330028_1', 'GASTOS DANA AYUNTAMIENTO DE LORCA', 'ES330028', "30"],
 'LORCHA-DGM': ['ES303054_1', "GASTOS DANA AYUNTAMIENTO DE LORCHA/ORXA, L'", 'ES303054', "03"],
 'LORQUÍ-JOG': ['ES330017_1', 'GASTOS DANA AYUNTAMIENTO DE LORQUÍ', 'ES330017', "30"],
 'MINISTERIO DEFENSA-EBB': ['ES114007_1', 'GASTOS DANA MINISTERIO DE DEFENSA', 'ES114007', "28"],
 'MOLINA DEL SEGURA-MAC': ['ES330009_1', 'GASTOS DANA AYUNTAMIENTO DE MOLINA DE SEGURA', 'ES330009', "30"],
 'MOLINICOS-DGM': ['ES302018_1', 'GASTOS DANA AYUNTAMIENTO DE MOLINICOS', 'ES302018', "02"],
 'MONACHIL- DGM': ['ES318026_1', 'GASTOS DANA AYUNTAMIENTO DE MONACHIL', 'ES318026', "18"],
 'NERPIO-JOG': ['ES302023_1', 'GASTOS DANA AYUNTAMIENTO DE NERPIO', 'ES302023', "02"],
 'NIJAR-MAC': ['ES304007_1', 'GASTOS DANA AYUNTAMIENTO DE NÍJAR', 'ES304007', "04"],
 'NOVELDA-EBB': ['ES303045_1', 'GASTOS DANA AYUNTAMIENTO DE NOVELDA', 'ES303045', "03"],
 'OJÓS-JOG': ['ES330026_1', 'GASTOS DANA AYUNTAMIENTO DE OJÓS', 'ES330026', "30"],
 'OLULA DEL RÍO-JOG': ['ES304027_1', 'GASTOS DANA AYUNTAMIENTO DE OLULA DEL RÍO', 'ES304027', "04"],
 'ONTINYENT-MAC': ['ES346007_1', 'GASTOS DANA AYUNTAMIENTO DE ONTINYENT', 'ES346007', "46"],
 'ONTUR-DGM': ['ES302053_1', 'GASTOS DANA AYUNTAMIENTO DE ONTUR', 'ES302053', "02"],
 'ORIHUELA-MAC': ['ES303003_1', 'GASTOS DANA AYUNTAMIENTO DE ORIHUELA', 'ES303003', "03"],
 'OTOS-JOG': ['ES346081_1', 'GASTOS DANA AYUNTAMIENTO DE OTOS', 'ES346081', "46"],
 'PARCENT-EBB': ['ES303049_1', 'GASTOS DANA AYUNTAMIENTO DE PARCENT', 'ES303049', "03"],
 'PILAR DE LA HORADADA EBB': ['ES303041_1', 'GASTOS DANA AYUNTAMIENTO DE PILAR DE LA HORADADA', 'ES303041', "03"],
 'PINOS GENIL-MAC': ['ES318057_1', 'GASTOS DANA AYUNTAMIENTO DE PINOS GENIL', 'ES318057', "18"],
 'PUEBLA DE DON FADRIQUE-EBB': ['ES318043_1', 'GASTOS DANA AYUNTAMIENTO DE PUEBLA DE DON FADRIQUE', 'ES318043', "18"],
 'PUERTO LUMBRERAS-JOG': ['ES330033_1', 'GASTOS DANA AYUNTAMIENTO DE PUERTO LUMBRERAS', 'ES330033', "30"],
 'PULPÍ-JOG': ['ES304016_1', 'GASTOS DANA AYUNTAMIENTO DE PULPÍ', 'ES304016', "04"],
 'PURCHENA-JOG': ['ES304019_1', 'GASTOS DANA AYUNTAMIENTO DE PURCHENA', 'ES304019', "04"],
 'REDOVÁN-DGM': ['ES303048_1', 'GASTOS DANA AYUNTAMIENTO DE REDOVÁN', 'ES303048', "03"],
 'REGIÓN DE MURCIA-DGM': ['ES208001_1', 'GASTOS DANA REGIÓN DE MURCIA', 'ES208001', "30"],
 'RENFE-MAC': ['ES117024_1', 'GASTOS DANA RENFE (MITMA)', 'ES117024', "28"],
 'RINCÓN DE LA VICTORIA-DGM': ['ES329011_1', 'GASTOS DANA AYUNTAMIENTO DE RINCÓN DE LA VICTORIA', 'ES329011', "29"],
 'RIOJA-JOG': ['ES304024_1', 'GASTOS DANA AYUNTAMIENTO DE RIOJA', 'ES304024',"04"],
 'SAN FULGENCIO-MAC': ['ES302057_1', 'GASTOS DANA AYUNTAMIENTO DE SAN FULGENCIO', 'ES302057', "03"],
 'SAN JAVIER-JOG': ['ES330001_1', 'GASTOS DANA AYUNTAMIENTO DE SAN JAVIER', 'ES330001', "30"],
 'SANTOMERA-JOG': ['ES330014_1', 'GASTOS DANA AYUNTAMIENTO DE SANTOMERA', 'ES330014', "30"],
 'SERÓN-JOG': ['ES304022_1', 'GASTOS DANA AYUNTAMIENTO DE SERÓN', 'ES304022', "04"],
 'TABERNO - JOG': ['ES304030_1', 'GASTOS DANA AYUNTAMIENTO DE TABERNO', 'ES304030'],
 'TÍJOLA-DGM' : ['ES304028_1', 'GASTOS DANA AYUNTAMIENTO DE TÍJOLA', 'ES304028', "04"],
 'TORRE PACHECO-DGM': ['ES330010_1', 'GASTOS DANA AYUNTAMIENTO DE TORRE-PACHECO', 'ES330010', "30"],
 'TORRES DE COTILLAS-MAC': ['ES330008_1', 'GASTOS DANA AYUNTAMIENTO DE TORRES DE COTILLAS, LAS', 'ES330008', "30"],
 'TOTANA-JOG': ['ES330032_1', 'GASTOS DANA AYUNTAMIENTO DE TOTANA', 'ES330032', "30"],
 
 'ULEA-JOG': ['ES330029_1', 'GASTOS DANA AYUNTAMIENTO DE ULEA', 'ES330029', "30"],
 'UNIÓN-DGM': ['ES330027_1', 'GASTOS DANA AYUNTAMIENTO DE UNIÓN, LA', 'ES330027', "30"],
 'URRACAL-DGM': ['ES304031_1', 'GASTOS DANA AYUNTAMIENTO DE URRÁCAL', 'ES304031', "04"],
 'VALLADA-JOG': ['ES312038_1', 'GASTOS DANA AYUNTAMIENTO DE VALLADA', 'ES312038', "46"],
 'VILLANUEVA DEL RIO SEGURA-DGM': ['ES330018_1', 'GASTOS DANA AYUNTAMIENTO DE VILLANUEVA DEL RÍO SEGURA', 'ES330018', "30"],
 'VIVEROS-JOG': ['ES302030_1', 'GASTOS DANA AYUNTAMIENTO DE VIVEROS', 'ES302030', "02"],
 'VÉLEZ MÁLAGA-DGM': ['ES329014_1', 'GASTOS DANA AYUNTAMIENTO DE VÉLEZ-MÁLAGA', 'ES329014', "29"],
 'ZURGENA-JOG': ['ES304023_1', 'GASTOS DANA AYUNTAMIENTO DE ZURGENA', 'ES304023', "04"]}

# %%
ayuntamientos = {'TÍJOLA-DGM' : ['ES304028_1', 'GASTOS DANA AYUNTAMIENTO DE TÍJOLA', 'ES304028', "04"],
                 'CONF.HIDRO.SEGURA-MAC': ['ES130006_1', 'GASTOS DANA CONFEDERACION HIDROGRAFICA DEL SEGURA, O.A. DEL MITECO', 'ES130006', "30"],
                 'ALGORFA-JOG': ['ES303016_1', 'GASTOS DANA AYUNTAMIENTO DE ALGORFA', 'ES303016', "03"],
                 'SERÓN-JOG': ['ES304022_1', 'GASTOS DANA AYUNTAMIENTO DE SERÓN', 'ES304022', "04"],
                 'BIGASTRO-JOG': ['ES303051_1','GASTOS DANA AYUNTAMIENTO DE BIGASTRO', 'ES303051', "46"],
                 'MINISTERIO DEFENSA-EBB': ['ES114007_1', 'GASTOS DANA MINISTERIO DE DEFENSA', 'ES114007', "28"],
                 'CONF.HIDRO.JÚCAR-EBB': ['ES130001_1', 'GASTOS DANA  CONFEDERACION HIDROGRAFICA DEL JÚCAR, O.A. DEL MITECO', 'ES130001', "46"],
                 'ALMORADÍ-DGM': ['ES303017_1','GASTOS DANA AYUNTAMIENTO DE ALMORADÍ','ES303017', "46"],
                }

# %%
len(ayuntamientos)
# Out:
# 8

# %%
ayuntamientos= {'NIJAR-MAC': ['ES304007_1', 'GASTOS DANA AYUNTAMIENTO DE NÍJAR', 'ES304007', "04"],
                'ALGORFA-JOG': ['ES303016_1', 'GASTOS DANA AYUNTAMIENTO DE ALGORFA', 'ES303016', "03"],
                'TÍJOLA-DGM' : ['ES304028_1', 'GASTOS DANA AYUNTAMIENTO DE TÍJOLA', 'ES304028', "04"],
                'HUESCAR-DGM': ['ES318042_1', 'GASTOS DANA AYUNTAMIENTO DE HUÉSCAR', 'ES318042', "18"],
                'RIOJA-JOG': ['ES304024_1', 'GASTOS DANA AYUNTAMIENTO DE RIOJA', 'ES304024',"04"],
                'CONF.HIDRO.SEGURA-MAC': ['ES130006_1', 'GASTOS DANA CONFEDERACION HIDROGRAFICA DEL SEGURA, O.A. DEL MITECO', 'ES130006', "30"],
               'ALCÁZARES-MAC': ['ES330025_1','GASTOS DANA AYUNTAMIENTO DE ALCÁZARES, LOS','ES330025', "30"],
               'BIGASTRO-JOG': ['ES303051_1','GASTOS DANA AYUNTAMIENTO DE BIGASTRO', 'ES303051', "46"],
               'DAYA NUEVA-DGM': ['ES303046_1', 'GASTOS DANA AYUNTAMIENTO DE DAYA NUEVA', 'ES303046', "03"],
               'FUENTE-ÁLAMO-JOG': ['ES302052_1', 'GASTOS DANA AYUNTAMIENTO DE FUENTE-ÁLAMO', 'ES302052', "30"],
               'ALBATERA-JOG': ['ES303044_1','GASTOS DANA AYUNTAMIENTO DE ALBATERA','ES303044', "03"],
               }

# %%
ayuntamientos= {'RENFE-MAC': ['ES117024_1', 'GASTOS DANA RENFE (MITMA)', 'ES117024', "28"],
                'REGIÓN DE MURCIA-DGM': ['ES208001_1', 'GASTOS DANA REGIÓN DE MURCIA', 'ES208001', "30"],
                #'MINISTERIO DEFENSA-EBB': ['ES114007_1', 'GASTOS DANA MINISTERIO DE DEFENSA', 'ES114007', "28"],
                'JUNTA ANDALUCÍA-JOG': ['ES204001_1', 'GASTOS DANA JUNTA DE ANDALUCÍA', 'ES204001', "41"],
                'DP MÁLAGA-JOG': ['ES329003_1', 'GASTOS DANA DIPUTACIÓN PROVINCIAL DE MÁLAGA', 'ES329003', "29"],
                'CONF.HIDRO.JÚCAR-EBB': ['ES130001_1', 'GASTOS DANA  CONFEDERACION HIDROGRAFICA DEL JÚCAR, O.A. DEL MITECO', 'ES130001', "46"],
                'ZURGENA-JOG': ['ES304023_1', 'GASTOS DANA AYUNTAMIENTO DE ZURGENA', 'ES304023', "04"],
                'VIVEROS-JOG': ['ES302030_1', 'GASTOS DANA AYUNTAMIENTO DE VIVEROS', 'ES302030', "02"],
                'VALLADA-JOG': ['ES312038_1', 'GASTOS DANA AYUNTAMIENTO DE VALLADA', 'ES312038',"46"],
                'ULEA-JOG': ['ES330029_1', 'GASTOS DANA AYUNTAMIENTO DE ULEA', 'ES330029', "30"],
                'TOTANA-JOG': ['ES330032_1', 'GASTOS DANA AYUNTAMIENTO DE TOTANA', 'ES330032', "30"],
                'TORRES DE COTILLAS-MAC': ['ES330008_1', 'GASTOS DANA AYUNTAMIENTO DE TORRES DE COTILLAS, LAS', 'ES330008', "30"],
                'TABERNO - JOG': ['ES304030_1', 'GASTOS DANA AYUNTAMIENTO DE TABERNO', 'ES304030'],
                'SERÓN-JOG': ['ES304022_1', 'GASTOS DANA AYUNTAMIENTO DE SERÓN', 'ES304022', "04"],
                'SANTOMERA-JOG': ['ES330014_1', 'GASTOS DANA AYUNTAMIENTO DE SANTOMERA', 'ES330014', "30"],
                'SAN JAVIER-JOG': ['ES330001_1', 'GASTOS DANA AYUNTAMIENTO DE SAN JAVIER', 'ES330001', "30"],
                'SAN FULGENCIO-MAC': ['ES302057_1', 'GASTOS DANA AYUNTAMIENTO DE SAN FULGENCIO', 'ES302057', "03"],
                'PURCHENA-JOG': ['ES304019_1', 'GASTOS DANA AYUNTAMIENTO DE PURCHENA', 'ES304019', "04"],
                'PULPÍ-JOG': ['ES304016_1', 'GASTOS DANA AYUNTAMIENTO DE PULPÍ', 'ES304016', "04"],
                'PUERTO LUMBRERAS-JOG': ['ES330033_1', 'GASTOS DANA AYUNTAMIENTO DE PUERTO LUMBRERAS', 'ES330033', "30"],
                'PINOS GENIL-MAC': ['ES318057_1', 'GASTOS DANA AYUNTAMIENTO DE PINOS GENIL', 'ES318057', "18"],
                'OTOS-JOG': ['ES346081_1', 'GASTOS DANA AYUNTAMIENTO DE OTOS', 'ES346081', "46"],
                'ORIHUELA-MAC': ['ES303003_1', 'GASTOS DANA AYUNTAMIENTO DE ORIHUELA', 'ES303003', "03"],
                'ONTINYENT-MAC': ['ES346007_1', 'GASTOS DANA AYUNTAMIENTO DE ONTINYENT', 'ES346007', "46"],
                'OLULA DEL RÍO-JOG': ['ES304027_1', 'GASTOS DANA AYUNTAMIENTO DE OLULA DEL RÍO', 'ES304027', "04"],
                'L-OLLERIA-JOG': ['ES346056_1', "GASTOS DANA AYUNTAMIENTO DE OLLERIA, L'", 'ES346056', "46"],
                'OJÓS-JOG': ['ES330026_1', 'GASTOS DANA AYUNTAMIENTO DE OJÓS', 'ES330026', "30"],
                #'NERPIO-JOG': ['ES302023_1', 'GASTOS DANA AYUNTAMIENTO DE NERPIO', 'ES302023', "02"],
                'MOLINICOS-DGM': ['ES302018_1', 'GASTOS DANA AYUNTAMIENTO DE MOLINICOS', 'ES302018', "02"],
                'MOLINA DEL SEGURA-MAC': ['ES330009_1', 'GASTOS DANA AYUNTAMIENTO DE MOLINA DE SEGURA', 'ES330009', "30"],
                'LORQUÍ-JOG': ['ES330017_1', 'GASTOS DANA AYUNTAMIENTO DE LORQUÍ', 'ES330017', "30"],
                'LOJA - JOG': ['ES318055_1', 'GASTOS DANA AYUNTAMIENTO DE LOJA', 'ES318055', "18"],
                'JACARILA-JOG': ['ES303052_1', 'GASTOS DANA AYUNTAMIENTO DE JACARILLA', 'ES303052', "03"],
                'GRANADA-JOG': ['ES318003_1', 'GASTOS DANA AYUNTAMIENTO DE GRANADA', 'ES318003', "18"],
                'GALLARDOS-JOG': ['ES304026_1', 'GASTOS DANA AYUNTAMIENTO DE GALLARDOS, LOS', 'ES304026', "04"],
                'DENIA-MAC': ['ES303026_1', 'GASTOS DANA AYUNTAMIENTO DE DÉNIA', 'ES303026', "03"],
                'CREVILLENT-MAC': ['ES303047_1', 'GASTOS DANA AYUNTAMIENTO DE CREVILLENT', 'ES303047', "03"],
                'CIEZA-JOG': ['ES330002_1', 'GASTOS DANA AYUNTAMIENTO DE CIEZA', 'ES330002', "30"],
                'BLANCA-JOG': ['ES330015_1', 'GASTOS DANA AYUNTAMIENTO DE BLANCA', 'ES330015', "30"],
                'BENIEL-JOG': ['ES330013_1', 'GASTOS DANA AYUNTAMIENTO DE BENIEL', 'ES330013', "30"],
                'BAZA-MAC': ['ES318001_1', 'GASTOS DANA AYUNTAMIENTO DE BAZA', 'ES318001', "18"],
                'ARCHENA-MAC': ['ES330005_1', 'GASTOS DANA AYUNTAMIENTO DE ARCHENA', 'ES330005', "30"],
                'ARBOLEAS-MAC': ['ES304025_1','GASTOS DANA AYUNTAMIENTO DE ARBOLEAS','ES304025', "04"],
                'ALMORADÍ-DGM': ['ES303017_1','GASTOS DANA AYUNTAMIENTO DE ALMORADÍ','ES303017', "46"],
                'ALHAURÍN DE LA TORRE-MAC': ['ES329005_1','GASTOS DANA AYUNTAMIENTO DE ALHAURÍN DE LA TORRE','ES329005', "29"],
    
                'ALCÓNTAR-JOG': ['ES304029_1','GASTOS DANA AYUNTAMIENTO DE ALCÓNTAR', 'ES304029', "04"],
                'ALBAIDA-MAC': ['ES346012_1', 'GASTOS DANA AYUNTAMIENTO DE ALBAIDA', 'ES346012', "46"],
                'AGULLENT-JOG': ['ES303050_1','GASTOS DANA AYUNTAMIENTO DE AGULLENT','ES303050', "46"],
                'ABANILLA-JOG': ['ES330024_1', 'GASTOS DANA AYUNTAMIENTO DE ABANILLA', 'ES330024', "30"],
                'AP CARTAGENA-MAC': ['ES117025_1', 'GASTOS DANA AUTORIDAD PORTUARIA CARTAGENA (MITMA)', 'ES117025', "30"],
               }

# %%
len(ayuntamientos)
# Out:
# 48

# %%
ayuntamientos= {'NIJAR-MAC': ['ES304007_1', 'GASTOS DANA AYUNTAMIENTO DE NÍJAR', 'ES304007', "04"],
                'ALGORFA-JOG': ['ES303016_1', 'GASTOS DANA AYUNTAMIENTO DE ALGORFA', 'ES303016', "03"],
                'TÍJOLA-DGM' : ['ES304028_1', 'GASTOS DANA AYUNTAMIENTO DE TÍJOLA', 'ES304028', "04"],
                'HUESCAR-DGM': ['ES318042_1', 'GASTOS DANA AYUNTAMIENTO DE HUÉSCAR', 'ES318042', "18"],
                'RIOJA-JOG': ['ES304024_1', 'GASTOS DANA AYUNTAMIENTO DE RIOJA', 'ES304024',"04"],
                'CONF.HIDRO.SEGURA-MAC': ['ES130006_1', 'GASTOS DANA CONFEDERACION HIDROGRAFICA DEL SEGURA, O.A. DEL MITECO', 'ES130006', "30"],
               'ALCÁZARES-MAC': ['ES330025_1','GASTOS DANA AYUNTAMIENTO DE ALCÁZARES, LOS','ES330025', "30"],
               'BIGASTRO-JOG': ['ES303051_1','GASTOS DANA AYUNTAMIENTO DE BIGASTRO', 'ES303051', "46"],
               'DAYA NUEVA-DGM': ['ES303046_1', 'GASTOS DANA AYUNTAMIENTO DE DAYA NUEVA', 'ES303046', "03"],
               'FUENTE-ÁLAMO-JOG': ['ES302052_1', 'GASTOS DANA AYUNTAMIENTO DE FUENTE-ÁLAMO', 'ES302052', "30"],
               'ALBATERA-JOG': ['ES303044_1','GASTOS DANA AYUNTAMIENTO DE ALBATERA','ES303044', "03"],
               'RENFE-MAC': ['ES117024_1', 'GASTOS DANA RENFE (MITMA)', 'ES117024', "28"],
                'REGIÓN DE MURCIA-DGM': ['ES208001_1', 'GASTOS DANA REGIÓN DE MURCIA', 'ES208001', "30"],
                #'MINISTERIO DEFENSA-EBB': ['ES114007_1', 'GASTOS DANA MINISTERIO DE DEFENSA', 'ES114007', "28"],
                'JUNTA ANDALUCÍA-JOG': ['ES204001_1', 'GASTOS DANA JUNTA DE ANDALUCÍA', 'ES204001', "41"],
                'DP MÁLAGA-JOG': ['ES329003_1', 'GASTOS DANA DIPUTACIÓN PROVINCIAL DE MÁLAGA', 'ES329003', "29"],
                'CONF.HIDRO.JÚCAR-EBB': ['ES130001_1', 'GASTOS DANA  CONFEDERACION HIDROGRAFICA DEL JÚCAR, O.A. DEL MITECO', 'ES130001', "46"],
                'ZURGENA-JOG': ['ES304023_1', 'GASTOS DANA AYUNTAMIENTO DE ZURGENA', 'ES304023', "04"],
                'VIVEROS-JOG': ['ES302030_1', 'GASTOS DANA AYUNTAMIENTO DE VIVEROS', 'ES302030', "02"],
                'VALLADA-JOG': ['ES312038_1', 'GASTOS DANA AYUNTAMIENTO DE VALLADA', 'ES312038',"46"],
                'ULEA-JOG': ['ES330029_1', 'GASTOS DANA AYUNTAMIENTO DE ULEA', 'ES330029', "30"],
                'TOTANA-JOG': ['ES330032_1', 'GASTOS DANA AYUNTAMIENTO DE TOTANA', 'ES330032', "30"],
                'TORRES DE COTILLAS-MAC': ['ES330008_1', 'GASTOS DANA AYUNTAMIENTO DE TORRES DE COTILLAS, LAS', 'ES330008', "30"],
                'TABERNO - JOG': ['ES304030_1', 'GASTOS DANA AYUNTAMIENTO DE TABERNO', 'ES304030'],
                'SERÓN-JOG': ['ES304022_1', 'GASTOS DANA AYUNTAMIENTO DE SERÓN', 'ES304022', "04"],
                'SANTOMERA-JOG': ['ES330014_1', 'GASTOS DANA AYUNTAMIENTO DE SANTOMERA', 'ES330014', "30"],
                'SAN JAVIER-JOG': ['ES330001_1', 'GASTOS DANA AYUNTAMIENTO DE SAN JAVIER', 'ES330001', "30"],
                'SAN FULGENCIO-MAC': ['ES302057_1', 'GASTOS DANA AYUNTAMIENTO DE SAN FULGENCIO', 'ES302057', "03"],
                'PURCHENA-JOG': ['ES304019_1', 'GASTOS DANA AYUNTAMIENTO DE PURCHENA', 'ES304019', "04"],
                'PULPÍ-JOG': ['ES304016_1', 'GASTOS DANA AYUNTAMIENTO DE PULPÍ', 'ES304016', "04"],
                'PUERTO LUMBRERAS-JOG': ['ES330033_1', 'GASTOS DANA AYUNTAMIENTO DE PUERTO LUMBRERAS', 'ES330033', "30"],
                'PINOS GENIL-MAC': ['ES318057_1', 'GASTOS DANA AYUNTAMIENTO DE PINOS GENIL', 'ES318057', "18"],
                'OTOS-JOG': ['ES346081_1', 'GASTOS DANA AYUNTAMIENTO DE OTOS', 'ES346081', "46"],
                'ORIHUELA-MAC': ['ES303003_1', 'GASTOS DANA AYUNTAMIENTO DE ORIHUELA', 'ES303003', "03"],
                'ONTINYENT-MAC': ['ES346007_1', 'GASTOS DANA AYUNTAMIENTO DE ONTINYENT', 'ES346007', "46"],
                'OLULA DEL RÍO-JOG': ['ES304027_1', 'GASTOS DANA AYUNTAMIENTO DE OLULA DEL RÍO', 'ES304027', "04"],
                'L-OLLERIA-JOG': ['ES346056_1', "GASTOS DANA AYUNTAMIENTO DE OLLERIA, L'", 'ES346056', "46"],
                'OJÓS-JOG': ['ES330026_1', 'GASTOS DANA AYUNTAMIENTO DE OJÓS', 'ES330026', "30"],
                #'NERPIO-JOG': ['ES302023_1', 'GASTOS DANA AYUNTAMIENTO DE NERPIO', 'ES302023', "02"],
                'MOLINICOS-DGM': ['ES302018_1', 'GASTOS DANA AYUNTAMIENTO DE MOLINICOS', 'ES302018', "02"],
                'MOLINA DEL SEGURA-MAC': ['ES330009_1', 'GASTOS DANA AYUNTAMIENTO DE MOLINA DE SEGURA', 'ES330009', "30"],
                'LORQUÍ-JOG': ['ES330017_1', 'GASTOS DANA AYUNTAMIENTO DE LORQUÍ', 'ES330017', "30"],
                'LOJA - JOG': ['ES318055_1', 'GASTOS DANA AYUNTAMIENTO DE LOJA', 'ES318055', "18"],
                'JACARILA-JOG': ['ES303052_1', 'GASTOS DANA AYUNTAMIENTO DE JACARILLA', 'ES303052', "03"],
                'GRANADA-JOG': ['ES318003_1', 'GASTOS DANA AYUNTAMIENTO DE GRANADA', 'ES318003', "18"],
                'GALLARDOS-JOG': ['ES304026_1', 'GASTOS DANA AYUNTAMIENTO DE GALLARDOS, LOS', 'ES304026', "04"],
                'DENIA-MAC': ['ES303026_1', 'GASTOS DANA AYUNTAMIENTO DE DÉNIA', 'ES303026', "03"],
                'CREVILLENT-MAC': ['ES303047_1', 'GASTOS DANA AYUNTAMIENTO DE CREVILLENT', 'ES303047', "03"],
                'CIEZA-JOG': ['ES330002_1', 'GASTOS DANA AYUNTAMIENTO DE CIEZA', 'ES330002', "30"],
                'BLANCA-JOG': ['ES330015_1', 'GASTOS DANA AYUNTAMIENTO DE BLANCA', 'ES330015', "30"],
                'BENIEL-JOG': ['ES330013_1', 'GASTOS DANA AYUNTAMIENTO DE BENIEL', 'ES330013', "30"],
                'BAZA-MAC': ['ES318001_1', 'GASTOS DANA AYUNTAMIENTO DE BAZA', 'ES318001', "18"],
                'ARCHENA-MAC': ['ES330005_1', 'GASTOS DANA AYUNTAMIENTO DE ARCHENA', 'ES330005', "30"],
                'ARBOLEAS-MAC': ['ES304025_1','GASTOS DANA AYUNTAMIENTO DE ARBOLEAS','ES304025', "04"],
                'ALMORADÍ-DGM': ['ES303017_1','GASTOS DANA AYUNTAMIENTO DE ALMORADÍ','ES303017', "46"],
                'ALHAURÍN DE LA TORRE-MAC': ['ES329005_1','GASTOS DANA AYUNTAMIENTO DE ALHAURÍN DE LA TORRE','ES329005', "29"],
    
                'ALCÓNTAR-JOG': ['ES304029_1','GASTOS DANA AYUNTAMIENTO DE ALCÓNTAR', 'ES304029', "04"],
                'ALBAIDA-MAC': ['ES346012_1', 'GASTOS DANA AYUNTAMIENTO DE ALBAIDA', 'ES346012', "46"],
                'AGULLENT-JOG': ['ES303050_1','GASTOS DANA AYUNTAMIENTO DE AGULLENT','ES303050', "46"],
                'ABANILLA-JOG': ['ES330024_1', 'GASTOS DANA AYUNTAMIENTO DE ABANILLA', 'ES330024', "30"],
                'AP CARTAGENA-MAC': ['ES117025_1', 'GASTOS DANA AUTORIDAD PORTUARIA CARTAGENA (MITMA)', 'ES117025', "30"],}

# %%
fichero_padre = "P:/Regulacion/49 Encargo MinHac 20-22/08 FSUE-DANA/02 Archivos de trabajo/BENEFICIARIOS FSUE DANA"
#fichero_padre = "C:/Users/bllanos/Desktop/Simulacion_dana"

# %%
os.listdir(fichero_padre)
# Out:
# ['01-EXceles',
#  'ABANILLA-JOG',
#  'ABARÁN-EBB',
#  'AENA-MAC-EBB',
#  'AGULLENT-JOG',
#  'ALBAIDA-MAC',
#  'ALBATERA-JOG',
#  'ALCAUCÍN-RENUNCIA',
#  'ALCÁZARES-MAC',
#  'ALCÓNTAR-JOG',
#  'ALGORFA-JOG',
#  'ALHAURÍN DE LA TORRE-MAC',
#  'ALMANSA-EBB',
#  'ALMERÍA-DGM',
#  'ALMORADÍ-DGM',
#  'ALQUERIA DE AZNAR-EBB',
#  'AP CARTAGENA-MAC',
#  'ARBOLEAS-MAC',
#  'ARCHENA-MAC',
#  'ARCHIDONA-EBB',
#  'BAZA-MAC',
#  'BENIEL-JOG',
#  'BIENSERVIDA-RENUNCIA',
#  'BIGASTRO-JOG',
#  'BLANCA-JOG',
#  'CAMPOS DEL RÍO - DGM',
#  'CARTAGENA-JOG',
#  'CASTILLA LA MANCHA- DGM',
#  'CASTRIL-DGM',
#  'CHAUCHINA-JOG',
#  'CIEZA-JOG',
#  'COCENTAINA-EBB',
#  'CONF.HIDRO.JÚCAR-EBB',
#  'CONF.HIDRO.SEGURA-MAC',
#  'COX-RENUNCIA',
#  'COÍN-JOG',
#  'CREVILLENT-MAC',
#  'CUEVAS DEL CAMPO-JOG',
#  'CULLAR-RENUNCIA-JOG',
#  'data_blp',
#  'DAYA NUEVA-DGM',
#  'DENIA-MAC',
#  'DGCMTM y AU-JOG',
#  'DP ALBACETE-DGM',
#  'DP ALMERÍA- DGM',
#  'DP GRANADA-JOG',
#  'DP MÁLAGA-JOG',
#  'FUENTE-ÁLAMO-JOG',
#  'GALLARDOS-JOG',
#  'GENERALITAT VALENCIANA-EBB',
#  'GRANADA-JOG',
#  'HELLÍN-DGM',
#  'HOYA GONZALO-JOG',
#  'HUESCAR-DGM',
#  'JACARILA-JOG',
#  'JUNTA ANDALUCÍA-JOG',
#  'L-OLLERIA-JOG',
#  'L-OLLERIA-JRL',
#  'Listas Contratos',
#  'LOJA - JOG',
#  'LORCA-DGM',
#  'LORCHA-DGM',
#  'LORQUÍ-JOG',
#  'MINISTERIO DEFENSA-EBB',
#  'MOLINA DEL SEGURA-MAC',
#  'MOLINICOS-DGM',
#  'MONACHIL- DGM',
#  'NERPIO-JOG',
#  'NIJAR-MAC',
#  'NOVELDA-EBB',
#  'OJÓS-JOG',
#  'OLULA DEL RÍO-JOG',
#  'ONTINYENT-MAC',
#  'ONTUR-DGM',
#  'ORIHUELA-MAC',
#  'OTOS-JOG',
#  'PARCENT-EBB',
#  'PILAR DE LA HORADADA EBB',
#  'PINOS GENIL-MAC',
#  'PUEBLA DE DON FADRIQUE-EBB',
#  'PUERTO LUMBRERAS-JOG',
#  'PULPÍ-JOG',
#  'PURCHENA-JOG',
#  'REDOVÁN-DGM',
#  'REGIÓN DE MURCIA-DGM',
#  'RENFE-MAC',
#  'RINCÓN DE LA VICTORIA-DGM',
#  'RIOJA-JOG',
#  'SAN FULGENCIO-MAC',
#  'SAN JAVIER-JOG',
#  'SANTOMERA-JOG',
#  'SERÓN-JOG',
#  'TABERNO - JOG',
#  'TORRE PACHECO-DGM',
#  'TORRES DE COTILLAS-MAC',
#  'TOTANA-JOG',
#  'TÍJOLA-DGM',
#  'ULEA-JOG',
#  'UNIÓN-DGM',
#  'URRACAL-DGM',
#  'VALLADA-JOG',
#  'VILLANUEVA DEL RIO SEGURA-DGM',
#  'VIVEROS-JOG',
#  'VÉLEZ MÁLAGA-DGM',
#  'ZURGENA-JOG']

# %%
def ayuntamientos_con_el_fichero(aytsdic):
    aytos_sin_fichero = {}
    for k,v in aytsdic.items():
        if "Justificacion_FSUE-DANA.xlsx" not in os.listdir(os.path.join(fichero_padre,k)):
            aytos_sin_fichero.update({k: os.listdir(os.path.join(fichero_padre,k))[4:]})
    return aytos_sin_fichero

# %%
sin_fichero = ayuntamientos_con_el_fichero(ayuntamientos)

# %%
sin_fichero, len(sin_fichero)
# Out:
# ({}, 0)

# %%
def dateconverter(df):
    for column in df.columns:
        if isinstance(column, str):
            if column.startswith("Fecha"):
                df[f"{column}"] = pd.to_datetime(df[f"{column}"]).dt.strftime("%d/%m/%Y")
    return df

# %%
def get_df_facturas(filepath):
    df = pd.read_excel(filepath, sheet_name= "2. DATOS BÁSICOS FACTURAS")
    df.dropna(thresh=6,inplace=True)
    df.columns = df.iloc[0]
    df.drop(df.index[0],inplace=True)
    df = df[df.elegible != "NO"]
    df = df[df.elegible != "N"]
    df.reset_index(inplace=True,drop=True)
    df = dateconverter(df)
    return df

# %%
def operation_getter(ayuntamiento):
    return ayuntamientos[ayuntamiento][0]

# %%
def benefieciario_getter(ayuntamiento):
    return ayuntamientos[ayuntamiento][2]

# %%
def get_subtipologia(concepto):
    if concepto.startswith("a)"):
        return "31a"
    elif concepto.startswith("b)"):
        return "31b"
    elif concepto.startswith("c)"):
        return "31c"
    elif concepto.startswith("d)"):
        return "31d"
    else:
        print(concepto)
        raise ValueError ( "el concepto de gasto esta mal redactado")

# %%
def get_contract(ayto,contractcode):
    contrats = pd.read_csv(os.path.join(fichero_padre,"data_blp/correspcontratos.csv"), sep = ";", names = ["ayto", "contrato", "codigo"], encoding="latin1")
    contrats.contrato = contrats.contrato.apply(lambda x : str(x).replace("\n", ""))
    contrats = contrats[contrats.ayto == ayto]
    contrats = contrats[contrats.contrato == contractcode]
    display(contrats)
    if contrats.shape[0]!=1:
        print(contrats)
        print(ayto,"----",contractcode)
        #return False
    return contrats.iloc[0]['codigo']

# %%
'''
# %%time
for k,v in ayuntamientos.items():
    if k not in sin_fichero:
        print(k)
        df=get_df_facturas(os.path.join(fichero_padre,k,"Justificacion_FSUE-DANA.xlsx"))
        display(df)
        root_transacciones = ET.Element("transacciones")
        num_transaccion = 1
        for index, row in df.iterrows():
            #print(row)
            transaccion = ET.SubElement(root_transacciones,"transaccion")
            operativo = ET.SubElement(transaccion,"cod_poperativo")
            operativo.text = "SO-DANA"
            operacion = ET.SubElement(transaccion,"cod_operacion")
            operacion.text = operation_getter(k)
            codtransaccion = ET.SubElement(transaccion,"cod_transaccion")
            codtransaccion.text = f"{benefieciario_getter(k)}_{num_transaccion}"
            elemento = ET.SubElement(transaccion,"bloqueada")
            elemento.text = "N"
            elemento = ET.SubElement(transaccion,"tipo_transaccion")
            elemento.text = "B1"
            subtipo = ET.SubElement(transaccion,"subtipologia")
            subtipo.text = get_subtipologia(row["Concepto de gasto (seleccionar de la lista)"])
            elemento = ET.SubElement(transaccion,"transaccion_hibrida")
            elemento.text = "N"
            destinatario = ET.SubElement(transaccion,"destinatario")
            destinatario.text = benefieciario_getter(k)
            gato_total = ET.SubElement(transaccion,"gasto_total")
            gato_total.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            gato_total_sub = ET.SubElement(transaccion,"gasto_total_subvencionable")
            gato_total_sub.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            gato_pub_sub = ET.SubElement(transaccion,"gasto_publico_subvencionable")
            gato_pub_sub.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            fecha = ET.SubElement(transaccion,"f_pago_efectivo")
            fecha.text = row["Fecha pago factura"]
            #elemento = ET.SubElement(transaccion,"f_pago_efectivo_2")
            #elemento.text = "0"
            elemento = ET.SubElement(transaccion,"gastos_compra_terrenos")
            elemento.text = "0"
            elemento = ET.SubElement(transaccion,"importe_iva_no_recuperable")
            elemento.text = "0"
            if str(row["Código Expte de Contratación/Encargo"]) != "nan":
                contratacion_pub = ET.SubElement(transaccion,"contratacion_publica")
                contratacion_pub.text = "S"
            concepto = ET.SubElement(transaccion,"concepto_gasto")
            concepto.text = row["Descriptivo"][0:250]
            factura = ET.SubElement(transaccion,"importe_factura")
            factura.text = str(row["Importe total de factura (con IVA)"])
            emisor = ET.SubElement(transaccion,"nif_emisor")
            emisor.text = str(row["NIF Proveedor"])
            numfact = ET.SubElement(transaccion,"num_factura")
            numfact.text = str(row["Nº factura"])
            operacioncont = ET.SubElement(transaccion,"num_ope_contable")
            if str(row["Número operación contable"]) == "nan":
                operacioncont.text = "0"
            else:
                operacioncont.text = str(row["Número operación contable"])
            ffactura = ET.SubElement(transaccion,"f_factura")
            ffactura.text = row["Fecha factura"]
            #gastos_sub_comision = ET.SubElement(transaccion,"gastos_subv_comision")
            #gastos_sub_comision.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            #gasto_publico_verif = ET.SubElement(transaccion,"gasto_publico_verif")
            #gasto_publico_verif.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            if str(row["Código Expte de Contratación/Encargo"]) != "nan":
                #contratacion_pub = ET.SubElement(transaccion,"contratacion_publica")
                #contratacion_pub.text = "S"
                transacciones_cont = ET.SubElement(transaccion,"transacciones_contratos")
                transaccion_cont = ET.SubElement(transacciones_cont,"transaccion_contratos")
                cod_cont = ET.SubElement(transaccion_cont,"cod_contrato")
                cod_cont.text = get_contract(k,str(row["Código Expte de Contratación/Encargo"]))
                version_cont = ET.SubElement(transaccion_cont,"version_cont")
                version_cont.text = "1"
                gasto_abonado = ET.SubElement(transaccion_cont,"gasto_abonado")
                gasto_abonado.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
                
            num_transaccion += 1
        tree = ET.ElementTree(root_transacciones)
        tree.write(os.path.join(fichero_padre,"data_blp",k.replace("-","_")+"_transacciones.xml"), encoding = "UTF-8", xml_declaration=True)
        '''
# Out:
# '\n%%time\nfor k,v in ayuntamientos.items():\n    if k not in sin_fichero:\n        print(k)\n        df=get_df_facturas(os.path.join(fichero_padre,k,"Justificacion_FSUE-DANA.xlsx"))\n        display(df)\n        root_transacciones = ET.Element("transacciones")\n        num_transaccion = 1\n        for index, row in df.iterrows():\n            #print(row)\n            transaccion = ET.SubElement(root_transacciones,"transaccion")\n            operativo = ET.SubElement(transaccion,"cod_poperativo")\n            operativo.text = "SO-DANA"\n            operacion = ET.SubElement(transaccion,"cod_operacion")\n            operacion.text = operation_getter(k)\n            codtransaccion = ET.SubElement(transaccion,"cod_transaccion")\n            codtransaccion.text = f"{benefieciario_getter(k)}_{num_transaccion}"\n            elemento = ET.SubElement(transaccion,"bloqueada")\n            elemento.text = "N"\n            elemento = ET.SubElement(transaccion,"tipo_transaccion")\n            elemento.text = "B1"\n            subtipo = ET.SubElement(transaccion,"subtipologia")\n            subtipo.text = get_subtipologia(row["Concepto de gasto (seleccionar de la lista)"])\n            elemento = ET.SubElement(transaccion,"transaccion_hibrida")\n            elemento.text = "N"\n            destinatario = ET.SubElement(transaccion,"destinatario")\n            destinatario.text = benefieciario_getter(k)\n            gato_total = ET.SubElement(transaccion,"gasto_total")\n            gato_total.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])\n            gato_total_sub = ET.SubElement(transaccion,"gasto_total_subvencionable")\n            gato_total_sub.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])\n            gato_pub_sub = ET.SubElement(transaccion,"gasto_publico_subvencionable")\n            gato_pub_sub.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])\n            fecha = ET.SubElement(transaccion,"f_pago_efectivo")\n            fecha.text = row["Fecha pago factura"]\n            #elemento = ET.SubElement(transaccion,"f_pago_efectivo_2")\n            #elemento.text = "0"\n            elemento = ET.SubElement(transaccion,"gastos_compra_terrenos")\n            elemento.text = "0"\n            elemento = ET.SubElement(transaccion,"importe_iva_no_recuperable")\n            elemento.text = "0"\n            if str(row["Código Expte de Contratación/Encargo"]) != "nan":\n                contratacion_pub = ET.SubElement(transaccion,"contratacion_publica")\n                contratacion_pub.text = "S"\n            concepto = ET.SubElement(transaccion,"concepto_gasto")\n            concepto.text = row["Descriptivo"][0:250]\n            factura = ET.SubElement(transaccion,"importe_factura")\n            factura.text = str(row["Importe total de factura (con IVA)"])\n            emisor = ET.SubElement(transaccion,"nif_emisor")\n            emisor.text = str(row["NIF Proveedor"])\n            numfact = ET.SubElement(transaccion,"num_factura")\n            numfact.text = str(row["Nº factura"])\n            operacioncont = ET.SubElement(transaccion,"num_ope_contable")\n            if str(row["Número operación contable"]) == "nan":\n                operacioncont.text = "0"\n            else:\n                operacioncont.text = str(row["Número operación contable"])\n            ffactura = ET.SubElement(transaccion,"f_factura")\n            ffactura.text = row["Fecha factura"]\n            #gastos_sub_comision = ET.SubElement(transaccion,"gastos_subv_comision")\n            #gastos_sub_comision.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])\n            #gasto_publico_verif = ET.SubElement(transaccion,"gasto_publico_verif")\n            #gasto_publico_verif.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])\n            if str(row["Código Expte de Contratación/Encarg ...

# %%
# %%time
root_transacciones = ET.Element("transacciones")
for k,v in ayuntamientos.items():
    if k not in sin_fichero:
        print(k)
        df=get_df_facturas(os.path.join(fichero_padre,k,"Justificacion_FSUE-DANA.xlsx"))
        display(df)
        num_transaccion = 1
        for index, row in df.iterrows():
            #print(row)
            transaccion = ET.SubElement(root_transacciones,"transaccion")
            operativo = ET.SubElement(transaccion,"cod_poperativo")
            operativo.text = "SO-DANA"
            operacion = ET.SubElement(transaccion,"cod_operacion")
            operacion.text = operation_getter(k)
            codtransaccion = ET.SubElement(transaccion,"cod_transaccion")
            codtransaccion.text = f"{benefieciario_getter(k)}_{num_transaccion}"
            elemento = ET.SubElement(transaccion,"bloqueada")
            elemento.text = "N"
            elemento = ET.SubElement(transaccion,"tipo_transaccion")
            elemento.text = "B1"
            subtipo = ET.SubElement(transaccion,"subtipologia")
            subtipo.text = get_subtipologia(row["Concepto de gasto (seleccionar de la lista)"])
            elemento = ET.SubElement(transaccion,"transaccion_hibrida")
            elemento.text = "N"
            destinatario = ET.SubElement(transaccion,"destinatario")
            destinatario.text = benefieciario_getter(k)
            gato_total = ET.SubElement(transaccion,"gasto_total")
            gato_total.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            gato_total_sub = ET.SubElement(transaccion,"gasto_total_subvencionable")
            gato_total_sub.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            gato_pub_sub = ET.SubElement(transaccion,"gasto_publico_subvencionable")
            gato_pub_sub.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            fecha = ET.SubElement(transaccion,"f_pago_efectivo")
            fecha.text = row["Fecha pago factura"]
            #elemento = ET.SubElement(transaccion,"f_pago_efectivo_2")
            #elemento.text = "0"
            elemento = ET.SubElement(transaccion,"gastos_compra_terrenos")
            elemento.text = "0"
            elemento = ET.SubElement(transaccion,"importe_iva_no_recuperable")
            elemento.text = "0"
            if str(row["Código Expte de Contratación/Encargo"]) != "nan":
                contratacion_pub = ET.SubElement(transaccion,"contratacion_publica")
                contratacion_pub.text = "S"
            concepto = ET.SubElement(transaccion,"concepto_gasto")
            concepto.text = row["Descriptivo"][0:250]
            factura = ET.SubElement(transaccion,"importe_factura")
            factura.text = str(row["Importe total de factura (con IVA)"]).replace(",",".").strip()
            emisor = ET.SubElement(transaccion,"nif_emisor")
            emisor.text = str(row["NIF Proveedor"])
            numfact = ET.SubElement(transaccion,"num_factura")
            numfact.text = str(row["Nº factura"])[-25:]
            operacioncont = ET.SubElement(transaccion,"num_ope_contable")
            if str(row["Número operación contable"]) == "nan":
                operacioncont.text = "0"
            else:
                operacioncont.text = str(row["Número operación contable"])
            ffactura = ET.SubElement(transaccion,"f_factura")
            ffactura.text = row["Fecha factura"]
            #gastos_sub_comision = ET.SubElement(transaccion,"gastoshttp://localhost:8888/notebooks/Desktop/project1/DANA/Transacciones.ipynb#_subv_comision")
            #gastos_sub_comision.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            #gasto_publico_verif = ET.SubElement(transaccion,"gasto_publico_verif")
            #gasto_publico_verif.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
            if str(row["Código Expte de Contratación/Encargo"]) != "nan":
                #contratacion_pub = ET.SubElement(transaccion,"contratacion_publica")
                #contratacion_pub.text = "S"
                transacciones_cont = ET.SubElement(transaccion,"transacciones_contratos")
                transaccion_cont = ET.SubElement(transacciones_cont,"transaccion_contratos")
                cod_cont = ET.SubElement(transaccion_cont,"cod_contrato")
                cod_cont.text = get_contract(k,str(row["Código Expte de Contratación/Encargo"]))
                version_cont = ET.SubElement(transaccion_cont,"version_cont")
                version_cont.text = "1"
                gasto_abonado = ET.SubElement(transaccion_cont,"gasto_abonado")
                gasto_abonado.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
                
            num_transaccion += 1
tree = ET.ElementTree(root_transacciones)
tree.write(os.path.join(fichero_padre,"data_blp/transacciones.xml"), encoding = "UTF-8", xml_declaration=True)
# Out:
# NIJAR-MAC
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo    Nº factura  \
# 0                           11389/2019  20J8L6000003
# 1                           11389/2019  20J8L6000044
# 2                           11389/2019  20J8L6000067
# 3                           11389/2019  20J8L6000087
# 4                           11389/2019  20J8L6000141
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                          124442.89                           113129.9
# 1                          243186.05                      221078.227273
# 2                          240065.39                      218241.263636
# 3                          196255.14                      178413.763636
# 4                          227539.04                      206853.672727
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                          124442.89
# 1                                          243186.05
# 2                                          240065.39
# 3                                          196255.14
# 4                                           28791.31
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           113129.9
# 1                                      221078.227273
# 2                                      218241.263636
# 3                                      178413.763636
# 4                                       26173.918182
#
# 7 Fecha pago factura                                        Descriptivo  \
# 0         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
# 1         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
# 2         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
# 3         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
# 4         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  d) Limpieza de las zonas siniestradas, incluid...
# 1  d) Limpieza de las zonas siniestradas, incluid...
# 2  d) Limpieza de las zonas siniestradas, incluid...
# 3  d) Limpieza de las zonas siniestradas, incluid...
# 4  d) Limpieza de las zonas siniestradas, incluid...
#
# 7                        Proveedor NIF Proveedor Número operación contable  \
# 0  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006284
# 1  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006285
# 2  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006286
# 3  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006287
# 4  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006288
#
# 7 Fecha factura Observaciones elegible
# 0    28/01/2020           NaN        S
# 1    03/12/2020           NaN        S
# 2    31/03/2020           NaN        S
# 3    30/04/2020           NaN        S
# 4    30/06/2020           NaN        S
# Empty DataFrame
# Columns: [ayto, contrato, codigo]
# Index: []
# Empty DataFrame
# Columns: [ayto, contrato, codigo]
# Index: []
# NIJAR-MAC ---- 11389/2019
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-20-0b0149bc2331> in get_contract(ayto, contractcode)
#       9         print(ayto,"----",contractcode)
#      10         #return False
# ---> 11     return contrats.iloc[0]['codigo']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
sin_errores = 0
for k,v in ayuntamientos.items():
    if k not in sin_fichero:
            print(k)
            df=get_df_facturas(os.path.join(fichero_padre,k,"Justificacion_FSUE-DANA.xlsx"))
            display(df)
            root_transacciones = ET.Element("transacciones")
            num_transaccion = 1
            for index, row in df.iterrows():
                transaccion = ET.SubElement(root_transacciones,"transaccion")
                operativo = ET.SubElement(transaccion,"cod_poperativo")
                operativo.text = "SO-DANA"
                operacion = ET.SubElement(transaccion,"cod_operacion")
                operacion.text = operation_getter(k)
                codtransaccion = ET.SubElement(transaccion,"cod_transaccion")
                codtransaccion.text = f"{benefieciario_getter(k)}_{num_transaccion}"
                elemento = ET.SubElement(transaccion,"bloqueada")
                elemento.text = "N"
                elemento = ET.SubElement(transaccion,"tipo_transaccion")
                elemento.text = "B1"
                subtipo = ET.SubElement(transaccion,"subtipologia")
                subtipo.text = get_subtipologia(row["Concepto de gasto (seleccionar de la lista)"])
                elemento = ET.SubElement(transaccion,"transaccion_hibrida")
                elemento.text = "N"
                destinatario = ET.SubElement(transaccion,"destinatario")
                destinatario.text = benefieciario_getter(k)
                gato_total = ET.SubElement(transaccion,"gasto_total")
                gato_total.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
                gato_total_sub = ET.SubElement(transaccion,"gasto_total_subvencionable")
                gato_total_sub.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
                gato_pub_sub = ET.SubElement(transaccion,"gasto_publico_subvencionable")
                gato_pub_sub.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
                fecha = ET.SubElement(transaccion,"f_pago_efectivo")
                fecha.text = row["Fecha pago factura"]
                #elemento = ET.SubElement(transaccion,"f_pago_efectivo_2")
                #elemento.text = "0"
                elemento = ET.SubElement(transaccion,"gastos_compra_terrenos")
                elemento.text = "0"
                elemento = ET.SubElement(transaccion,"importe_iva_no_recuperable")
                elemento.text = "0"
                concepto = ET.SubElement(transaccion,"concepto_gasto")
                concepto.text = row["Descriptivo"][0:250]
                factura = ET.SubElement(transaccion,"importe_factura")
                factura.text = str(row["Importe total de factura (con IVA)"])
                emisor = ET.SubElement(transaccion,"nif_emisor")
                emisor.text = str(row["NIF Proveedor"])
                numfact = ET.SubElement(transaccion,"num_factura")
                numfact.text = str(row["Nº factura"])
                operacioncont = ET.SubElement(transaccion,"num_ope_contable")
                if str(row["Número operación contable"]) == "nan":
                    operacioncont.text = "0"
                else:
                    operacioncont.text = str(row["Número operación contable"])
                ffactura = ET.SubElement(transaccion,"f_factura")
                ffactura.text = row["Fecha factura"]
                #gastos_sub_comision = ET.SubElement(transaccion,"gastos_subv_comision")
                #gastos_sub_comision.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
                #gasto_publico_verif = ET.SubElement(transaccion,"gasto_publico_verif")
                #gasto_publico_verif.text = str(row["Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**"])
                num_transaccion += 1
            tree = ET.ElementTree(root_transacciones)
            tree.write(os.path.join(fichero_padre,"data_blp",k.replace("-","_")+"_transacciones.xml"), encoding = "UTF-8", xml_declaration=True)
            sin_errores +=1
# Out:
# NIJAR-MAC
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo    Nº factura  \
# 0                           11389/2019  20J8L6000003
# 1                           11389/2019  20J8L6000044
# 2                           11389/2019  20J8L6000067
# 3                           11389/2019  20J8L6000087
# 4                           11389/2019  20J8L6000141
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                          124442.89                           113129.9
# 1                          243186.05                      221078.227273
# 2                          240065.39                      218241.263636
# 3                          196255.14                      178413.763636
# 4                          227539.04                      206853.672727
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                          124442.89
# 1                                          243186.05
# 2                                          240065.39
# 3                                          196255.14
# 4                                           28791.31
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           113129.9
# 1                                      221078.227273
# 2                                      218241.263636
# 3                                      178413.763636
# 4                                       26173.918182
#
# 7 Fecha pago factura                                        Descriptivo  \
# 0         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
# 1         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
# 2         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
# 3         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
# 4         18/06/2021  CONTRATO MAYOR DE SERVICIOS PARA LA GESTION DE...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  d) Limpieza de las zonas siniestradas, incluid...
# 1  d) Limpieza de las zonas siniestradas, incluid...
# 2  d) Limpieza de las zonas siniestradas, incluid...
# 3  d) Limpieza de las zonas siniestradas, incluid...
# 4  d) Limpieza de las zonas siniestradas, incluid...
#
# 7                        Proveedor NIF Proveedor Número operación contable  \
# 0  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006284
# 1  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006285
# 2  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006286
# 3  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006287
# 4  CESPA GESTION DE RESIDUOS, S.A.     A59202861              220210006288
#
# 7 Fecha factura Observaciones elegible
# 0    28/01/2020           NaN        S
# 1    03/12/2020           NaN        S
# 2    31/03/2020           NaN        S
# 3    30/04/2020           NaN        S
# 4    30/06/2020           NaN        S
# ALGORFA-JOG
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                          22019003518     00 169
# 1                          22020000538      00 46
# 2                          22020003412        003
# 3                          22020003412       0047
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           17732.09                           14654.62
# 1                            1433.73                             1184.9
# 2                               3872                               3200
# 3                            1360.23                            1124.16
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           17732.09
# 1                                            1433.73
# 2                                               3872
# 3                                             971.24
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           14654.62
# 1                                             1184.9
# 2                                               3200
# 3                                             802.68
#
# 7 Fecha pago factura                                        Descriptivo  \
# 0         25/02/2020  CÉSPED, PIEDRA MAMPOSTERIA, M3 DE HORMIGÓN, SA...
# 1         15/05/2020  RETIRADA DE TELAS VIEJAS Y BORDILLO A VERTEDER...
# 2         08/03/2021  REDACCION DE PROYECTO DE LAS OBRAS DE REPARACI...
# 3         04/08/2021  DIRECCION DE OBRA Y C.S.S. DE LAS OBRAS DE REP...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
# 1  a) Restablecimiento del funcionamiento de las ...
# 2  a) Restablecimiento del funcionamiento de las ...
# 3  a) Restablecimiento del funcionamiento de las ...
#
# 7                     Proveedor NIF Proveedor Número operación contable  \
# 0                Preserbol S.L.     B54629217              220200000821
# 1                Preserbol S.L.     B54629217              220200002634
# 2  Cauce Proyectos y Obras S.A.     A03378668              220210001027
# 3  Cauce Proyectos y Obras S.A.     A03378668              220210004414
#
# 7 Fecha factura                                      Observaciones elegible
# 0    17/11/2019  El Nº de operación contable corresponde a la f...      NaN
# 1    31/03/2020  El Nº de operación contable corresponde a la f...      NaN
# 2    05/01/2021  El Nº de operación contable corresponde a la f...      NaN
# 3    24/05/2021  El Nº de operación contable corresponde a la f...      NaN
# TÍJOLA-DGM
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0            2020/092412/006-030/00001        154
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           41637.02                           34410.76
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           21632.93
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           17093.01
#
# 7 Fecha pago factura                                 Descriptivo  \
# 0         08/07/2021  Obra emergencia entrada oeste al municipio
#
# 7        Concepto de gasto (seleccionar de la lista)   Proveedor  \
# 0  a) Restablecimiento del funcionamiento de las ...  AGUAEMA SL
#
# 7 NIF Proveedor Número operación contable Fecha factura Observaciones elegible
# 0     B04038204              220210005306    02/07/2021           NaN      NaN
# HUESCAR-DGM
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo      Nº factura  \
# 0                                  NaN           FE 28
# 1                                  NaN        2019-750
# 2                                  NaN  1 J2019/000151
# 3                                  NaN  1 J2019/000152
# 4                                  NaN          7/2020
# 5                                  NaN           85/19
# 6                                  NaN        171/2019
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                             1161.6                                960
# 1                             297.24                             245.65
# 2                              358.4                              296.2
# 3                             726.48                              600.4
# 4                             465.85                                385
# 5                             457.38                                378
# 6                                250                             206.61
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                             1161.6
# 1                                             297.24
# 2                                              358.4
# 3                                             726.48
# 4                                              12.69
# 5                                             457.38
# 6                                                250
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                                960
# 1                                             245.65
# 2                                              296.2
# 3                                              600.4
# 4                                              10.49
# 5                                                378
# 6                                             206.61
#
# 7 Fecha pago factura                                        Descriptivo  \
# 0         07/01/2020         TRABAJOS C/ MAYOR. REPARACIONES DAÑOS DANA
# 1         26/12/2019          SUMINISTRO MATERIAL REPARACIONES C/ MAYOR
# 2         26/12/2019  SUMINISTRO MATERIAL REPARACIONES COLEGIO PRINC...
# 3         26/12/2019          SUMINISTRO MATERIAL REPARACIONES C/ MAYOR
# 4         21/05/2020             REPARACIONES MOLINO DEL PASO-CUCURIGIL
# 5         26/12/2019  SUMINISTRO HORMIGON PARA REPARACIONES COLEGIO ...
# 6         26/12/2019                       REPARACIONES MOLINO DEL PASO
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
# 1  a) Restablecimiento del funcionamiento de las ...
# 2  a) Restablecimiento del funcionamiento de las ...
# 3  a) Restablecimiento del funcionamiento de las ...
# 4  a) Restablecimiento del funcionamiento de las ...
# 5  a) Restablecimiento del funcionamiento de las ...
# 6  a) Restablecimiento del funcionamiento de las ...
#
# 7                                   Proveedor NIF Proveedor  \
# 0              CONSTRUCCIONES OSCENSES S.C.A.     F18021469
# 1                       MARMOLES HUESCAR S.L.     B18411710
# 2  DISTRIBUIDORA DE CONSTRUCCION HUESCAR S.L.     B18230920
# 3  DISTRIBUIDORA DE CONSTRUCCION HUESCAR S.L.     B18230920
# 4               INSTALACIONES CONTINENTAL S.L     B72211451
# 5                     HORMIGONES HUESCAR S.L.     B18482786
# 6           AGRUPACION DE SERVICIOS 2009 S.L.     B18923748
#
# 7 Número operación contable Fecha factura  \
# 0              220190010939    23/09/2019
# 1              220190010944    25/09/2019
# 2              220190010941    30/09/2019
# 3              220190010949    30/09/2019
# 4              220200003147    10/05/2020
# 5              220190010940    11/11/2019
# 6              220190010942    26/09/2019
#
# 7                                      Observaciones elegible
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4  ESTA FACTURA NO FUE PRESENTADA POR EL PROVEEDO...      NaN
# 5                                                NaN      NaN
# 6                                                NaN      NaN
# RIOJA-JOG
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                                  NaN    2020-11
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                               2904                               2400
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                               2904
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                               2400
#
# 7 Fecha pago factura                       Descriptivo  \
# 0         01/07/2020  TRABAJOS ACONDICIONAMIENTO TALUD
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  c) Aseguramiento de las infraestructuras de pr...
#
# 7                      Proveedor NIF Proveedor Número operación contable  \
# 0  JOSE ADOLFO CANILLAS MARTINEZ     34839184A              220200001213
#
# 7 Fecha factura Observaciones elegible
# 0    18/02/2020           NaN      NaN
# CONF.HIDRO.SEGURA-MAC
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7  Código Expte de Contratación/Encargo      Nº factura  \
# 0                         19000519005/1       C00001/20
# 1                         19000519005/1       C00002/20
# 2                         19000519005/1       C00003/20
# 3                         19000519005/1       C00004/20
# 4                         19000519005/1       C00005/20
# 5                         19000519005/1       C00006/20
# 6                         19000519005/1       C00007/20
# 7                         19000519005/1       C00008/20
# 8                         19000519005/1       C00009/20
# 9                         19000519005/1       C00010/20
# 10                        19000519005/1       C00015/20
# 11                        19000519005/1       C00015/20
# 12                        19000519005/1       C00015/20
# 13                        19000519010/6  5400-OC20-0013
# 14                        19000519010/6  5400-OC20-0045
# 15                        19000519010/6  5400-OC20-0064
# 16                        19000519010/6  5400-OC20-0081
# 17                        19000519010/6  5400-OC20-0100
# 18                        19000519017/3             380
# 19                        19000519018/2       7FV20/010
# 20                        19000519018/2       7FV20/013
# 21                        19000519018/2       7FV20/016
# 22                        19000519018/2       7FV20/019
# 23                        19000519018/2       7FV20/023
# 24                        19000519018/2       7FV20/030
# 25                        19000519018/2       7FV20/033
#
# 7                          Proveedor NIF Proveedor Fecha factura  \
# 0         Acciona Construcción, S.A.     A81638108    29/02/2020
# 1         Acciona Construcción, S.A.     A81638108    29/02/2020
# 2         Acciona Construcción, S.A.     A81638108    20/04/2020
# 3         Acciona Construcción, S.A.     A81638108    18/05/2020
# 4         Acciona Construcción, S.A.     A81638108    15/06/2020
# 5         Acciona Construcción, S.A.     A81638108    13/07/2020
# 6         Acciona Construcción, S.A.     A81638108    14/09/2020
# 7         Acciona Construcción, S.A.     A81638108    14/09/2020
# 8         Acciona Construcción, S.A.     A81638108    28/10/2020
# 9         Acciona Construcción, S.A.     A81638108    11/11/2020
# 10        Acciona Construcción, S.A.     A81638108    04/12/2020
# 11        Acciona Construcción, S.A.     A81638108    15/03/2021
# 12        Acciona Construcción, S.A.     A81638108    15/03/2021
# 13  AGLOMERADOS LOS SERRANOS, S.A.U.     A03443801    31/01/2020
# 14  AGLOMERADOS LOS SERRANOS, S.A.U.     A03443801    25/03/2020
# 15  AGLOMERADOS LOS SERRANOS, S.A.U.     A03443801    06/04/2020
# 16  AGLOMERADOS LOS SERRANOS, S.A.U.     A03443801    18/05/2020
# 17  AGLOMERADOS LOS SERRANOS, S.A.U.     A03443801    10/07/2020
# 18   CONTRATAS EL SALVAORICO, S.L.U.     B53776530    08/11/2019
# 19    Obras y Servicios Públicos, SA     A28012359    13/02/2020
# 20    Obras y Servicios Públicos, SA     A28012359    12/03/2020
# 21    Obras y Servicios Públicos, SA     A28012359    23/04/2020
# 22    Obras y Servicios Públicos, SA     A28012359    11/05/2020
# 23    Obras y Servicios Públicos, SA     A28012359    17/06/2020
# 24    Obras y Servicios Públicos, SA     A28012359    14/07/2020
# 25    Obras y Servicios Públicos, SA     A28012359    14/08/2020
#
# 7  Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            64072.75                           52952.69
# 1                           255893.07                          211481.88
# 2                           211183.79                          174532.06
# 3                           176832.35                          146142.44
# 4                           129416.06                          106955.42
# 5                           221377.51                          182956.62
# 6                           141744.83                          117144.49
# 7                           214457.02                          177237.21
# 8                           262389.73                          216851.02
# 9                           360719.83                          298115.56
# 10                          213670.29                          176587.02
# 11                          280227.92                          231593.32
# 12                            7903.99                            6532.22
# 13                          378897.64                          313138.55
# 14                          489901.89                           404877.6
# 15                          322791.09                           266769.5
# 16                           263803.9                          218019.75
# 17                          276147.15                          228220.79
# 18                         1379619.92                         1140181.75
# 19                          222654.67                          184012.12
# 20                          439432.59                          363167.43
# 21                          632558.39                          522775.53
# 22                          290821.26                          240348.15
# 23                          218390.08                          180487.67
# 24                            5997.72                            4956.79
# 25                           24530.92                           20273.49
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            64072.75
# 1                                           255893.07
# 2                                           211183.79
# 3                                           176832.35
# 4                                           129416.06
# 5                                           221377.51
# 6                                           141744.83
# 7                                           214457.02
# 8                                           262389.73
# 9                                           360719.83
# 10                                          213670.29
# 11                                          280227.92
# 12                                            7903.99
# 13                                          378897.64
# 14                                          489901.89
# 15                                          322791.09
# 16                                           263803.9
# 17                                          276147.15
# 18                                         1379619.92
# 19                                          222654.67
# 20                                          439432.59
# 21                                          632558.39
# 22                                          290821.26
# 23                                          218390.08
# 24                                            5997.72
# 25                                           24530.92
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            52952.69
# 1                                           211481.88
# 2                                           174532.06
# 3                                           146142.44
# 4                                           106955.42
# 5                                           182956.62
# 6                                           117144.49
# 7                                           177237.21
# 8                                           216851.02
# 9                                           298115.56
# 10                                          176587.02
# 11                                          231593.32
# 12                                            6532.22
# 13                                          313138.55
# 14                                           404877.6
# 15                                           266769.5
# 16                                          218019.75
# 17                                          228220.79
# 18                                         1140181.75
# 19                                          184012.12
# 20                                          363167.43
# 21                                          522775.53
# 22                                          240348.15
# 23                                            4956.79
# 24                                           20273.49
# 25                                           20273.49
#
# 7  Fecha pago factura                                        Descriptivo  \
# 0          11/09/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 1          11/09/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 2          24/09/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 3          29/09/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 4          14/12/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 5          29/12/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 6          29/12/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 7          29/12/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 8          29/12/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 9          29/12/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 10         29/12/2020  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 11         09/04/2021  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 12         09/04/2021  REPARACIÓN DE COMPUERTAS DE ALIVIADERO Y SELLA...
# 13         21/07/2020  EMERGENCIA SEPT. 2019 MU C2. TRAMO OJOS-CONTRA...
# 14         05/08/2020  EMERGENCIA SEPT. 2019 MU C2. TRAMO OJOS-CONTRA...
# 15         12/08/2020  EMERGENCIA SEPT. 2019 MU C2. TRAMO OJOS-CONTRA...
# 16         29/09/2020  EMERGENCIA SEPT. 2019 MU C2. TRAMO OJOS-CONTRA...
# 17         29/12/2020  EMERGENCIA SEPT. 2019 MU C2. TRAMO OJOS-CONTRA...
# 18         21/01/2020  Taponamiento de dos roturas en los muros de en...
# 19         06/10/2020  OBRA DE EMERGENCIA DE LOS TRABAJOS DE REPARACI...
# 20         15/10/2020  OBRA DE EMERGENCIA DE LOS TRABAJOS DE REPARACI...
# 21         15/10/2020  OBRA DE EMERGENCIA DE LOS TRABAJOS DE REPARACI...
# 22         27/10/2020  OBRA DE EMERGENCIA DE LOS TRABAJOS DE REPARACI...
# 23         21/12/2020  OBRA DE EMERGENCIA DE LOS TRABAJOS DE REPARACI...
# 24         21/12/2020  OBRA DE EMERGENCIA DE LOS TRABAJOS DE REPARACI...
# 25         21/12/2020  OBRA DE EMERGENCIA DE LOS TRABAJOS DE REPARACI...
#
# 7         Concepto de gasto (seleccionar de la lista)  \
# 0   a) Restablecimiento del funcionamiento de las ...
# 1   a) Restablecimiento del funcionamiento de las ...
# 2   a) Restablecimiento del funcionamiento de las ...
# 3   a) Restablecimiento del funcionamiento de las ...
# 4   a) Restablecimiento del funcionamiento de las ...
# 5   a) Restablecimiento del funcionamiento de las ...
# 6   a) Restablecimiento del funcionamiento de las ...
# 7   a) Restablecimiento del funcionamiento de las ...
# 8   a) Restablecimiento del funcionamiento de las ...
# 9   a) Restablecimiento del funcionamiento de las ...
# 10  a) Restablecimiento del funcionamiento de las ...
# 11  a) Restablecimiento del funcionamiento de las ...
# 12  a) Restablecimiento del funcionamiento de las ...
# 13  c) Aseguramiento de las infraestructuras de pr...
# 14  c) Aseguramiento de las infraestructuras de pr...
# 15  c) Aseguramiento de las infraestructuras de pr...
# 16  c) Aseguramiento de las infraestructuras de pr...
# 17  c) Aseguramiento de las infraestructuras de pr...
# 18  c) Aseguramiento de las infraestructuras de pr...
# 19  c) Aseguramiento de las infraestructuras de pr...
# 20  c) Aseguramiento de las infraestructuras de pr...
# 21  c) Aseguramiento de las infraestructuras de pr...
# 22  c) Aseguramiento de las infraestructuras de pr...
# 23  c) Aseguramiento de las infraestructuras de pr...
# 24  c) Aseguramiento de las infraestructuras de pr...
# 25  c) Aseguramiento de las infraestructuras de pr...
#
# 7  Número operación contable Observaciones elegible
# 0     17232.2.20.3.1.0001440           NaN       SÍ
# 1     17232.2.20.3.1.0001441           NaN       SÍ
# 2     17232.2.20.3.1.0001445           NaN       SÍ
# 3     17232.2.20.3.1.0001509           NaN       SÍ
# 4     17232.2.20.3.1.0002115           NaN       SÍ
# 5     17232.2.20.3.1.0002427           NaN       SÍ
# 6     17232.2.20.3.1.0002428           NaN       SÍ
# 7     17232.2.20.3.1.0002429           NaN       SÍ
# 8     17232.2.20.3.1.0002430           NaN       SÍ
# 9     17232.2.20.3.1.0002431           NaN       SÍ
# 10    17232.2.20.3.1.0002432           NaN       SÍ
# 11    17232.2.21.3.1.0001052           NaN       SÍ
# 12    17232.2.21.3.1.0001053           NaN       SÍ
# 13    17232.2.20.3.1.0001245           NaN       SÍ
# 14    17232.2.20.3.1.0001246           NaN       SÍ
# 15    17232.2.20.3.1.0001247           NaN       SÍ
# 16    17232.2.20.3.1.0001248           NaN       SÍ
# 17    17232.2.20.3.1.0002415           NaN       SÍ
# 18    17232.2.19.3.1.0001897           NaN       SÍ
# 19    17232.2.20.3.1.0001517           NaN       SÍ
# 20    17232.2.20.3.1.0001518           NaN       SÍ
# 21    17232.2.20.3.1.0001519           NaN       SÍ
# 22    17232.2.20.3.1.0001543           NaN       SÍ
# 23    17232.2.20.3.1.0002316           NaN       SÍ
# 24    17232.2.20.3.1.0002317           NaN       SÍ
# 25    17232.2.20.3.1.0002318           NaN       SÍ
# ALCÁZARES-MAC
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7  Código Expte de Contratación/Encargo       Nº factura  \
# 0                             8853/2019         Emitida1
# 1                             8853/2019         Emitida3
# 2                              867/2020            EMI.8
# 3                              867/2020        EMITIDA12
# 4                             8001/2019          Emit-44
# 5                             5990/2019          Emit-46
# 6                             1314/2020         EMIT-012
# 7                             3651/2020         Emit-016
# 8                            10459/2019          EMIT-49
# 9                             7770/2019         2019/840
# 10                            3401/2020              174
# 11                            1451/2020          T000353
# 12                            9236/2019                7
# 13                           10304/2019          EMIT-15
# 14                        FACT-2020-101          X000017
# 15                       FACT-2019-2263     NULL20190892
# 16                        FACT-2020-191         P1901363
# 17                       FACT-2019-2282         EMIT-741
# 18                       FACT-2019-2255         EMIT-730
# 19                       FACT-2019-2254         EMIT-729
# 20                       FACT-2019-2252         EMIT-727
# 21                       FACT-2019-2251        EMIT-726
# 22                       FACT-2019-2249         EMIT-724
# 23                       FACT-2019-2238         EMIT-721
# 24                       FACT-2019-2237         EMIT-720
# 25                       FACT-2019-2027             1926
# 26                       FACT-2019-1967              489
# 27                       FACT-2019-1968              490
# 28                       FACT-2019-1966              487
# 29                       FACT-2019-1965              488
# 30                            5968/2019            N0024
# 31                             842 2020           EMIT-5
# 32                            2533/2020         Emit-137
# 33                           10403/2019            A.534
# 34                            1478/2020            F20-3
# 35                           10353/2019            F20-2
# 36                            7773/2019           A./392
# 37                            7681/2019           A./393
# 38                            7955/2019          Emit-61
# 39                            8159/2019          Emit-92
# 40                            3799/2019         Emit-142
# 41                            8002/2019        20-014 66
# 42                            8002/2019        20-004 64
# 43                            9777/2019  A-2020/A/200006
# 44                            1815/2020        202000021
# 45                           10314/2019          Emit-14
# 46                            6152/2020        A31770554
# 47                            4132/2020          Emit-99
# 48                            4132/2020         Emit-100
# 49                            4132/2020         Emit-110
#
# 7  Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            27358.92                           22610.68
# 1                            20054.93                           16574.32
# 2                            23428.02                           19362.02
# 3                            23428.02                           19362.02
# 4                              8888.4                            7345.79
# 5                             12075.8                               9980
# 6                             11966.9                               9890
# 7                            11337.57                            9369.89
# 8                              2613.6                               2160
# 9                            17708.96                            14635.5
# 10                            5833.83                            4821.35
# 11                               2665                            2202.48
# 12                               4961                               4100
# 13                           12095.16                               9996
# 14                             381.16                                315
# 15                             2069.1                               1710
# 16                              643.2                             531.56
# 17                           18422.25                              15225
# 18                              653.4                                540
# 19                               72.6                                 60
# 20                              508.2                                420
# 21                                363                                300
# 22                             1524.6                               1260
# 23                             1379.4                               1140
# 24                             1161.6                                960
# 25                             7550.4                               6240
# 26                              66.55                                 55
# 27                              26.62                                 22
# 28                              26.62                                 22
# 29                              26.62                                 22
# 30                             300.08                                248
# 31                            10478.6                               8660
# 32                           12076.41                             9980.5
# 33                              65000                           53719.01
# 34                           12000.01                            9917.36
# 35                           25001.02                              20662
# 36                              12342                              10200
# 37                            11555.5                               9550
# 38                           11935.44                               9864
# 39                             8240.1                               6810
# 40                              24805                              20500
# 41                           14601.24                           12067.14
# 42                           21692.71                           17927.86
# 43                           36507.39                            30171.4
# 44                           18736.52                           15484.73
# 45                             5263.5                               4350
# 46                           70460.84                            58232.1
# 47                            5948.12                             4915.8
# 48                           37242.98                           30779.32
# 49                            1898.64                            1569.12
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            13679.46
# 1                                            10027.47
# 2                                            11714.01
# 3                                            11714.01
# 4                                              4444.2
# 5                                             12075.8
# 6                                             11966.9
# 7                                            11337.57
# 8                                              2613.6
# 9                                            13042.47
# 10                                            5833.83
# 11                                               2665
# 12                                               4961
# 13                                           12095.16
# 14                                             381.16
# 15                                             2069.1
# 16                                              643.2
# 17                                           18422.25
# 18                                              653.4
# 19                                               72.6
# 20                                              508.2
# 21                                                363
# 22                                             1524.6
# 23                                             1379.4
# 24                                             1161.6
# 25                                             7187.4
# 26                                              66.55
# 27                                              26.62
# 28                                              26.62
# 29                                              26.62
# 30                                             300.08
# 31                                            10478.6
# 32                                           12076.41
# 33                                              65000
# 34                                            6000.01
# 35                                           12500.51
# 36                                               6171
# 37                                            5777.75
# 38                                            5972.95
# 39                                            4120.05
# 40                                            12402.5
# 41                                            7300.62
# 42                                           10846.36
# 43                                           18253.69
# 44                                            9368.26
# 45                                            2631.75
# 46                                           35230.42
# 47                                            1487.03
# 48                                            9310.75
# 49                                             474.66
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            11305.34
# 1                                             8287.16
# 2                                                9681
# 3                                                9681
# 4                                             3672.89
# 5                                                9980
# 6                                                9890
# 7                                             9369.89
# 8                                                2160
# 9                                             10778.9
# 10                                            4821.35
# 11                                            2202.48
# 12                                               4100
# 13                                               9996
# 14                                                315
# 15                                               1710
# 16                                             531.56
# 17                                              15225
# 18                                                540
# 19                                                 60
# 20                                                420
# 21                                                300
# 22                                               1260
# 23                                               1140
# 24                                                960
# 25                                               5940
# 26                                                 55
# 27                                                 22
# 28                                                 22
# 29                                                 22
# 30                                                248
# 31                                               8660
# 32                                             9980.5
# 33                                           53719.01
# 34                                            4958.69
# 35                                              10331
# 36                                               5100
# 37                                               4775
# 38                                            4936.32
# 39                                               3405
# 40                                              10250
# 41                                            6033.57
# 42                                            8963.93
# 43                                           15085.69
# 44                                            7742.36
# 45                                               2175
# 46                                           29116.05
# 47                                            1228.95
# 48                                            7694.83
# 49                                             392.28
#
# 7  Fecha pago factura                                        Descriptivo  \
# 0          11/02/2020  Parcheo de asfalto de varias calles del munici...
# 1          06/04/2020  Parcheo de asfalto de varias calles del munici...
# 2          15/07/2020  Obra:Parcheo de varias calles del municipio Ac...
# 3          17/12/2020  Obra:Parcheo de varias calles del municipio Ac...
# 4          27/12/2019  OFICINA DE TURISMO; Parte Informática necesari...
# 5          09/01/2020  PRESUPUESTO RAMBLA; Demolición de acera con má...
# 6          08/04/2020  Grupo de presión doble más bancada  MOD ESPA M...
# 7          28/07/2020  Reparación y acondicionamiento de la Bibliotec...
# 8          29/01/2020  Servicio de carga, extracción y desalojo de má...
# 9          04/09/2020  Actuación por emergencia de demolición de vivi...
# 10         17/11/2020  Acondicionamiento de la Biblioteca municipal p...
# 11         17/12/2020  Suministro de paneles para evitar la entrada d...
# 12         08/01/2020  Reparación de las paredes en el Edificio de La...
# 13         08/01/2020  Limpieza, arreglo y acondicionamiento de Sala ...
# 14         04/09/2020        Señales de emeregencias en zonas inundadas.
# 15         04/09/2020  Actuación de emergencia a consecuencia de los ...
# 16         07/09/2020  Servicios de grúa por emergencias  ante inunda...
# 17         04/09/2020  El día 02 de octubre de 2019, se recogieron 20...
# 18         04/09/2020  El día 04 de octubre de 2019, se recogieron 9 ...
# 19         04/09/2020  El día 03 de octubre de 2019, se recogieron 1 ...
# 20         04/09/2020  El día 01 de octubre de 2019, se recogieron 7 ...
# 21         04/09/2020  El día 27 de septiembre de 2019, se recogieron...
# 22         04/09/2020  El día 25 de septiembre de 2019, se recogieron...
# 23         04/09/2020  El día 22 de septiembre de 2019, se recogieron...
# 24         04/09/2020  El día 21 de septiembre de 2019, se recogieron...
# 25         04/09/2020  Servicio de grúa y recogida de vehículos de em...
# 26         17/12/2019  Mano de obra ante actuaciones de emergencia po...
# 27         27/12/2019  Mano de obra ante actuaciones de emergencia po...
# 28         17/12/2019  Mano de obra ante actuaciones de emergencia po...
# 29         27/12/2019  Mano de obra ante actuaciones de emergencia po...
# 30         16/12/2019  Lavado especial de vehiculos municipales por i...
# 31         29/04/2020  Reparación de canaletas de desagüe en patio de...
# 32         28/07/2020  Obras de ajardinamiento de los parterres de su...
# 33         29/01/2020  Obras por emergencia de retirada de escombro y...
# 34         13/05/2020  Reparación de socavones en pavimento de la Pla...
# 35         13/05/2020  Reconstrucción de un tramo de vallado del Poli...
# 36         27/12/2019  Obras de emergencia para la reparación del tra...
# 37         27/12/2019   Obras de emergencia para la reparación del tr...
# 38         09/01/2020   Reparación en el Juzgado de Paz tras las inun...
# 39         09/01/2020  Reparación de las obras del edificio municipal...
# 40         03/09/2020  Acondicionamiento de alcorques sitos en Paseo ...
# 41         18/09/2020  Reparación en Centro de la 3º Edad tras las in...
# 42         13/05/2020  Reparación en Centro de la 3º Edad tras las in...
# 43         29/04/2020  Obras de acondicionamiento y rehabilitación de...
# 44         29/10/2020  Reconstrucción de un tramo de vallado del Poli...
# 45         08/01/2020  Reparación del muro de piedra de la Rambla, de...
# 46         10/05/2021  Retirada de Lodos y limpieza del aparcamiento ...
# 47         04/01/2021  Obra de colector de pluviales en calle Manuel ...
# 48         04/01/2021  Obra de colector de pluviales en calle Manuel ...
# 49         17/05/2021  Obra de colector de pluviales en calle Manuel ...
#
# 7         Concepto de gasto (seleccionar de la lista)  \
# 0   a) Restablecimiento del funcionamiento de las ...
# 1   a) Restablecimiento del funcionamiento de las ...
# 2   a) Restablecimiento del funcionamiento de las ...
# 3   a) Restablecimiento del funcionamiento de las ...
# 4   a) Restablecimiento del funcionamiento de las ...
# 5   c) Aseguramiento de las infraestructuras de pr...
# 6   a) Restablecimiento del funcionamiento de las ...
# 7   c) Aseguramiento de las infraestructuras de pr...
# 8   a) Restablecimiento del funcionamiento de las ...
# 9   c) Aseguramiento de las infraestructuras de pr...
# 10  a) Restablecimiento del funcionamiento de las ...
# 11  a) Restablecimiento del funcionamiento de las ...
# 12  a) Restablecimiento del funcionamiento de las ...
# 13  a) Restablecimiento del funcionamiento de las ...
# 14  c) Aseguramiento de las infraestructuras de pr...
# 15  a) Restablecimiento del funcionamiento de las ...
# 16  a) Restablecimiento del funcionamiento de las ...
# 17  a) Restablecimiento del funcionamiento de las ...
# 18  a) Restablecimiento del funcionamiento de las ...
# 19  a) Restablecimiento del funcionamiento de las ...
# 20  a) Restablecimiento del funcionamiento de las ...
# 21  a) Restablecimiento del funcionamiento de las ...
# 22  a) Restablecimiento del funcionamiento de las ...
# 23  a) Restablecimiento del funcionamiento de las ...
# 24  a) Restablecimiento del funcionamiento de las ...
# 25  a) Restablecimiento del funcionamiento de las ...
# ...
# 8                              188.75                             171.59
# 9                               22.17                              20.15
# 10                              914.1                                831
# 11                              413.6                                376
# 12                             743.19                         614.206612
# 13                              23.37                              19.32
# 14                              13.21                          10.917355
# 15                              31.16                          25.752066
# 16                             428.34                                354
# 17                             381.26                              346.6
# 18                              55.61                          45.958678
# 19                             621.42                         513.570248
# 20                              75.02                                 62
# 21                             129.95                         107.396694
# 22                             937.76                         775.008264
# 23                              212.5                         175.619835
# 24                                121                                100
# 25                                242                                200
# 26                              193.6                                160
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                                27.7
# 1                                              378.88
# 2                                             1192.24
# 3                                              164.56
# 4                                              464.79
# 5                                               85.31
# 6                                               13.75
# 7                                               86.04
# 8                                              188.75
# 9                                               22.17
# 10                                              914.1
# 11                                              413.6
# 12                                             743.19
# 13                                              23.37
# 14                                              13.21
# 15                                              31.16
# 16                                             428.34
# 17                                             381.26
# 18                                              55.61
# 19                                             621.42
# 20                                              75.02
# 21                                             129.95
# 22                                             937.76
# 23                                              212.5
# 24                                                121
# 25                                                242
# 26                                              193.6
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           22.892562
# 1                                          313.123967
# 2                                              985.32
# 3                                                 136
# 4                                          384.123967
# 5                                           70.504132
# 6                                           11.363636
# 7                                           71.107438
# 8                                              171.59
# 9                                               20.15
# 10                                                831
# 11                                                376
# 12                                         614.206612
# 13                                              19.32
# 14                                          10.917355
# 15                                          25.752066
# 16                                                354
# 17                                              346.6
# 18                                          45.958678
# 19                                         513.570248
# 20                                                 62
# 21                                         107.396694
# 22                                         775.008264
# 23                                         175.619835
# 24                                                100
# 25                                                200
# 26                                                160
#
# 7  Fecha pago factura                                        Descriptivo  \
# 0          27/02/2020  FRA. EMIT- 23 MATERIALS D'OBRA A LA FONT JORDA...
# 1          27/02/2020  FRA. EMIT- 25 MATERIAL D'OBRA FONT JORDANA, MU...
# 2          27/02/2020         FRA. 4043733270 MATERIAL DE REPARACIÓ DANA
# 3          27/02/2020  FRA. FV20/0008 TREBALL MAQUINARIA OBRA FONT JO...
# 4          27/02/2020   FRA. 4043795123 MATERIAL DE REPARACIONS PEL DANA
# 5          18/03/2020          FRA. 00- 457351 MATERIALS FERRETERIA DANA
# 6          18/03/2020            FRA. EMIT- 29 MATERIAL CONSTRUCCIÓ DANA
# 7          18/03/2020           FRA. EMIT- 31 MATERIALS CONSTRUCCIÓ DANA
# 8          18/03/2020           FRA. RECT-EMIT- 1 RESIDUS PER OBRES DANA
# 9          18/03/2020                 FRA. EMIT- 2 MATERIALS CONSTRUCCIÓ
# 10         18/03/2020                FRA. RECT-EMIT- 3 RESIDUS PER OBRES
# 11         18/03/2020                     FRA. EMIT- 4 RESIDUS PER OBRES
# 12         06/04/2020     FRA. 34 MATERIALS CONSTRUCCIO REPARACIONS DANA
# 13         06/04/2020  FRA. 35 MATERIALS CONSTRUCCIO VORERE CENTRE SALUT
# 14         06/04/2020                       FRA 36 MATERIALS CONSTRUCCIO
# 15         06/04/2020         FRA. 9953 LLOGUER MAQUINARIA EL 07.02.2020
# 16         09/04/2020            FRA- 477 MATERIALS OBRES DEL 14.02.2020
# 17         09/04/2020                    FRA. 5 TRACTAMENT RESIDUS OBRES
# 18         09/04/2020                      FRA. 37 MATERIALS CONSTRUCCIO
# 19         09/04/2020          FRA. 124 MATERIALS CONSTRUCCIO OBRES DANA
# 20         29/04/2020              FRA. 2000963 LLOGUER MAQUINARIA OBRES
# 21         29/04/2020         FRA. 459919 MATERIALS FERRETERIA OBRA DANA
# 22         29/04/2020           FRA. 38 MATERIALS CONSTRUCCIO OBRES DANA
# 23         29/04/2020            FRA. 2001061 MATERIALS CONSTRUCCIO DANA
# 24         26/05/2020                    FRA. 8 SERVEI CONTENIDORS OBRES
# 25         26/05/2020                   FRA. 10 SERVEI CONTENIDORS OBRES
# 26         26/05/2020                   FRA. 13 SERVEI CONTENIDORS OBRES
#
# 7         Concepto de gasto (seleccionar de la lista)  \
# 0   a) Restablecimiento del funcionamiento de las ...
# 1   a) Restablecimiento del funcionamiento de las ...
# 2   a) Restablecimiento del funcionamiento de las ...
# 3   a) Restablecimiento del funcionamiento de las ...
# 4   a) Restablecimiento del funcionamiento de las ...
# 5   a) Restablecimiento del funcionamiento de las ...
# 6   a) Restablecimiento del funcionamiento de las ...
# 7   a) Restablecimiento del funcionamiento de las ...
# 8   a) Restablecimiento del funcionamiento de las ...
# 9   a) Restablecimiento del funcionamiento de las ...
# 10  a) Restablecimiento del funcionamiento de las ...
# 11  a) Restablecimiento del funcionamiento de las ...
# 12  a) Restablecimiento del funcionamiento de las ...
# 13  a) Restablecimiento del funcionamiento de las ...
# 14  a) Restablecimiento del funcionamiento de las ...
# 15  a) Restablecimiento del funcionamiento de las ...
# 16  a) Restablecimiento del funcionamiento de las ...
# 17  a) Restablecimiento del funcionamiento de las ...
# 18  a) Restablecimiento del funcionamiento de las ...
# 19  a) Restablecimiento del funcionamiento de las ...
# 20  a) Restablecimiento del funcionamiento de las ...
# 21  a) Restablecimiento del funcionamiento de las ...
# 22  a) Restablecimiento del funcionamiento de las ...
# 23  a) Restablecimiento del funcionamiento de las ...
# 24  a) Restablecimiento del funcionamiento de las ...
# 25  a) Restablecimiento del funcionamiento de las ...
# 26  a) Restablecimiento del funcionamiento de las ...
#
# 7                                   Proveedor NIF Proveedor  \
# 0                             PRETOBE, S.A.L.     A96179817
# 1                             PRETOBE, S.A.L.     A96179817
# 2                            WURTH ESPAÑA, SA     A08472276
# 3                    NAVARRO NACHER, SALVADOR     52714256G
# 4                            WURTH ESPAÑA, SA     A08472276
# 5                   SUMINISTROS NAVARRO, S.A.     A46148912
# 6                             PRETOBE, S.A.L.     A96179817
# 7                             PRETOBE, S.A.L.     A96179817
# 8                        RECIFRAN E HIJOS, SL     B97829733
# 9                        RECIFRAN E HIJOS, SL     B97829733
# 10                       RECIFRAN E HIJOS, SL     B97829733
# 11                       RECIFRAN E HIJOS, SL     B97829733
# 12                            PRETOBE, S.A.L.     A96179817
# 13                            PRETOBE, S.A.L.     A96179817
# 14                            PRETOBE, S.A.L.     A96179817
# 15                        ALSETRANS 2000, SL.     B97034490
# 16            GUEROLA ARIDOS Y HORMIGONES SL.     B96854864
# 17                       RECIFRAN E HIJOS, SL     B97829733
# 18                            PRETOBE, S.A.L.     A96179817
# 19  MATERIALS DE CONSTRUCCIO TINO JORNET, SLU     B97311468
# 20                      MAQUINAL A.V.M., S.L.     B46568218
# 21                  SUMINISTROS NAVARRO, S.A.     A46148912
# 22  MATERIALS DE CONSTRUCCIO TINO JORNET, SLU     B97311468
# 23                      MAQUINAL A.V.M., S.L.     B46568218
# 24                 CANO GABALDON MIGUEL ANGEL     52715123C
# 25                 CANO GABALDON MIGUEL ANGEL     52715123C
# 26                 CANO GABALDON MIGUEL ANGEL     52715123C
#
# 7  Número operación contable Fecha factura    Observaciones elegible
# 0               220200000711    04/01/2020  No hay contrato      NaN
# 1               220200000713    11/01/2020  No hay contrato      NaN
# 2               220200000717    16/01/2020  No hay contrato      NaN
# 3               220200000747    20/01/2020  No hay contrato      NaN
# 4               220200000755    29/01/2020  No hay contrato      NaN
# 5               220200000960    31/01/2020  No hay contrato      NaN
# 6               220200000973    31/01/2020  No hay contrato      NaN
# 7               220200000975    31/01/2020  No hay contrato      NaN
# 8               220200000980    31/01/2020  No hay contrato      NaN
# 9               220200000981    31/01/2020  No hay contrato      NaN
# 10              220200000982    31/01/2020  No hay contrato      NaN
# 11              220200000983    07/02/2020  No hay contrato      NaN
# 12              220200001416    22/02/2020  No hay contrato      NaN
# 13              220200001417    22/02/2020  No hay contrato      NaN
# 14              220200001418    22/02/2020  No hay contrato      NaN
# 15              220200001426    15/02/2020  No hay contrato      NaN
# 16              220200001537    05/03/2020  No hay contrato      NaN
# 17              220200001538    29/02/2020  No hay contrato      NaN
# 18              220200001545    07/03/2020  No hay contrato      NaN
# 19              220200001565    31/01/2020  No hay contrato      NaN
# 20              220200001766    13/03/2020  No hay contrato      NaN
# 21              220200001776    15/03/2020  No hay contrato      NaN
# 22              220200001792    23/03/2020  No hay contrato      NaN
# 23              220200001796    26/03/2020  No hay contrato      NaN
# 24              220200002226    28/02/2020  No hay contrato      NaN
# 25              220200002227    24/03/2020  No hay contrato      NaN
# 26              220200002230    24/03/2020  No hay contrato      NaN
# ABANILLA-JOG
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                                11.19         52
# 1                                11.19         63
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            69672.5                           57580.58
# 1                           18124.17                           14978.65
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           34836.25
# 1                                            9062.08
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           28790.29
# 1                                            7489.32
#
# 7 Fecha pago factura                    Descriptivo  \
# 0         20/04/2020  Certificación nº 1 marzo 2020
# 1         02/09/2020    Certificación nº 2 y última
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
# 1  a) Restablecimiento del funcionamiento de las ...
#
# 7                         Proveedor NIF Proveedor Número operación contable  \
# 0  ISETEC SERVICIOS INTEGRALES S.L.     B73900896            2020.2.0000836
# 1  ISETEC SERVICIOS INTEGRALES S.L.     B73900896            2020.2.0001650
#
# 7 Fecha factura Observaciones elegible
# 0    11/03/2020           NaN      NaN
# 1    22/06/2020           NaN      NaN
# AP CARTAGENA-MAC
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                           PC19-00961   EMIT-392
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           16558.85                              13685
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           16558.85
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                              13685
#
# 7 Fecha pago factura                                        Descriptivo  \
# 0         29/11/2019  Reparación de incidencias por motivos metereol...
#
# 7        Concepto de gasto (seleccionar de la lista)        Proveedor  \
# 0  d) Limpieza de las zonas siniestradas, así com...  IBERLEC S.COOP.
#
# 7 NIF Proveedor Número operación contable Fecha factura Observaciones elegible
# 0     F30731517                    437067    21/10/2019           NaN        S

# %%
sin_errores
# Out:
# 59

# %%
resultados = {}
for k,v in ayuntamientos.items():
    if k not in sin_fichero:
        df=get_df_facturas(os.path.join(fichero_padre,k,"Justificacion_FSUE-DANA.xlsx"))
        resultados.update({k:df['Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**'].sum()})
# Out:
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
resultados
# Out:
# {'NIJAR-MAC': 832740.7800000001,
#  'ALGORFA-JOG': 24009.06,
#  'TÍJOLA-DGM': 21632.93,
#  'HUESCAR-DGM': 3263.79,
#  'RIOJA-JOG': 2904,
#  'CONF.HIDRO.SEGURA-MAC': 7485436.359999999,
#  'ALCÁZARES-MAC': 398386.19999999995,
#  'BIGASTRO-JOG': 61138.35,
#  'DAYA NUEVA-DGM': 17763.43,
#  'FUENTE-ÁLAMO-JOG': 9620.19,
#  'ALBATERA-JOG': 4559.43,
#  'RENFE-MAC': 35912.46,
#  'REGIÓN DE MURCIA-DGM': 1035544.6200000001,
#  'JUNTA ANDALUCÍA-JOG': 11243671.070000004,
#  'DP MÁLAGA-JOG': 149995.42,
#  'CONF.HIDRO.JÚCAR-EBB': 3871330.5600000015,
#  'ZURGENA-JOG': 17901.950000000004,
#  'VIVEROS-JOG': 1543.5,
#  'VALLADA-JOG': 2014.67,
#  'ULEA-JOG': 15117.91,
#  'TOTANA-JOG': 1197.9,
#  'TORRES DE COTILLAS-MAC': 17329.62,
#  'TABERNO - JOG': 15565.59,
#  'SERÓN-JOG': 38154.740000000005,
#  'SANTOMERA-JOG': 3409.18,
#  'SAN JAVIER-JOG': 118837.88999999998,
#  'SAN FULGENCIO-MAC': 9729.25,
#  'PURCHENA-JOG': 11021.5,
#  'PULPÍ-JOG': 21133.989999999998,
#  'PUERTO LUMBRERAS-JOG': 25918.99,
#  'PINOS GENIL-MAC': 68598.45000000001,
#  'OTOS-JOG': 1277.76,
#  'ORIHUELA-MAC': 1354011.3200000005,
#  'ONTINYENT-MAC': 117093.17000000001,
#  'OLULA DEL RÍO-JOG': 17540.0,
#  'L-OLLERIA-JOG': 1990.45,
#  'OJÓS-JOG': 726,
#  'MOLINICOS-DGM': 18895.680000000004,
#  'MOLINA DEL SEGURA-MAC': 188878.40999999997,
#  'LORQUÍ-JOG': 55107.37,
#  'LOJA - JOG': 2879.8,
#  'JACARILA-JOG': 14089.05,
#  'GRANADA-JOG': 5426.96,
#  'GALLARDOS-JOG': 1111.23,
#  'DENIA-MAC': 80644.2,
#  'CREVILLENT-MAC': 40254.5,
#  'CIEZA-JOG': 67592.42000000001,
#  'BLANCA-JOG': 4188.96,
#  'BENIEL-JOG': 10977.12,
#  'BAZA-MAC': 1753.43,
#  'ARCHENA-MAC': 6433.59,
#  'ARBOLEAS-MAC': 10995.28,
#  'ALMORADÍ-DGM': 271252.71,
#  'ALHAURÍN DE LA TORRE-MAC': 239459.42999999996,
#  'ALCÓNTAR-JOG': 605,
#  'ALBAIDA-MAC': 123155.93,
#  'AGULLENT-JOG': 8161.280000000001,
#  'ABANILLA-JOG': 43898.33,
#  'AP CARTAGENA-MAC': 16558.85}
