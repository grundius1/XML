# %%
import csv

# %%
file = "C:/Users/bllanos/Desktop/project1/prueba1/Abril_2022/Operaciones/Campañas de concienciación COVID/masivooperacionesSANIDAD_CAMPANAS_PUBLI.csv"

# %%
with open(file) as f:
    csv_reader = csv.DictReader(f,delimiter=";")
    for line in csv_reader:
        print(type(line))
        for item, value in line.items():
            print(item,"-->" ,value)
        print("----------------------------------------------")
    print("aaaaaaaaaaa")
# Out:
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_AN
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 2
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Andalucía.
# name --> COVID-19 social awareness campaigns in Andalucía.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 2862825,78
# costetotal_subv --> 2862825,78
# costepub_subv --> 2862825,78
# ayuda_publica_deca --> 2862825,78
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES61
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99004
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 2862825,78
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_AR
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Aragón
# name --> COVID-19 social awareness campaigns in Aragón
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 448870,04
# costetotal_subv --> 448870,04
# costepub_subv --> 448870,04
# ayuda_publica_deca --> 448870,04
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES24
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99010
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 448870,04
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_AS
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Principado de Asturias
# name --> COVID-19 social awareness campaigns in Principado de Asturias
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 347993,19
# costetotal_subv --> 347993,19
# costepub_subv --> 347993,19
# ayuda_publica_deca --> 347993,19
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES12
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99005
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 347993,19
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_CE
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Ciudad Autónoma de Ceuta.
# name --> COVID-19 social awareness campaigns in Ciudad Autónoma de Ceuta.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 28844,17
# costetotal_subv --> 28844,17
# costepub_subv --> 28844,17
# ayuda_publica_deca --> 28844,17
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES63
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99018
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 28844,17
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_CL
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Castilla y León.
# name --> COVID-19 social awareness campaigns in Castilla y León.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 816412,16
# costetotal_subv --> 816412,16
# costepub_subv --> 816412,16
# ayuda_publica_deca --> 816412,16
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES41
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99017
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 816412,16
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_CM
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 2
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Castilla-La Mancha.
# name --> COVID-19 social awareness campaigns in Castilla-La Mancha.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 691652,79
# costetotal_subv --> 691652,79
# costepub_subv --> 691652,79
# ayuda_publica_deca --> 691652,79
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES42
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99011
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 691652,79
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_CN
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Cantabria.
# name --> COVID-19 social awareness campaigns in Cantabria.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 197703,54
# costetotal_subv --> 197703,54
# costepub_subv --> 197703,54
# ayuda_publica_deca --> 197703,54
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES13
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99006
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 197703,54
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_CT
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Cataluña.
# name --> COVID-19 social awareness campaigns in Cataluña.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 2611383,68
# costetotal_subv --> 2611383,68
# costepub_subv --> 2611383,68
# ayuda_publica_deca --> 2611383,68
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES51
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99002
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 2611383,68
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_CV
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Comunitat Valenciana.
# name --> COVID-19 social awareness campaigns in Comunitat Valenciana.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 1702461,4
# costetotal_subv --> 1702461,4
# costepub_subv --> 1702461,4
# ayuda_publica_deca --> 1702461,4
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES52
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99009
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 1702461,4
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_EU
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en País Vasco.
# name --> COVID-19 social awareness campaigns in País vasco.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 751164,46
# costetotal_subv --> 751164,46
# costepub_subv --> 751164,46
# ayuda_publica_deca --> 751164,46
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES21
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99001
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 751164,46
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_EX
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 1
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Extremadura.
# name --> COVID-19 social awareness campaigns in Extremadura.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# ...
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES30
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99016
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 2267125,26
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_ME
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 2
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Ciudad Autónoma de Melilla.
# name --> COVID-19 social awareness campaigns in Ciudad Autónoma de Melilla.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 29425,97
# costetotal_subv --> 29425,97
# costepub_subv --> 29425,97
# ayuda_publica_deca --> 29425,97
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES64
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99019
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 29425,97
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_MU
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 2
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Región de Murcia.
# name --> COVID-19 social awareness campaigns in Región de Murcia.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 508277,6
# costetotal_subv --> 508277,6
# costepub_subv --> 508277,6
# ayuda_publica_deca --> 508277,6
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES62
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99008
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 508277,6
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# <class 'dict'>
# cod_poperativo --> PE
# cod_operacion --> CampanasCocienciSocialCOVID_NA
# cod_subvencionglobal --> 0
# cod_eje --> 01
# cat_region --> 3
# cod_obj_tematico --> 01
# cod_prioridad --> 1b
# cod_obj_especifico --> 010b4
# cod_organismo --> ES115007
# cod_actuacion --> GCS1
# nombre --> Campañas de concienciación social a la población sobre la COVID-19 en Comunidad Foral de Navarra.
# name --> COVID-19 social awareness campaigns in Comunidad Foral de Navarra.
# descripcion --> Concienciar a la población española con información y recomendaciones para prevenir el contagio y la enfermedad. Dentro de las medidas no farmacológicas que se han llevado a cabo se encuentra a difusión de las distintas campañas publicitarias institucionales para sensibilizar a la población sobre la enfermedad producida por la COVID-19 y su prevención, con el objetivo de evitar la transmisión de la enfermedad, el control de los brotes y sus consecuencias.
# operation_summary --> Raise awareness among the Spanish population with information and recommendations to prevent contagion and disease. Among the non-pharmacological measures that have been carried out is the dissemination of the different institutional advertising campaigns to sensitize the population about the disease caused by COVID-19 and its prevention, with the aim of avoiding the transmission of the disease, control of outbreaks and their consequences.
# cod_beneficiario --> ES133001
# iva_recuperable --> N
# costetotal --> 222587,03
# costetotal_subv --> 222587,03
# costepub_subv --> 222587,03
# ayuda_publica_deca --> 222587,03
# utilizacion_ocs --> N
# cod_base_calculo_1 --> CORE
# cod_base_calculo_2 -->
# cod_base_calculo_3 -->
# cod_base_calculo_4 -->
# finan_costeind --> N
# calculo_hora --> N
# cod_manera_tipofijo -->
# finan_tipofijo_horizonte2020 --> N
# finan_tipofijo_LIFE --> N
# autorizado_ocs_ag --> N
# f_presentacion --> 16/03/2022
# f_inicio_DECA --> 01/02/2020
# f_inicio_ejecucion_real --> 01/02/2020
# f_fin --> 30/06/2022
# f_real -->
# cod_org_deca --> ES115007
# f_deca --> 25/03/2022
# fecha_oper_fin_2_14 -->
# gproyecto --> N
# cod_gran_proyecto -->
# texto_gp -->
# plan_accion_conjunto --> N
# regimen_ayudas --> N
# referencia_bdns -->
# proy_cooperacion --> N
# cod_proyecto -->
# ayuda_estado --> N
# cod_tipo_ayuda -->
# reglamento_minimis -->
# reglamento_exencion -->
# f_comunicacion_exencion -->
# notificacion_autorizacion --> N
# f_notificacion_autorizacion -->
# f_autorizacion -->
# publica_privada --> N
# cod_pubpriv -->
# finan_anticipos --> N
# convenio --> N
# cod_convenio -->
# cod_iti_1 -->
# cod_iti_3 -->
# cod_obj_estrategia_atlantica -->
# instrumento_finan --> N
# cod_instrumento -->
# costes_gestion_if --> N
# gastos_fuera_zona --> N
# gastos_fuera_ue --> N
# normativa_med_amb --> N
# contratos_publicos --> S
# genera_ingresos --> N
# genera_ingresos_netos --> N
# genera_ingresos_61 --> N
# ogi_metodo -->
# cod_sector -->
# reembolso_total -->
# genera_ingresos_65 --> N
# compra_terrenos --> N
# imp_terrenos --> 0
# terrenos_limite_10 --> N
# terrenos_limite_15 --> N
# terrenos_limite_otro --> N
# terrenos_limite_proposito --> N
# terrenos_limite_realojo --> N
# f_sol_compra_terrenos -->
# aut_compra_terrenos --> N
# f_aut_compra_terrenos -->
# contr_especie --> N
# cod_campo_intervencion --> 053
# cod_campo_intervencion-porcentaje --> 100
# cod_tipo_financiacion --> 01
# cod_tipo_financiacion-porcentaje --> 100
# cod_dimension_terr --> 07
# cod_dimension_terr-porcentaje --> 100
# cod_mecanismo_entrega --> 07
# cod_mecanismo_entrega-porcentaje --> 100
# cod_actividad --> 18
# cod_actividad_porcentaje --> 100
# cod_nut --> ES22
# cod_nut-porcentaje --> 100
# cod_contrato -->
# cod_municipio --> 99013
# cod_postal --> 99
# cod_org_intermedio --> ES115007
# cod_org_certifica --> ES115007
# cod_org_aprueba --> ES115007
# cod_org_verifica --> ES115007
# cod_org_firma --> ES115007
# cod_org_conserva_doc --> ES133001
# cod_org_ayuda -->
# doc_benef --> S
# doc_emplazamiento -->
# gestion_red_natura -->
# operacion_2007 --> N
# cod_operacion_2007 -->
# buena_practica --> N
# porc_comunicacion --> 0
# cod_ind_resultado --> R001Y
# cod_ind_productividad --> CV40
# cod_ind_productividad-val_2023 --> 222587,03
# cod_ind_productividad-2 -->
# cod_ind_productividad-val_2023-2 -->
# cod_ind_productividad-3 -->
# cod_ind_productividad-val_2023-3 -->
# art_53b_ley_21_2013 -->
# eia_articulo7_21_2013 -->
# procedimiento_eia -->
# dia_favorable -->
# coherencia_dia -->
# f_aut_dia -->
# iia_favorable -->
# coherencia_iia -->
# f_aut_iia -->
# afecta_rn2000 -->
# f_proc_amb -->
# dia --> N
# f_dia -->
# f_no_dia -->
# aut_amb_int --> N
# f_aut_amb_int -->
# sospecha_fraude --> N
# f_sospecha_fraude -->
# fraude_constatado --> N
# f_fraude_constatado -->
# limitada_sobreprogramacion --> N
# cod_etiqueta --> COVID
# cod_iaf -->
# ----------------------------------------------
# aaaaaaaaaaa
