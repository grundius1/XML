# %%
from lxml import etree, objectify

# %%
#import pandas as pd

# %%
file = "XSDs/organismos.xsd"

# %%
file2 = "XSDs/transacciones.xsd"

# %%
file3 = "XSDs/operaciones.xsd"

# %%
file4= "XSDs/destinatarios.xsd"

# %%
file5= "XSDs/contratos.xsd"

# %%
file6 = "XSDs/transacciones_IP.xsd"

# %%
file7 = "XSDs/Modificacion_de_transacciones.xsd"

# %%
chosed_file = file2
print(chosed_file)
# Out:
# XSDs/transacciones.xsd

# %%
f = open(chosed_file, "r")
f
f.close()

# %%
#tree = etree.parse(chosed_file)
#etree.tostring(tree)

# %%
#root = tree.getroot()
#root.tag

# %%
#parser = etree.XMLParser(remove_blank_text=True)

# %%
#root = etree.XML(etree.tostring(tree), parser)

# %%
#print(etree.tostring(root, pretty_print=True))

# %%
## test 2 XSLT

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse(chosed_file)
root = tree.getroot()

# %%
root.tag
# Out:
# '{http://www.w3.org/2001/XMLSchema}schema'

# %%
root.attrib
# Out:
# {}

# %%
for child in root:
    print(child.tag)
    print(child.attrib)
# Out:
# {http://www.w3.org/2001/XMLSchema}element
# {'name': 'transacciones'}
# {http://www.w3.org/2001/XMLSchema}simpleType
# {'name': 'TImporteDecimal'}

# %%
root[0].attrib
# Out:
# {'name': 'transacciones'}

# %%
for child in root.iter():
    print(child.attrib)
# Out:
# {}
# {'name': 'transacciones'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'transaccion'}
# {}
# {}
# {'name': 'cod_poperativo'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'cod_operacion'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '30'}
# {'name': 'cod_transaccion'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '20'}
# {'name': 'bloqueada'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'tipo_transaccion'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'AN'}
# {'value': 'B1'}
# {'value': 'B2'}
# {'value': 'B3'}
# {'value': 'NE'}
# {'value': 'DA'}
# {'value': 'JA'}
# {'name': 'transaccion_hibrida', 'minOccurs': '0'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'destinatario'}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# ...

# %%
import xmlschema
schema = xmlschema.XMLSchema(chosed_file)
dir(schema)
# Out:
# ['BASE_SCHEMAS',
#  'BUILDERS',
#  'BUILDERS_MAP',
#  'XSD_VERSION',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_get_xpath_namespaces',
#  '_global_views',
#  '_import_namespace',
#  '_locations',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_root_elements',
#  '_validate_references',
#  '_xpath_lock',
#  '_xpath_parse',
#  '_xpath_parser',
#  'all_errors',
#  'allow',
# ...

# %%
schema.types
# Out:
# NamespaceView({'TImporteDecimal': XsdAtomicRestriction(name='TImporteDecimal')})

# %%
for xsd_component in schema.iter():
    print(type(xsd_component))
    print(dir(xsd_component))
    #print(xsd_component.get_type())
    print("-----")
# Out:
# <class 'xmlschema.validators.schema.XMLSchema10'>
# ...

# %%
#dir(xsd_component)
method_list = [func for func in dir(schema) if callable(getattr(schema, func)) and not func.startswith("__")]

# %%
method_list
# Out:
# ['_get_xpath_namespaces',
#  '_import_namespace',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_validate_references',
#  '_xpath_parse',
#  'build',
#  'builtin_types',
#  'check_schema',
#  'check_validator',
#  'clear',
#  'converter',
#  'copy',
#  'count',
#  'create_any_attribute_group',
#  'create_any_content_group',
#  'create_any_type',
#  'create_bindings',
#  'create_element',
#  'create_empty_attribute_group',
#  'create_empty_content_group',
#  'create_meta_schema',
#  'decode',
#  'encode',
#  'export',
#  'find',
#  'findall',
#  'get',
#  'get_converter',
#  'get_element',
#  'get_locations',
#  'get_schema',
#  'get_text',
#  'import_schema',
#  'include_schema',
#  'index',
#  'is_valid',
#  'iter',
#  'iter_components',
#  'iter_decode',
#  'iter_encode',
#  'iter_errors',
#  'iter_globals',
#  'iterchildren',
#  'iterfind',
#  'parse_error',
#  'raw_decoder',
#  'resolve_qname',
#  'to_dict',
#  'to_etree',
#  'to_objects',
# ...

# %%
for item in schema.iter_components():
    print(dir(item))
    break
# Out:
# ['BASE_SCHEMAS', 'BUILDERS', 'BUILDERS_MAP', 'XSD_VERSION', '__abstractmethods__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_get_xpath_namespaces', '_global_views', '_import_namespace', '_locations', '_parse_imports', '_parse_inclusions', '_parse_xpath_default_namespace', '_root_elements', '_validate_references', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'all_errors', 'allow', 'attrib', 'attribute_form_default', 'attribute_groups', 'attributes', 'base_url', 'block_default', 'build', 'built', 'builtin_types', 'check_schema', 'check_validator',
# ...

# %%
for item in schema.iter():
    print(item)
    print(list(item.iter()))
    try:
        print(item.get_text())
    except:
        pass
    print("----")
# Out:
# XMLSchema10(name='transacciones.xsd', namespace='')
# ...

# %%
for item in schema.iter():
    try:
        print(item.to_dict)
    #print(list(item.iter()))
    #print(item.get_text())
        print("----")
    except:
        pass
# Out:
# <bound method XMLSchemaBase.decode of XMLSchema10(name='transacciones.xsd', namespace='')>
# ----

# %%
#schema.attributes()

# %%
dir(schema)
# Out:
# ['BASE_SCHEMAS',
#  'BUILDERS',
#  'BUILDERS_MAP',
#  'XSD_VERSION',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_get_xpath_namespaces',
#  '_global_views',
#  '_import_namespace',
#  '_locations',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_root_elements',
#  '_validate_references',
#  '_xpath_lock',
#  '_xpath_parse',
#  '_xpath_parser',
#  'all_errors',
#  'allow',
# ...

# %%
schema.create_meta_schema()
# Out:
# MetaXMLSchema10(name='XMLSchema.xsd', namespace='http://www.w3.org/2001/XMLSchema')

# %%
aaa =schema.to_dict(chosed_file)
aaa["xs:element"]
# Out:
# {'@name': 'transacciones',
#  '@abstract': False,
#  '@nillable': False,
#  'xs:complexType': {'@mixed': False,
#   'xs:sequence': {'@maxOccurs': 'unbounded',
#    '@minOccurs': 1,
#    'xs:element': {'@name': 'transaccion',
#     '@maxOccurs': 1,
#     '@minOccurs': 1,
#     '@nillable': False,
#     'xs:complexType': {'@mixed': False,
#      'xs:sequence': {'@maxOccurs': 1,
#       '@minOccurs': 1,
#       'xs:element': [{'@name': 'cod_poperativo',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': 'Campo (1) en pantalla'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'cod_operacion',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
# ...

# %%
aaa
# Out:
# {'@xmlns:xs': 'http://www.w3.org/2001/XMLSchema',
#  '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#  '@finalDefault': [],
#  '@blockDefault': [],
#  '@attributeFormDefault': 'unqualified',
#  '@elementFormDefault': 'unqualified',
#  'xs:element': {'@name': 'transacciones',
#   '@abstract': False,
#   '@nillable': False,
#   'xs:complexType': {'@mixed': False,
#    'xs:sequence': {'@maxOccurs': 'unbounded',
#     '@minOccurs': 1,
#     'xs:element': {'@name': 'transaccion',
#      '@maxOccurs': 1,
#      '@minOccurs': 1,
#      '@nillable': False,
#      'xs:complexType': {'@mixed': False,
#       'xs:sequence': {'@maxOccurs': 1,
#        '@minOccurs': 1,
#        'xs:element': [{'@name': 'cod_poperativo',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': 'Campo (1) en pantalla'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
# ...

# %%
for xsd_component in schema.iter():
    print(type(xsd_component))
        
    print("-----")
# Out:
# <class 'xmlschema.validators.schema.XMLSchema10'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# ...

# %%
for xsd_component in schema.iter():
    if 'XMLSchema10' in str(type(xsd_component))  :
        pass
    else:
        #print(type(xsd_component))
        print(xsd_component.name)# , xsd_component.is_emptiable())
        #print(xsd_component.is_emptiable())
        '''
        print(list(xsd_component.iterchildren()))
        print(len(list(xsd_component.iterchildren())))
        print(xsd_component.parent)
        print(dir(xsd_component))
        #print(xsd_component.get_type)'''
        #print("-----")
# Out:
# transacciones
# transaccion
# cod_poperativo
# cod_operacion
# cod_transaccion
# bloqueada
# tipo_transaccion
# transaccion_hibrida
# destinatario
# gasto_total
# gasto_total_subvencionable
# gasto_publico_subvencionable
# f_sol_pago_benef
# f_pago_efectivo
# f_pago_efectivo_2
# gastos_compra_terrenos
# importe_iva_no_recuperable
# contratacion_publica
# certificado_ingresos
# concepto_gasto
# gastos_fuera_zona
# gastos_fuera_union
# importe_factura
# nif_emisor
# num_factura
# num_ope_contable
# f_factura
# numero_serie
# gastos_subv_comision
# gasto_publico_verif
# gastos_subv_becu
# gasto_publico_becu
# cod_baremo
# cantidad_unidad_becu
# gastos_subv_alzado
# gasto_pub_alzado
# cod_pago
# gastos_subv_fija
# gasto_pub_fija
# gastos_fse
# imp_especie
# cod_transaccion_modif
# motivo_modif
# clase_modif
# cod_control
# cod_plac
# cod_control_art125
# f_modif
# f_admision_spb
# imp_origen_gasto
# imp_origen_gastopub
# imp_remu_basica
# imp_rendimiento
# transacciones_pagos
# ...

# %%
for xsd_component in schema.iter():
    if "XsdGroup" in str(type(xsd_component)):
        print(dir(xsd_component))
        print(xsd_component.name)
        
        print("-----")
