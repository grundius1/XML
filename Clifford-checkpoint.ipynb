# %%
import json
import pandas as pd

# %%
file = open("C:/Users/bllanos/Downloads/descarga.json","r",encoding="utf8")

# %%
with open('C:/Users/bllanos/Downloads/descarga.json','r',encoding="utf8") as f:
    data = json.loads(f.read())

# %%
df_nested_list = pd.json_normalize(data,meta_prefix="")#, record_path =['data'])

# %%
df_nested_list
# Out:
#                           _id                     owner roles access  \
# 0    624bf23e9b38029d35563dfd  623211ce22093a3b4b9d3b63    []     []
# 1    62502ad89b38027592563e32  622effec22093ad2b49d3b32    []     []
# 2    624ad01e9b38025706563df3  623e521aaab2112ea1d6d118    []     []
# 3    624e97609b3802d059563e14  622bdd1081e565019c2eaa30    []     []
# 4    624c22c09b38024000563dff  623e519daab2117fcfd6d115    []     []
# ..                        ...                       ...   ...    ...
# 112  62387fcfaab211d759d6d106  62320ad322093a02ce9d3b5b    []     []
# 113  623afaa0aab211a9f6d6d108  6232189f22093a04049d3b6e    []     []
# 114  624ae23a9b38028fdb563df6  62320e0922093a20229d3b5e    []     []
# 115  624f00999b38022fd0563e18  6230d80922093a7b329d3b4c    []     []
# 116  624ae4eb9b3802c91b563df9  62433b1bdd677b7c4ea934b2    []     []
#
#                          form externalIds                   created  \
# 0    61e91d497b8f54182f10bb27          []  2022-04-05T07:39:42.647Z
# 1    61e91d497b8f54182f10bb27          []  2022-04-08T12:30:16.977Z
# 2    61e91d497b8f54182f10bb27          []  2022-04-04T11:01:50.493Z
# 3    61e91d497b8f54182f10bb27          []  2022-04-07T07:48:48.841Z
# 4    61e91d497b8f54182f10bb27          []  2022-04-05T11:06:40.535Z
# ..                        ...         ...                       ...
# 112  61e91d497b8f54182f10bb27          []  2022-03-21T13:38:23.321Z
# 113  61e91d497b8f54182f10bb27          []  2022-03-23T10:46:56.659Z
# 114  61e91d497b8f54182f10bb27          []  2022-04-04T12:19:06.407Z
# 115  61e91d497b8f54182f10bb27          []  2022-04-07T15:17:45.528Z
# 116  61e91d497b8f54182f10bb27          []  2022-04-04T12:30:35.632Z
#
#                      modified  \
# 0    2022-04-05T07:39:42.648Z
# 1    2022-04-08T12:46:05.402Z
# 2    2022-04-04T11:05:32.555Z
# 3    2022-04-07T07:53:42.716Z
# 4    2022-04-05T11:06:40.536Z
# ..                        ...
# 112  2022-03-21T13:42:34.934Z
# 113  2022-03-30T10:14:26.564Z
# 114  2022-04-04T12:19:06.410Z
# 115  2022-04-07T15:17:45.531Z
# 116  2022-04-04T16:14:24.799Z
#
#                                           data.resumen  \
# 0                        Administración Digital (JCCM)
# 1                     Agencia Estatal de Investigación
# 2                 Agencia Gallega de Innovación (GAIN)
# 3                                         Agencia IDEA
# 4    Agencia de Modernización Tecnológica de Galici...
# ..                                                 ...
# 112  Subdirección General de Internacionalización d...
# 113                                               UCLM
# 114            Viceconsejería de Medio Ambiente (JCCM)
# 115                                   Xunta de Galicia
# 116                                            procesa
#
#                               data.organismoIntermedio  ...  \
# 0                        Administración Digital (JCCM)  ...
# 1                     Agencia Estatal de Investigación  ...
# 2                 Agencia Gallega de Innovación (GAIN)  ...
# 3                                         Agencia IDEA  ...
# 4    Agencia de Modernización Tecnológica de Galici...  ...
# ..                                                 ...  ...
# 112  Subdirección General de Internacionalización d...  ...
# 113                                               UCLM  ...
# 114            Viceconsejería de Medio Ambiente (JCCM)  ...
# 115                                   Xunta de Galicia  ...
# 116                                            procesa  ...
#
#     data.p4o1.p4o1c3.p4o1c3r  \
# 0                  noProcede
# 1              significativo
# 2                   moderado
# 3              significativo
# 4                   moderado
# ..                       ...
# 112                 moderado
# 113                noProcede
# 114                    debil
# 115            significativo
# 116            significativo
#
#                               data.p4o1.p4o1c3.p4o1c3o  \
# 0    Los proyectos de la D.G.Administración Digital...
# 1    La comunicación a través de los buzones electr...
# 2    Aunque se mantiene informados a los beneficiar...
# 3    Justificación de la valoración:\nComo se ha co...
# 4
# ..                                                 ...
# 112  Existe una comunicación fluida con los benefic...
# 113
# 114  Se abren canales de comunicación para asesorar...
# 115
# 116  La aplicación informática que utilizamos en la...
#
#     data.p4o1.p4o1c4.p4o1c4r  \
# 0                  noProcede
# 1                   moderado
# 2                   moderado
# 3              significativo
# 4                   moderado
# ..                       ...
# 112                    debil
# 113                noProcede
# 114                noProcede
# 115                    debil
# 116                   fuerte
#
#                               data.p4o1.p4o1c4.p4o1c4o  \
# 0    Los proyectos de la D.G.Administración Digital...
# 1    - A través del Foro de beneficiarios se conoce...
# 2    Existe colaboración de la Agencia con algunas ...
# 3    Justificación de la valoración:\nLa conexión d...
# 4
# ..                                                 ...
# 112  Se establecen estas comunicaciones cuando es n...
# 113
# 114        Los beneficiarios son entidades locales\n\n
# 115
# 116  Las organizaciones profesionales locales forma...
#
#     data.p4o2.p4o2c1.p4o2c1r  \
# 0                  noProcede
# 1                   moderado
# 2                   moderado
# 3                      debil
# 4                  noProcede
# ..                       ...
# 112                noProcede
# 113                   fuerte
# 114                    debil
# 115                    debil
# 116                   fuerte
#
#                               data.p4o2.p4o2c1.p4o2c1o  \
# 0    Los proyectos de la D.G.Administración Digital...
# 1    Se ha iniciado una encuesta entre los investig...
# 2    En el marco de la RIS3 se realizan a través de...
# 3    Justificación de la valoración:\nLa recogida d...
# 4
# ..                                                 ...
# 112
# 113  El diseño de la actuaciones a incorporar en el...
# 114  Se mantienen reuniones periódicas con entidade...
# 115
# 116  La colaboración es activa con todos los intere...
#
#     data.p4o2.p4o2c2.p4o2c2r  \
# 0                  noProcede
# 1              significativo
# 2                   moderado
# 3                      debil
# 4                   moderado
# ..                       ...
# 112                noProcede
# 113                   fuerte
# 114                noProcede
# 115                    debil
# 116                   fuerte
#
#                               data.p4o2.p4o2c2.p4o2c2o  \
# 0    Los proyectos de la D.G.Administración Digital...
# 1    Las partes interesadas en los programas de ayu...
# 2    Con frecuencia y con carácter previo al desarr...
# 3    Justificación de la valoración:\nPor el moment...
# 4
# ..                                                 ...
# 112
# 113  El diseño de la actuaciones a incorporar en el...
# 114  Se mantienen reuniones periódicas con entidade...
# 115
# 116  Desde PROCESA fomenta la participación de las ...
#
#     data.p4o2.p4o2c3.p4o2c3r  \
# 0                  noProcede
# 1                   moderado
# 2                      debil
# 3                      debil
# 4                  noProcede
# ..                       ...
# 112                noProcede
# 113                 moderado
# 114                noProcede
# 115                    debil
# 116            significativo
#
#                               data.p4o2.p4o2c3.p4o2c3o
# 0    Los proyectos de la D.G.Administración Digital...
# 1    El Foro de gestión de ayudas de la AEI difunde...
# 2    La Agencia Gallega de Innovación no dispone de...
# 3    Justificación de la valoración:\nTodo lo que s...
# 4
# ..                                                 ...
# 112
# 113  El dialogo continuo con las partes interesadas...
# 114  Se mantienen reuniones periódicas con entidade...
# 115
# 116  Al objeto de facilitar el dialogo multilateral...
#
# [117 rows x 92 columns]

# %%
df_nested_list.to_csv("C:/Users/bllanos/Downloads/descarga.csv",sep=';',encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-17-fc8aff3a0fc1> in <module>
# ----> 1 df_nested_list.to_csv("C:/Users/bllanos/Downloads/descarga.csv",sep=';',encoding="latin1")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     255             )
#     256
# --> 257             self._save()
#     258
#     259     def _save(self) -> None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     260         if self._need_to_save_header:
#     261             self._save_header()
# --> 262         self._save_body()
#     263
#     264     def _save_header(self) -> None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_body(self)
#     298             if start_i >= end_i:
#     299                 break
# --> 300             self._save_chunk(start_i, end_i)
#     301
#     302     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     309
#     310         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 311         libwriters.write_csv_rows(
#     312             data,
#     313             ix,
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# UnicodeEncodeError: 'latin-1' codec can't encode character '\u2026' in position 11142: ordinal not in range(256)

# %%
def diciterator(diccionario):
    lista = []
    for key, value in diccionario.items():
        #print(key,value)
        if type(value) is dict:
            diciterator(value)
        else:
            lista.append(value)
    return lista
    #print(diccionario)

# %%
for encuesta in datos:
    registro = []
    #print(encuesta)
    for clave, valor in encuesta["data"].items():
        if type(valor) is dict:
            #print(valor)
            registro += diciterator(valor)
        else:
            registro.append(valor)
        #print(clave, type(valor))
    print(registro)    
    print("-------------------------")
    total.append(registro)
# Out:
# ['Administración Digital (JCCM)', 'Administración Digital (JCCM)']
# -------------------------
# ['Agencia Estatal de Investigación', 'Agencia Estatal de Investigación']
# -------------------------
# ['Agencia Gallega de Innovación (GAIN)', 'Agencia Gallega de Innovación (GAIN)']
# -------------------------
# ['Agencia IDEA', 'Agencia IDEA']
# -------------------------
# ['Agencia de Modernización Tecnológica de Galicia (AMTEGA)', 'Agencia de Modernización Tecnológica de Galicia (AMTEGA)']
# -------------------------
# ['Agencia del Agua (JCCM)', 'Agencia del Agua (JCCM)']
# -------------------------
# ['Aguas de Galicia', 'Aguas de Galicia']
# -------------------------
# ['CDTI', 'CDTI']
# -------------------------
# ['Ciudad Autónoma de Melilla', 'Ciudad Autónoma de Melilla']
# -------------------------
# ['Comunidad Autónoma Castilla-La Mancha', 'Comunidad Autónoma Castilla-La Mancha']
# -------------------------
# ['Comunidad Autónoma de Canarias. Dirección General de Promoción Económica', 'Comunidad Autónoma de Canarias. Dirección General de Promoción Económica']
# -------------------------
# ['Comunidad Autónoma de Canarias. Viceconsejería de Lucha contra el Cambio Climático y Transición Ecológica', 'Comunidad Autónoma de Canarias. Viceconsejería de Lucha contra el Cambio Climático y Transición Ecológica']
# -------------------------
# ['Comunidad Autónoma de la Región de Murcia', 'Comunidad Autónoma de la Región de Murcia']
# -------------------------
# ['Comunidad Foral de Navarra', 'Comunidad Foral de Navarra']
# -------------------------
# ['Comunidad de Madrid', 'Comunidad de Madrid']
# -------------------------
# ['Consejería de Admistración Autonómica, Medio Ambiente y Cambio Climático (Principado de Asturias)', 'Consejería de Admistración Autonómica, Medio Ambiente y Cambio Climático (Principado de Asturias)']
# -------------------------
# ['Consejería de Educación (Principado de Asturias)', 'Consejería de Educación (Principado de Asturias)']
# -------------------------
# ['Consejería de Medio Rural y Cohesión Territorial (Principado de Asturias)', 'Consejería de Medio Rural y Cohesión Territorial (Principado de Asturias)']
# -------------------------
# ['Consejería de Salud (Principado de Asturias)', 'Consejería de Salud (Principado de Asturias)']
# -------------------------
# ['Consejería de Salud – Servicio de Salud del Principado de Asturias', 'Consejería de Salud – Servicio de Salud del Principado de Asturias']
# -------------------------
# ['Consejería de la Presidencia (Principado de Asturias)', 'Consejería de la Presidencia (Principado de Asturias)']
# -------------------------
# ['Cámara de España', 'Cámara de España']
# -------------------------
# ['DG Empresas, Competitividad e Internacionalización (JCCM)', 'DG Empresas, Competitividad e Internacionalización (JCCM)']
# -------------------------
# ['DG Turismo, Comercio y Artesanía (JCCM)', 'DG Turismo, Comercio y Artesanía (JCCM)']
# -------------------------
# ['DG Universidades, Investigación e Innovación (JCCM)', 'DG Universidades, Investigación e Innovación (JCCM)']
# -------------------------
# ['DG de Cooperación Autonómica y Local', 'DG de Cooperación Autonómica y Local']
# -------------------------
# ['Delegación del Gobierno de Canarias', 'Delegación del Gobierno de Canarias']
# -------------------------
# ['Diputación Foral de Guipúzcoa', 'Diputación Foral de Guipúzcoa']
# -------------------------
# ['Diputación Foral de Álava', 'Diputación Foral de Álava']
# -------------------------
# ['Diputación de Vizcaya', 'Diputación de Vizcaya']
# -------------------------
# ['Dirección General de Comercio y Consumo (Cantabria)', 'Dirección General de Comercio y Consumo (Cantabria)']
# -------------------------
# ['Dirección General de Obras Públicas (Cantabria)', 'Dirección General de Obras Públicas (Cantabria)']
# -------------------------
# ['Dirección General de Organización y Tecnología (Cantabria)', 'Dirección General de Organización y Tecnología (Cantabria)']
# -------------------------
# ['Generalitat Valenciana', 'Generalitat Valenciana']
# -------------------------
# ['Generalitat de Catalunya. Agencia para la Competitividad de la Empresa', 'Generalitat de Catalunya. Agencia para la Competitividad de la Empresa']
# -------------------------
# ['Generalitat de Catalunya. Departamento de Economía', 'Generalitat de Catalunya. Departamento de Economía']
# -------------------------
# ['Generalitat de Catalunya. Departamento de Educación', 'Generalitat de Catalunya. Departamento de Educación']
# -------------------------
# ['Generalitat de Catalunya. Departamento de Investigación y Universidades', 'Generalitat de Catalunya. Departamento de Investigación y Universidades']
# -------------------------
# ['Generalitat de Catalunya. Departamento de Salud', 'Generalitat de Catalunya. Departamento de Salud']
# -------------------------
# -------------------------
# ['Junta de Andalucía. S.G. Vivienda', 'Junta de Andalucía. S.G. Vivienda']
# -------------------------
# ['Junta de Castilla y León', 'Junta de Castilla y León']
# -------------------------
# ['Junta de Castilla y León. Agencia Protección Civil ', 'Junta de Castilla y León. Agencia Protección Civil ']
# -------------------------
# ['Junta de Castilla y León. D.G. Centros, Planificación y Ordenación Educativa', 'Junta de Castilla y León. D.G. Centros, Planificación y Ordenación Educativa']
# -------------------------
# ['Junta de Castilla y León. D.G. Infraestructuras y Tec. Información - SACYL', 'Junta de Castilla y León. D.G. Infraestructuras y Tec. Información - SACYL']
# -------------------------
# ['Junta de Castilla y León. D.G. Política Económica y Competitividad', 'Junta de Castilla y León. D.G. Política Económica y Competitividad']
# -------------------------
# ['Junta de Castilla y León. D.G. Telecomunicaciones y Transformación Digital', 'Junta de Castilla y León. D.G. Telecomunicaciones y Transformación Digital']
# -------------------------
# ['Junta de Castilla y León. D.G. Universidades e Investigación', 'Junta de Castilla y León. D.G. Universidades e Investigación']
# -------------------------
# ['Junta de Castilla y León. Eren', 'Junta de Castilla y León. Eren']
# -------------------------
# ['Junta de Castilla y León. Fundación Patrimonio Natural', 'Junta de Castilla y León. Fundación Patrimonio Natural']
# -------------------------
# ['Junta de Castilla y León. Instituto para la Competitividad Empresarial', 'Junta de Castilla y León. Instituto para la Competitividad Empresarial']
# -------------------------
# ['Junta de Castilla y León. SG de Economía y Hacienda', 'Junta de Castilla y León. SG de Economía y Hacienda']
# -------------------------
# ['Junta de Castilla y León. Somacyl', 'Junta de Castilla y León. Somacyl']
# -------------------------
# ['Junta de Extremadura', 'Junta de Extremadura']
# -------------------------
# ['Principado de Asturias', 'Principado de Asturias']
# -------------------------
# ['Red.es', 'Red.es']
# -------------------------
# ['SETELECO', 'SETELECO']
# -------------------------
# ['SG Bienestar Social (JCCM)', 'SG Bienestar Social (JCCM)']
# -------------------------
# ['SG Desarrollo Urbano', 'SG Desarrollo Urbano']
# -------------------------
# ['SG Educación, Cultura y Deportes (JCCM)', 'SG Educación, Cultura y Deportes (JCCM)']
# -------------------------
# ['SG Fomento (JCCM)', 'SG Fomento (JCCM)']
# -------------------------
# ['SG Hacienda y AAPP (JCCM)', 'SG Hacienda y AAPP (JCCM)']
# -------------------------
# ['SG SESCAM (JCCM)', 'SG SESCAM (JCCM)']
# -------------------------
# ['SG Sanidad (JCCM)', 'SG Sanidad (JCCM)']
# -------------------------
# ['Secretaría General de Innovación', 'Secretaría General de Innovación']
# -------------------------
# ['Subdirección General de Incentivos Regionales', 'Subdirección General de Incentivos Regionales']
# -------------------------
# ['Subdirección General de Internacionalización de la Ciencia y la Investigación', 'Subdirección General de Internacionalización de la Ciencia y la Investigación']
# -------------------------
# ['UCLM', 'UCLM']
# -------------------------
# ['Viceconsejería de Medio Ambiente (JCCM)', 'Viceconsejería de Medio Ambiente (JCCM)']
# -------------------------
# ['Xunta de Galicia', 'Xunta de Galicia']
# -------------------------
# ['procesa', 'procesa']
# -------------------------

# %%
registro
# Out:
# ['procesa', 'procesa']
