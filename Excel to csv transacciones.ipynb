# %%
import csv
import pandas as pd

# %%
fields =['cod_poperativo', 'cod_operacion', 'cod_transaccion', 'bloqueada', 'tipo_transaccion', 'transaccion_hibrida', 'destinatario', 'gasto_total', 'gasto_total_subvencionable', 'gasto_publico_subvencionable', 'f_pago_efectivo', 'gastos_compra_terrenos', 'importe_iva_no_recuperable', 'contratacion_publica', 'certificado_ingresos', 'concepto_gasto', 'gastos_fuera_zona', 'gastos_fuera_union', 'importe_factura', 'nif_emisor', 'num_factura', 'num_ope_contable', 'f_factura', 'numero_serie', 'gastos_subv_comision', 'gasto_publico_verif', 'gastos_subv_becu', 'gasto_publico_becu', 'cod_baremo', 'cantidad_unidad_becu', 'gastos_subv_alzado', 'gasto_pub_alzado', 'cod_pago', 'gastos_subv_fija', 'gasto_pub_fija', 'gastos_fse', 'imp_especie', 'cod_transaccion_modif', 'motivo_modif', 'clase_modif', 'cod_control', 'cod_plac', 'cod_control_art125', 'imp_origen_gasto', 'imp_remu_basica', 'imp_rendimiento', 'cambios_ip', 'cod_etiqueta', 'cod_contrato', 'version_cont', 'gasto_abonado']
dic = dict.fromkeys(fields)
dic
# Out:
# {'cod_poperativo': None,
#  'cod_operacion': None,
#  'cod_transaccion': None,
#  'bloqueada': None,
#  'tipo_transaccion': None,
#  'transaccion_hibrida': None,
#  'destinatario': None,
#  'gasto_total': None,
#  'gasto_total_subvencionable': None,
#  'gasto_publico_subvencionable': None,
#  'f_pago_efectivo': None,
#  'gastos_compra_terrenos': None,
#  'importe_iva_no_recuperable': None,
#  'contratacion_publica': None,
#  'certificado_ingresos': None,
#  'concepto_gasto': None,
#  'gastos_fuera_zona': None,
#  'gastos_fuera_union': None,
#  'importe_factura': None,
#  'nif_emisor': None,
#  'num_factura': None,
#  'num_ope_contable': None,
#  'f_factura': None,
#  'numero_serie': None,
#  'gastos_subv_comision': None,
#  'gasto_publico_verif': None,
#  'gastos_subv_becu': None,
#  'gasto_publico_becu': None,
#  'cod_baremo': None,
#  'cantidad_unidad_becu': None,
#  'gastos_subv_alzado': None,
#  'gasto_pub_alzado': None,
#  'cod_pago': None,
#  'gastos_subv_fija': None,
# ...

# %%
file = "C:/Users/bllanos/Desktop/project1/prueba1/Dec_2021/Ceuta/transacciones_pos/TRANSACCIONES CEUTA - PISTA DE AUDITORIA J2 (Autoguardado)_mods.xls"

# %%
df = pd.read_excel(file, sheet_name="REVISIÓN CON R FINAL")
#df["cod_operacion"] = "REFUERZO-CAPAC-SANITARIA-COVID"
df
# Out:
#    INICIAL cod_poperativo                   cod_operacion  \
# 0       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 1       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 2       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 3       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 4       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 5       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 6       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 7       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 8       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 9       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 10      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 11      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 12      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 13      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 14      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# ...

# %%
df.drop("cod_transaccion 2", axis=1, inplace = True)
df
# Out:
#    INICIAL cod_poperativo                   cod_operacion  \
# 0       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 1       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 2       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 3       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 4       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 5       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 6       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 7       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 8       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 9       CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 10      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 11      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 12      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 13      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# 14      CE             CE  REFUERZO-CAPAC-SANITARIA-COVID
# ...

# %%
with open("C:/Users/bllanos/Desktop/project1/prueba1/Julio_2021/Transacciones_positivas/Ceuta/Ceuta_TB1.csv") as f:
    reader = csv.DictReader(f, delimiter=";")
    for row in reader:
        li = []
        for k in row:
            li.append(k)
        print(li)
        break
# Out:
# ['cod_poperativo', 'cod_operacion', 'cod_transaccion', 'bloqueada', 'tipo_transaccion', 'transaccion_hibrida', 'destinatario', 'gasto_total', 'gasto_total_subvencionable', 'gasto_publico_subvencionable', 'f_pago_efectivo', 'gastos_compra_terrenos', 'importe_iva_no_recuperable', 'contratacion_publica', 'certificado_ingresos', 'concepto_gasto', 'gastos_fuera_zona', 'gastos_fuera_union', 'importe_factura', 'nif_emisor', 'num_factura', 'num_ope_contable', 'f_factura', 'numero_serie', 'gastos_subv_comision', 'gasto_publico_verif', 'gastos_subv_becu', 'gasto_publico_becu', 'cod_baremo', 'cantidad_unidad_becu', 'gastos_subv_alzado', 'gasto_pub_alzado', 'cod_pago', 'gastos_subv_fija', 'gasto_pub_fija', 'gastos_fse', 'imp_especie', 'cod_transaccion_modif', 'motivo_modif', 'clase_modif', 'cod_control', 'cod_plac', 'cod_control_art125', 'imp_origen_gasto', 'imp_remu_basica', 'imp_rendimiento', 'cambios_ip', 'cod_etiqueta', 'cod_contrato', 'version_cont', 'gasto_abonado']
