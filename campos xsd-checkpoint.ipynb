# %%
from lxml import etree, objectify

# %%
#import pandas as pd

# %%
file = "XSDs/organismos.xsd"

# %%
file2 = "XSDs/transacciones.xsd"

# %%
file3 = "XSDs/operaciones.xsd"

# %%
file4= "XSDs/destinatarios.xsd"

# %%
file5= "XSDs/contratos.xsd"

# %%
chosed_file = file4
print(chosed_file)
# Out:
# XSDs/destinatarios.xsd

# %%
f = open(chosed_file, "r")
f
f.close()

# %%
#tree = etree.parse(chosed_file)
#etree.tostring(tree)

# %%
#root = tree.getroot()
#root.tag

# %%
#parser = etree.XMLParser(remove_blank_text=True)

# %%
#root = etree.XML(etree.tostring(tree), parser)

# %%
#print(etree.tostring(root, pretty_print=True))

# %%
## test 2 XSLT

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse(chosed_file)
root = tree.getroot()

# %%
root.tag
# Out:
# '{http://www.w3.org/2001/XMLSchema}schema'

# %%
root.attrib
# Out:
# {}

# %%
for child in root:
    print(child.tag)
    print(child.attrib)
# Out:
# {http://www.w3.org/2001/XMLSchema}element
# {'name': 'destinatarios'}

# %%
root[0].attrib
# Out:
# {'name': 'destinatarios'}

# %%
for child in root.iter():
    print(child.attrib)
# Out:
# {}
# {'name': 'destinatarios'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'destinatario'}
# {}
# {}
# {'name': 'cod_destinatario'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '10'}
# {'name': 'destinatario_pago'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '255'}
# {'name': 'nif'}
# {}
# {'base': 'xs:string'}
# {'value': '1'}
# {'value': '30'}
# {'name': 'clasificacion_pagos', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': ''}
# {'value': '11'}
# {'value': '12'}
# {'value': '15'}
# {'value': '2'}
# {'value': '3'}
# {'value': '4'}
# {'name': 'clasificacion_ac', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': ''}
# {'value': '0'}
# {'value': '11'}
# {'value': '12'}
# {'value': '13'}
# {'value': '14'}
# {'value': '15'}
# {'value': '16'}
# {'value': '2'}
# {'value': '3'}
# {'value': '4'}
# {'name': 'persona_de_contacto', 'minOccurs': '0'}
# {}
# {}
# {'name': 'nombre', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '255'}
# {'name': 'direccion', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '200'}
# {'name': 'provincia', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'municipio', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'correo_corporativo', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '200'}
# {'name': 'telefono_1', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '15'}
# {'name': 'telefono_2', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '15'}
# {'name': 'cargo', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '200'}
# {'name': 'codigo_postal', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '5'}
# {'name': 'ciudad', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '10'}
# {'name': 'correo_e', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '200'}
# {'name': 'fax', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '25'}
# {'name': 'cuentas_corrientes', 'minOccurs': '0'}
# {}
# {'maxOccurs': 'unbounded'}
# {'name': 'cuenta_corriente'}
# {}
# {}
# {'name': 'cod_banco'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '6'}
# {'name': 'ordinal_bancario', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '20'}
# {'name': 'iban'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '40'}
# {'name': 'bic', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '20'}
# {'name': 'nif', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': '0'}
# {'value': '30'}
# {'name': 'activa'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'name': 'pignorada', 'minOccurs': '0'}
# {}
# {'base': 'xs:string'}
# {'value': 'S'}
# {'value': 'N'}
# {'value': ''}
# {'name': 'tipo_de_pago', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': ''}
# {'value': '01'}
# {'value': '06'}
# {'value': '30'}
# {'name': 'forma_de_pago', 'minOccurs': '0'}
# {}
# {}
# {}
# {}
# {}
# {'base': 'xs:string'}
# {'value': ''}
# {'value': '03'}
# {'value': '06'}
# {'value': '30'}

# %%
import xmlschema
schema = xmlschema.XMLSchema(chosed_file)
dir(schema)
# Out:
# ['BASE_SCHEMAS',
#  'BUILDERS',
#  'BUILDERS_MAP',
#  'XSD_VERSION',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_get_xpath_namespaces',
#  '_global_views',
#  '_import_namespace',
#  '_locations',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_root_elements',
#  '_validate_references',
#  '_xpath_lock',
#  '_xpath_parse',
#  '_xpath_parser',
#  'all_errors',
#  'allow',
#  'attrib',
#  'attribute_form_default',
#  'attribute_groups',
#  'attributes',
#  'base_url',
#  'block_default',
#  'build',
#  'built',
#  'builtin_types',
#  'check_schema',
#  'check_validator',
#  'clear',
#  'complex_types',
#  'converter',
#  'copy',
#  'count',
#  'create_any_attribute_group',
#  'create_any_content_group',
#  'create_any_type',
#  'create_bindings',
#  'create_element',
#  'create_empty_attribute_group',
#  'create_empty_content_group',
#  'create_meta_schema',
#  'decode',
#  'default_attributes',
#  'default_namespace',
#  'default_open_content',
#  'defuse',
#  'elem',
#  'element_form_default',
#  'elements',
#  'encode',
#  'errors',
#  'export',
#  'fallback_locations',
#  'final_default',
#  'find',
#  'findall',
#  'get',
#  'get_converter',
#  'get_element',
#  'get_locations',
#  'get_schema',
#  'get_text',
#  'groups',
#  'id',
#  'identities',
#  'import_schema',
#  'imports',
#  'include_schema',
#  'includes',
#  'index',
#  'is_valid',
#  'iter',
#  'iter_components',
#  'iter_decode',
#  'iter_encode',
#  'iter_errors',
#  'iter_globals',
#  'iterchildren',
#  'iterfind',
#  'locations',
#  'maps',
#  'meta_schema',
#  'name',
#  'namespaces',
#  'no_namespace_schema_location',
#  'notations',
#  'override',
#  'parse_error',
#  'raw_decoder',
#  'redefine',
#  'resolve_qname',
#  'root',
#  'root_elements',
#  'schema_location',
#  'simple_types',
#  'source',
#  'substitution_groups',
#  'tag',
#  'tail',
#  'target_namespace',
#  'target_prefix',
#  'text',
#  'timeout',
#  'to_dict',
#  'to_etree',
#  'to_objects',
#  'types',
#  'url',
#  'use_meta',
#  'validate',
#  'validation',
#  'validation_attempted',
#  'validation_error',
#  'validity',
#  'version',
#  'version_check',
#  'warnings',
#  'xpath_default_namespace',
#  'xpath_proxy',
#  'xpath_tokens',
#  'xsd_version']

# %%
schema.types
# Out:
# NamespaceView({})

# %%
for xsd_component in schema.iter():
    print(type(xsd_component))
    print(dir(xsd_component))
    #print(xsd_component.get_type())
    print("-----")
# Out:
# <class 'xmlschema.validators.schema.XMLSchema10'>
# ['BASE_SCHEMAS', 'BUILDERS', 'BUILDERS_MAP', 'XSD_VERSION', '__abstractmethods__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_get_xpath_namespaces', '_global_views', '_import_namespace', '_locations', '_parse_imports', '_parse_inclusions', '_parse_xpath_default_namespace', '_root_elements', '_validate_references', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'all_errors', 'allow', 'attrib', 'attribute_form_default', 'attribute_groups', 'attributes', 'base_url', 'block_default', 'build', 'built', 'builtin_types', 'check_schema', 'check_validator', 'clear', 'complex_types', 'converter', 'copy', 'count', 'create_any_attribute_group', 'create_any_content_group', 'create_any_type', 'create_bindings', 'create_element', 'create_empty_attribute_group', 'create_empty_content_group', 'create_meta_schema', 'decode', 'default_attributes', 'default_namespace', 'default_open_content', 'defuse', 'elem', 'element_form_default', 'elements', 'encode', 'errors', 'export', 'fallback_locations', 'final_default', 'find', 'findall', 'get', 'get_converter', 'get_element', 'get_locations', 'get_schema', 'get_text', 'groups', 'id', 'identities', 'import_schema', 'imports', 'include_schema', 'includes', 'index', 'is_valid', 'iter', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_globals', 'iterchildren', 'iterfind', 'locations', 'maps', 'meta_schema', 'name', 'namespaces', 'no_namespace_schema_location', 'notations', 'override', 'parse_error', 'raw_decoder', 'redefine', 'resolve_qname', 'root', 'root_elements', 'schema_location', 'simple_types', 'source', 'substitution_groups', 'tag', 'tail', 'target_namespace', 'target_prefix', 'text', 'timeout', 'to_dict', 'to_etree', 'to_objects', 'types', 'url', 'use_meta', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'version', 'version_check', 'warnings', 'xpath_default_namespace', 'xpath_proxy', 'xpath_tokens', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ...
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# ['_ADMITTED_TAGS', '_REGEX_SPACE', '_REGEX_SPACES', '__abstractmethods__', '__annotations__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_block', '_final', '_get_xpath_namespaces', '_head_type', '_parse', '_parse_attributes', '_parse_child_component', '_parse_constraints', '_parse_particle', '_parse_reference', '_parse_substitution_group', '_parse_target_namespace', '_parse_type', '_parse_xpath_default_namespace', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'abstract', 'all_errors', 'alternatives', 'annotation', 'any_atomic_type', 'any_simple_type', 'any_type', 'attrib', 'attributes', 'binding', 'block', 'built', 'check_dynamic_context', 'copy', 'count', 'data_value', 'decode', 'default', 'default_namespace', 'effective_max_occurs', 'effective_min_occurs', 'elem', 'encode', 'errors', 'final', 'find', 'findall', 'fixed', 'form', 'get', 'get_attribute', 'get_attributes', 'get_binding', 'get_global', 'get_matching_item', 'get_parent_type', 'get_path', 'get_type', 'has_occurs_restriction', 'id', 'identities', 'index', 'inheritable', 'is_ambiguous', 'is_consistent', 'is_emptiable', 'is_empty', 'is_global', 'is_matching', 'is_missing', 'is_multiple', 'is_over', 'is_overlap', 'is_override', 'is_restriction', 'is_single', 'is_univocal', 'is_valid', 'iter', 'iter_ancestors', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_substitutes', 'iterchildren', 'iterfind', 'local_name', 'maps', 'match', 'max_occurs', 'min_occurs', 'name', 'namespaces', 'nillable', 'occurs', 'parent', 'parse_error', 'prefixed_name', 'qualified', 'qualified_name', 'redefine', 'ref', 'schema', 'schema_elem', 'scope', 'source', 'start_identities', 'stop_identities', 'substitution_group', 'tag', 'tail', 'target_namespace', 'text', 'to_objects', 'tostring', 'type', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'value_constraint', 'xpath_default_namespace', 'xpath_proxy', 'xsd_version']
# -----

# %%
#dir(xsd_component)
method_list = [func for func in dir(schema) if callable(getattr(schema, func)) and not func.startswith("__")]

# %%
method_list
# Out:
# ['_get_xpath_namespaces',
#  '_import_namespace',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_validate_references',
#  '_xpath_parse',
#  'build',
#  'builtin_types',
#  'check_schema',
#  'check_validator',
#  'clear',
#  'converter',
#  'copy',
#  'count',
#  'create_any_attribute_group',
#  'create_any_content_group',
#  'create_any_type',
#  'create_bindings',
#  'create_element',
#  'create_empty_attribute_group',
#  'create_empty_content_group',
#  'create_meta_schema',
#  'decode',
#  'encode',
#  'export',
#  'find',
#  'findall',
#  'get',
#  'get_converter',
#  'get_element',
#  'get_locations',
#  'get_schema',
#  'get_text',
#  'import_schema',
#  'include_schema',
#  'index',
#  'is_valid',
#  'iter',
#  'iter_components',
#  'iter_decode',
#  'iter_encode',
#  'iter_errors',
#  'iter_globals',
#  'iterchildren',
#  'iterfind',
#  'parse_error',
#  'raw_decoder',
#  'resolve_qname',
#  'to_dict',
#  'to_etree',
#  'to_objects',
#  'validate',
#  'validation_error',
#  'version_check']

# %%
for item in schema.iter_components():
    print(dir(item))
    break
# Out:
# ['BASE_SCHEMAS', 'BUILDERS', 'BUILDERS_MAP', 'XSD_VERSION', '__abstractmethods__', '__class__', '__contains__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_get_xpath_namespaces', '_global_views', '_import_namespace', '_locations', '_parse_imports', '_parse_inclusions', '_parse_xpath_default_namespace', '_root_elements', '_validate_references', '_xpath_lock', '_xpath_parse', '_xpath_parser', 'all_errors', 'allow', 'attrib', 'attribute_form_default', 'attribute_groups', 'attributes', 'base_url', 'block_default', 'build', 'built', 'builtin_types', 'check_schema', 'check_validator', 'clear', 'complex_types', 'converter', 'copy', 'count', 'create_any_attribute_group', 'create_any_content_group', 'create_any_type', 'create_bindings', 'create_element', 'create_empty_attribute_group', 'create_empty_content_group', 'create_meta_schema', 'decode', 'default_attributes', 'default_namespace', 'default_open_content', 'defuse', 'elem', 'element_form_default', 'elements', 'encode', 'errors', 'export', 'fallback_locations', 'final_default', 'find', 'findall', 'get', 'get_converter', 'get_element', 'get_locations', 'get_schema', 'get_text', 'groups', 'id', 'identities', 'import_schema', 'imports', 'include_schema', 'includes', 'index', 'is_valid', 'iter', 'iter_components', 'iter_decode', 'iter_encode', 'iter_errors', 'iter_globals', 'iterchildren', 'iterfind', 'locations', 'maps', 'meta_schema', 'name', 'namespaces', 'no_namespace_schema_location', 'notations', 'override', 'parse_error', 'raw_decoder', 'redefine', 'resolve_qname', 'root', 'root_elements', 'schema_location', 'simple_types', 'source', 'substitution_groups', 'tag', 'tail', 'target_namespace', 'target_prefix', 'text', 'timeout', 'to_dict', 'to_etree', 'to_objects', 'types', 'url', 'use_meta', 'validate', 'validation', 'validation_attempted', 'validation_error', 'validity', 'version', 'version_check', 'warnings', 'xpath_default_namespace', 'xpath_proxy', 'xpath_tokens', 'xsd_version']

# %%
for item in schema.iter():
    print(item)
    print(list(item.iter()))
    try:
        print(item.get_text())
    except:
        pass
    print("----")
# Out:
# XMLSchema10(name='destinatarios.xsd', namespace='')
# [XMLSchema10(name='destinatarios.xsd', namespace=''), XsdElement(name='destinatarios', occurs=[1, 1]), XsdElement(name='destinatario', occurs=[1, 1]), XsdElement(name='cod_destinatario', occurs=[1, 1]), XsdElement(name='destinatario_pago', occurs=[1, 1]), XsdElement(name='nif', occurs=[1, 1]), XsdElement(name='clasificacion_pagos', occurs=[0, 1]), XsdElement(name='clasificacion_ac', occurs=[0, 1]), XsdElement(name='persona_de_contacto', occurs=[0, 1]), XsdElement(name='nombre', occurs=[0, 1]), XsdElement(name='direccion', occurs=[0, 1]), XsdElement(name='provincia', occurs=[0, 1]), XsdElement(name='municipio', occurs=[0, 1]), XsdElement(name='correo_corporativo', occurs=[0, 1]), XsdElement(name='telefono_1', occurs=[0, 1]), XsdElement(name='telefono_2', occurs=[0, 1]), XsdElement(name='cargo', occurs=[0, 1]), XsdElement(name='codigo_postal', occurs=[0, 1]), XsdElement(name='ciudad', occurs=[0, 1]), XsdElement(name='correo_e', occurs=[0, 1]), XsdElement(name='fax', occurs=[0, 1]), XsdElement(name='cuentas_corrientes', occurs=[0, 1]), XsdElement(name='cuenta_corriente', occurs=[1, 1]), XsdElement(name='cod_banco', occurs=[1, 1]), XsdElement(name='ordinal_bancario', occurs=[0, 1]), XsdElement(name='iban', occurs=[1, 1]), XsdElement(name='bic', occurs=[0, 1]), XsdElement(name='nif', occurs=[0, 1]), XsdElement(name='activa', occurs=[1, 1]), XsdElement(name='pignorada', occurs=[0, 1]), XsdElement(name='tipo_de_pago', occurs=[0, 1]), XsdElement(name='forma_de_pago', occurs=[0, 1])]
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- edited with XMLSpy v2010 rel. 2 (http://www.altova.com) by IGAE Intervención Gral. de la Admón. Del Estado (IGAE Intervención Gral. de la Admón. Del Estado) -->
# <!--W3C Schema generated by XMLSpy v2010 rel. 2 (http://www.altova.com)-->
# <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
# 	<xs:element name="destinatarios">
# 		<xs:complexType>
# 			<xs:sequence maxOccurs="unbounded">
# 				<xs:element name="destinatario">
# 					<xs:complexType>
# 						<xs:sequence>
#
# 							<xs:element name="cod_destinatario">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="10"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<xs:element name="destinatario_pago">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="255"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<xs:element name="nif">
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:minLength value="1"/>
# 										<xs:maxLength value="30"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<xs:element name="clasificacion_pagos" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>11 - Estado</xs:documentation>
# 									<xs:documentation>12 - OOAA</xs:documentation>
# 									<xs:documentation>15 - Pagos al exterior</xs:documentation>
# 									<xs:documentation>2 - CCAA</xs:documentation>
# 									<xs:documentation>3 - Ayuntamientos</xs:documentation>
# 									<xs:documentation>4 - Resto</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value=""/>
# 										<xs:enumeration value="11"/>
# 										<xs:enumeration value="12"/>
# 										<xs:enumeration value="15"/>
# 										<xs:enumeration value="2"/>
# 										<xs:enumeration value="3"/>
# 										<xs:enumeration value="4"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
# 							<xs:element name="clasificacion_ac" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>0 - Sin clasificar</xs:documentation>
# 									<xs:documentation>11 - Estado</xs:documentation>
# 									<xs:documentation>12 - Organismos Autónomos</xs:documentation>
# 									<xs:documentation>13 - Empresas Públicas e Instituciones</xs:documentation>
# 									<xs:documentation>14 - MINECO (ES127003, ES127004, ES127007)</xs:documentation>
# 									<xs:documentation>15 - TGSS-FOGASA</xs:documentation>
# 									<xs:documentation>16 - SEPE</xs:documentation>
# 									<xs:documentation>2 - CC.AA.</xs:documentation>
# 									<xs:documentation>3 - CC.LL</xs:documentation>
# 									<xs:documentation>4 - Otros</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value=""/>
# 										<xs:enumeration value="0"/>
# 										<xs:enumeration value="11"/>
# 										<xs:enumeration value="12"/>
# 										<xs:enumeration value="13"/>
# 										<xs:enumeration value="14"/>
# 										<xs:enumeration value="15"/>
# 										<xs:enumeration value="16"/>
# 										<xs:enumeration value="2"/>
# 										<xs:enumeration value="3"/>
# 										<xs:enumeration value="4"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
#
# 							<xs:element name="persona_de_contacto" minOccurs="0">
# 							<xs:complexType>
# 							<xs:sequence>
# 								<xs:element name="nombre" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="255"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="direccion" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="200"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="provincia" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="10"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="municipio" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="10"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="correo_corporativo" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="200"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="telefono_1" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="15"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								 <xs:element name="telefono_2" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="15"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								 <xs:element name="cargo" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="200"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="codigo_postal" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="5"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="ciudad" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="10"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="correo_e" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="200"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
#
# 								<xs:element name="fax" minOccurs="0">
# 								<xs:simpleType>
# 								<xs:restriction base="xs:string">
# 								<xs:minLength value="0"/>
# 								<xs:maxLength value="25"/>
# 								</xs:restriction>
# 								</xs:simpleType>
# 								</xs:element>
# 							</xs:sequence>
# 							</xs:complexType>
# 							</xs:element>
#
# 							<xs:element name="cuentas_corrientes" minOccurs="0">
# 								<xs:complexType>
# 									<xs:sequence maxOccurs="unbounded">
# 										<xs:element name="cuenta_corriente">
# 											<xs:complexType>
# 												<xs:sequence>
#
# 													<xs:element name="cod_banco">
# 														<xs:simpleType>
# 															<xs:restriction base="xs:string">
# 																<xs:minLength value="0"/>
# 																<xs:maxLength value="6"/>
# 															</xs:restriction>
# 														</xs:simpleType>
# 													</xs:element>
#
# 													<xs:element name="ordinal_bancario" minOccurs="0">
# 														<xs:simpleType>
# 															<xs:restriction base="xs:string">
# 																<xs:minLength value="0"/>
# 																<xs:maxLength value="20"/>
# 															</xs:restriction>
# 														</xs:simpleType>
# 													</xs:element>
#
# 													<xs:element name="iban">
# 														<xs:simpleType>
# 															<xs:restriction base="xs:string">
# 																<xs:minLength value="0"/>
# 																<xs:maxLength value="40"/>
# 															</xs:restriction>
# 														</xs:simpleType>
# 													</xs:element>
# 									              <xs:element name="bic" minOccurs="0">
# 														<xs:simpleType>
# 															<xs:restriction base="xs:string">
# 																<xs:minLength value="0"/>
# 																<xs:maxLength value="20"/>
# 															</xs:restriction>
# 														</xs:simpleType>
# 													</xs:element>
#
# 													<xs:element name="nif" minOccurs="0">
# 														<xs:simpleType>
# 															<xs:restriction base="xs:string">
# 																<xs:minLength value="0"/>
# 																<xs:maxLength value="30"/>
# 															</xs:restriction>
# 														</xs:simpleType>
# 													</xs:element>
#
# 													<xs:element name="activa">
# 														<xs:simpleType>
# 									                   <xs:restriction base="xs:string">
# 										               <xs:enumeration value="S"/>
# 										               <xs:enumeration value="N"/>
# 									                   </xs:restriction>
# 								                      </xs:simpleType>
# 													</xs:element>
#
# 													<xs:element name="pignorada" minOccurs="0">
# 														<xs:simpleType>
# 									                   <xs:restriction base="xs:string">
# 										               <xs:enumeration value="S"/>
# 										               <xs:enumeration value="N"/>
# 										               <xs:enumeration value=""/>
# 									                   </xs:restriction>
# 								                      </xs:simpleType>
# 													</xs:element>
#
# 												</xs:sequence>
# 											</xs:complexType>
# 										</xs:element>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
#
#                           <xs:element name="tipo_de_pago" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>01 - Pago directo</xs:documentation>
# 									<xs:documentation>06 - Titular C/C OO.AA estatales</xs:documentation>
# 									<xs:documentation>30 - P.divisa OM. nacional P.F.</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value=""/>
# 										<xs:enumeration value="01"/>
# 										<xs:enumeration value="06"/>
# 										<xs:enumeration value="30"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
#
#                           <xs:element name="forma_de_pago" minOccurs="0">
# 								<xs:annotation>
# 									<xs:documentation>03 - Transferencia bancaria</xs:documentation>
# 									<xs:documentation>06 - Formalización</xs:documentation>
# 									<xs:documentation>30 - P.divisa OM. nacional P.F.</xs:documentation>
# 								</xs:annotation>
# 								<xs:simpleType>
# 									<xs:restriction base="xs:string">
# 										<xs:enumeration value=""/>
# 										<xs:enumeration value="03"/>
# 										<xs:enumeration value="06"/>
# 										<xs:enumeration value="30"/>
# 									</xs:restriction>
# 								</xs:simpleType>
# 							</xs:element>
#
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 			</xs:sequence>
# 		</xs:complexType>
# 	</xs:element>
#
# </xs:schema>
# ----
# XsdElement(name='destinatarios', occurs=[1, 1])
# [XsdElement(name='destinatarios', occurs=[1, 1]), XsdElement(name='destinatario', occurs=[1, 1]), XsdElement(name='cod_destinatario', occurs=[1, 1]), XsdElement(name='destinatario_pago', occurs=[1, 1]), XsdElement(name='nif', occurs=[1, 1]), XsdElement(name='clasificacion_pagos', occurs=[0, 1]), XsdElement(name='clasificacion_ac', occurs=[0, 1]), XsdElement(name='persona_de_contacto', occurs=[0, 1]), XsdElement(name='nombre', occurs=[0, 1]), XsdElement(name='direccion', occurs=[0, 1]), XsdElement(name='provincia', occurs=[0, 1]), XsdElement(name='municipio', occurs=[0, 1]), XsdElement(name='correo_corporativo', occurs=[0, 1]), XsdElement(name='telefono_1', occurs=[0, 1]), XsdElement(name='telefono_2', occurs=[0, 1]), XsdElement(name='cargo', occurs=[0, 1]), XsdElement(name='codigo_postal', occurs=[0, 1]), XsdElement(name='ciudad', occurs=[0, 1]), XsdElement(name='correo_e', occurs=[0, 1]), XsdElement(name='fax', occurs=[0, 1]), XsdElement(name='cuentas_corrientes', occurs=[0, 1]), XsdElement(name='cuenta_corriente', occurs=[1, 1]), XsdElement(name='cod_banco', occurs=[1, 1]), XsdElement(name='ordinal_bancario', occurs=[0, 1]), XsdElement(name='iban', occurs=[1, 1]), XsdElement(name='bic', occurs=[0, 1]), XsdElement(name='nif', occurs=[0, 1]), XsdElement(name='activa', occurs=[1, 1]), XsdElement(name='pignorada', occurs=[0, 1]), XsdElement(name='tipo_de_pago', occurs=[0, 1]), XsdElement(name='forma_de_pago', occurs=[0, 1])]
# ----
# XsdElement(name='destinatario', occurs=[1, 1])
# [XsdElement(name='destinatario', occurs=[1, 1]), XsdElement(name='cod_destinatario', occurs=[1, 1]), XsdElement(name='destinatario_pago', occurs=[1, 1]), XsdElement(name='nif', occurs=[1, 1]), XsdElement(name='clasificacion_pagos', occurs=[0, 1]), XsdElement(name='clasificacion_ac', occurs=[0, 1]), XsdElement(name='persona_de_contacto', occurs=[0, 1]), XsdElement(name='nombre', occurs=[0, 1]), XsdElement(name='direccion', occurs=[0, 1]), XsdElement(name='provincia', occurs=[0, 1]), XsdElement(name='municipio', occurs=[0, 1]), XsdElement(name='correo_corporativo', occurs=[0, 1]), XsdElement(name='telefono_1', occurs=[0, 1]), XsdElement(name='telefono_2', occurs=[0, 1]), XsdElement(name='cargo', occurs=[0, 1]), XsdElement(name='codigo_postal', occurs=[0, 1]), XsdElement(name='ciudad', occurs=[0, 1]), XsdElement(name='correo_e', occurs=[0, 1]), XsdElement(name='fax', occurs=[0, 1]), XsdElement(name='cuentas_corrientes', occurs=[0, 1]), XsdElement(name='cuenta_corriente', occurs=[1, 1]), XsdElement(name='cod_banco', occurs=[1, 1]), XsdElement(name='ordinal_bancario', occurs=[0, 1]), XsdElement(name='iban', occurs=[1, 1]), XsdElement(name='bic', occurs=[0, 1]), XsdElement(name='nif', occurs=[0, 1]), XsdElement(name='activa', occurs=[1, 1]), XsdElement(name='pignorada', occurs=[0, 1]), XsdElement(name='tipo_de_pago', occurs=[0, 1]), XsdElement(name='forma_de_pago', occurs=[0, 1])]
# ----
# XsdElement(name='cod_destinatario', occurs=[1, 1])
# [XsdElement(name='cod_destinatario', occurs=[1, 1])]
# ----
# XsdElement(name='destinatario_pago', occurs=[1, 1])
# [XsdElement(name='destinatario_pago', occurs=[1, 1])]
# ----
# XsdElement(name='nif', occurs=[1, 1])
# [XsdElement(name='nif', occurs=[1, 1])]
# ----
# XsdElement(name='clasificacion_pagos', occurs=[0, 1])
# [XsdElement(name='clasificacion_pagos', occurs=[0, 1])]
# ----
# XsdElement(name='clasificacion_ac', occurs=[0, 1])
# [XsdElement(name='clasificacion_ac', occurs=[0, 1])]
# ----
# XsdElement(name='persona_de_contacto', occurs=[0, 1])
# [XsdElement(name='persona_de_contacto', occurs=[0, 1]), XsdElement(name='nombre', occurs=[0, 1]), XsdElement(name='direccion', occurs=[0, 1]), XsdElement(name='provincia', occurs=[0, 1]), XsdElement(name='municipio', occurs=[0, 1]), XsdElement(name='correo_corporativo', occurs=[0, 1]), XsdElement(name='telefono_1', occurs=[0, 1]), XsdElement(name='telefono_2', occurs=[0, 1]), XsdElement(name='cargo', occurs=[0, 1]), XsdElement(name='codigo_postal', occurs=[0, 1]), XsdElement(name='ciudad', occurs=[0, 1]), XsdElement(name='correo_e', occurs=[0, 1]), XsdElement(name='fax', occurs=[0, 1])]
# ----
# XsdElement(name='nombre', occurs=[0, 1])
# [XsdElement(name='nombre', occurs=[0, 1])]
# ----
# XsdElement(name='direccion', occurs=[0, 1])
# [XsdElement(name='direccion', occurs=[0, 1])]
# ----
# XsdElement(name='provincia', occurs=[0, 1])
# [XsdElement(name='provincia', occurs=[0, 1])]
# ----
# XsdElement(name='municipio', occurs=[0, 1])
# [XsdElement(name='municipio', occurs=[0, 1])]
# ----
# XsdElement(name='correo_corporativo', occurs=[0, 1])
# [XsdElement(name='correo_corporativo', occurs=[0, 1])]
# ----
# XsdElement(name='telefono_1', occurs=[0, 1])
# [XsdElement(name='telefono_1', occurs=[0, 1])]
# ----
# XsdElement(name='telefono_2', occurs=[0, 1])
# [XsdElement(name='telefono_2', occurs=[0, 1])]
# ----
# XsdElement(name='cargo', occurs=[0, 1])
# [XsdElement(name='cargo', occurs=[0, 1])]
# ----
# XsdElement(name='codigo_postal', occurs=[0, 1])
# [XsdElement(name='codigo_postal', occurs=[0, 1])]
# ----
# XsdElement(name='ciudad', occurs=[0, 1])
# [XsdElement(name='ciudad', occurs=[0, 1])]
# ----
# XsdElement(name='correo_e', occurs=[0, 1])
# [XsdElement(name='correo_e', occurs=[0, 1])]
# ----
# XsdElement(name='fax', occurs=[0, 1])
# [XsdElement(name='fax', occurs=[0, 1])]
# ----
# XsdElement(name='cuentas_corrientes', occurs=[0, 1])
# [XsdElement(name='cuentas_corrientes', occurs=[0, 1]), XsdElement(name='cuenta_corriente', occurs=[1, 1]), XsdElement(name='cod_banco', occurs=[1, 1]), XsdElement(name='ordinal_bancario', occurs=[0, 1]), XsdElement(name='iban', occurs=[1, 1]), XsdElement(name='bic', occurs=[0, 1]), XsdElement(name='nif', occurs=[0, 1]), XsdElement(name='activa', occurs=[1, 1]), XsdElement(name='pignorada', occurs=[0, 1])]
# ----
# XsdElement(name='cuenta_corriente', occurs=[1, 1])
# [XsdElement(name='cuenta_corriente', occurs=[1, 1]), XsdElement(name='cod_banco', occurs=[1, 1]), XsdElement(name='ordinal_bancario', occurs=[0, 1]), XsdElement(name='iban', occurs=[1, 1]), XsdElement(name='bic', occurs=[0, 1]), XsdElement(name='nif', occurs=[0, 1]), XsdElement(name='activa', occurs=[1, 1]), XsdElement(name='pignorada', occurs=[0, 1])]
# ----
# XsdElement(name='cod_banco', occurs=[1, 1])
# [XsdElement(name='cod_banco', occurs=[1, 1])]
# ----
# XsdElement(name='ordinal_bancario', occurs=[0, 1])
# [XsdElement(name='ordinal_bancario', occurs=[0, 1])]
# ----
# XsdElement(name='iban', occurs=[1, 1])
# [XsdElement(name='iban', occurs=[1, 1])]
# ----
# XsdElement(name='bic', occurs=[0, 1])
# [XsdElement(name='bic', occurs=[0, 1])]
# ----
# XsdElement(name='nif', occurs=[0, 1])
# [XsdElement(name='nif', occurs=[0, 1])]
# ----
# XsdElement(name='activa', occurs=[1, 1])
# [XsdElement(name='activa', occurs=[1, 1])]
# ----
# XsdElement(name='pignorada', occurs=[0, 1])
# [XsdElement(name='pignorada', occurs=[0, 1])]
# ----
# XsdElement(name='tipo_de_pago', occurs=[0, 1])
# [XsdElement(name='tipo_de_pago', occurs=[0, 1])]
# ----
# XsdElement(name='forma_de_pago', occurs=[0, 1])
# [XsdElement(name='forma_de_pago', occurs=[0, 1])]
# ----

# %%
for item in schema.iter():
    try:
        print(item.to_dict)
    #print(list(item.iter()))
    #print(item.get_text())
        print("----")
    except:
        pass
# Out:
# <bound method XMLSchemaBase.decode of XMLSchema10(name='destinatarios.xsd', namespace='')>
# ----

# %%
#schema.attributes()

# %%
dir(schema)
# Out:
# ['BASE_SCHEMAS',
#  'BUILDERS',
#  'BUILDERS_MAP',
#  'XSD_VERSION',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_get_xpath_namespaces',
#  '_global_views',
#  '_import_namespace',
#  '_locations',
#  '_parse_imports',
#  '_parse_inclusions',
#  '_parse_xpath_default_namespace',
#  '_root_elements',
#  '_validate_references',
#  '_xpath_lock',
#  '_xpath_parse',
#  '_xpath_parser',
#  'all_errors',
#  'allow',
#  'attrib',
#  'attribute_form_default',
#  'attribute_groups',
#  'attributes',
#  'base_url',
#  'block_default',
#  'build',
#  'built',
#  'builtin_types',
#  'check_schema',
#  'check_validator',
#  'clear',
#  'complex_types',
#  'converter',
#  'copy',
#  'count',
#  'create_any_attribute_group',
#  'create_any_content_group',
#  'create_any_type',
#  'create_bindings',
#  'create_element',
#  'create_empty_attribute_group',
#  'create_empty_content_group',
#  'create_meta_schema',
#  'decode',
#  'default_attributes',
#  'default_namespace',
#  'default_open_content',
#  'defuse',
#  'elem',
#  'element_form_default',
#  'elements',
#  'encode',
#  'errors',
#  'export',
#  'fallback_locations',
#  'final_default',
#  'find',
#  'findall',
#  'get',
#  'get_converter',
#  'get_element',
#  'get_locations',
#  'get_schema',
#  'get_text',
#  'groups',
#  'id',
#  'identities',
#  'import_schema',
#  'imports',
#  'include_schema',
#  'includes',
#  'index',
#  'is_valid',
#  'iter',
#  'iter_components',
#  'iter_decode',
#  'iter_encode',
#  'iter_errors',
#  'iter_globals',
#  'iterchildren',
#  'iterfind',
#  'locations',
#  'maps',
#  'meta_schema',
#  'name',
#  'namespaces',
#  'no_namespace_schema_location',
#  'notations',
#  'override',
#  'parse_error',
#  'raw_decoder',
#  'redefine',
#  'resolve_qname',
#  'root',
#  'root_elements',
#  'schema_location',
#  'simple_types',
#  'source',
#  'substitution_groups',
#  'tag',
#  'tail',
#  'target_namespace',
#  'target_prefix',
#  'text',
#  'timeout',
#  'to_dict',
#  'to_etree',
#  'to_objects',
#  'types',
#  'url',
#  'use_meta',
#  'validate',
#  'validation',
#  'validation_attempted',
#  'validation_error',
#  'validity',
#  'version',
#  'version_check',
#  'warnings',
#  'xpath_default_namespace',
#  'xpath_proxy',
#  'xpath_tokens',
#  'xsd_version']

# %%
schema.create_meta_schema()
# Out:
# MetaXMLSchema10(name='XMLSchema.xsd', namespace='http://www.w3.org/2001/XMLSchema')

# %%
aaa =schema.to_dict(chosed_file)
aaa["xs:element"]
# Out:
# {'@name': 'destinatarios',
#  '@abstract': False,
#  '@nillable': False,
#  'xs:complexType': {'@mixed': False,
#   'xs:sequence': {'@maxOccurs': 'unbounded',
#    '@minOccurs': 1,
#    'xs:element': {'@name': 'destinatario',
#     '@maxOccurs': 1,
#     '@minOccurs': 1,
#     '@nillable': False,
#     'xs:complexType': {'@mixed': False,
#      'xs:sequence': {'@maxOccurs': 1,
#       '@minOccurs': 1,
#       'xs:element': [{'@name': 'cod_destinatario',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#        {'@name': 'destinatario_pago',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 255, '@fixed': False}}}},
#        {'@name': 'nif',
#         '@maxOccurs': 1,
#         '@minOccurs': 1,
#         '@nillable': False,
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:minLength': {'@value': 1, '@fixed': False},
#           'xs:maxLength': {'@value': 30, '@fixed': False}}}},
#        {'@name': 'clasificacion_pagos',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': '11 - Estado'},
#           {'$': '12 - OOAA'},
#           {'$': '15 - Pagos al exterior'},
#           {'$': '2 - CCAA'},
#           {'$': '3 - Ayuntamientos'},
#           {'$': '4 - Resto'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': ''},
#            {'@value': '11'},
#            {'@value': '12'},
#            {'@value': '15'},
#            {'@value': '2'},
#            {'@value': '3'},
#            {'@value': '4'}]}}},
#        {'@name': 'clasificacion_ac',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': '0 - Sin clasificar'},
#           {'$': '11 - Estado'},
#           {'$': '12 - Organismos Autónomos'},
#           {'$': '13 - Empresas Públicas e Instituciones'},
#           {'$': '14 - MINECO (ES127003, ES127004, ES127007)'},
#           {'$': '15 - TGSS-FOGASA'},
#           {'$': '16 - SEPE'},
#           {'$': '2 - CC.AA.'},
#           {'$': '3 - CC.LL'},
#           {'$': '4 - Otros'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': ''},
#            {'@value': '0'},
#            {'@value': '11'},
#            {'@value': '12'},
#            {'@value': '13'},
#            {'@value': '14'},
#            {'@value': '15'},
#            {'@value': '16'},
#            {'@value': '2'},
#            {'@value': '3'},
#            {'@value': '4'}]}}},
#        {'@name': 'persona_de_contacto',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 1,
#           '@minOccurs': 1,
#           'xs:element': [{'@name': 'nombre',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 255, '@fixed': False}}}},
#            {'@name': 'direccion',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#            {'@name': 'provincia',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#            {'@name': 'municipio',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#            {'@name': 'correo_corporativo',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#            {'@name': 'telefono_1',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 15, '@fixed': False}}}},
#            {'@name': 'telefono_2',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 15, '@fixed': False}}}},
#            {'@name': 'cargo',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#            {'@name': 'codigo_postal',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 5, '@fixed': False}}}},
#            {'@name': 'ciudad',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#            {'@name': 'correo_e',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#            {'@name': 'fax',
#             '@minOccurs': 0,
#             '@maxOccurs': 1,
#             '@nillable': False,
#             'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#               'xs:minLength': {'@value': 0, '@fixed': False},
#               'xs:maxLength': {'@value': 25, '@fixed': False}}}}]}}},
#        {'@name': 'cuentas_corrientes',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:complexType': {'@mixed': False,
#          'xs:sequence': {'@maxOccurs': 'unbounded',
#           '@minOccurs': 1,
#           'xs:element': {'@name': 'cuenta_corriente',
#            '@maxOccurs': 1,
#            '@minOccurs': 1,
#            '@nillable': False,
#            'xs:complexType': {'@mixed': False,
#             'xs:sequence': {'@maxOccurs': 1,
#              '@minOccurs': 1,
#              'xs:element': [{'@name': 'cod_banco',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 0, '@fixed': False},
#                  'xs:maxLength': {'@value': 6, '@fixed': False}}}},
#               {'@name': 'ordinal_bancario',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 0, '@fixed': False},
#                  'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#               {'@name': 'iban',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 0, '@fixed': False},
#                  'xs:maxLength': {'@value': 40, '@fixed': False}}}},
#               {'@name': 'bic',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 0, '@fixed': False},
#                  'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#               {'@name': 'nif',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:minLength': {'@value': 0, '@fixed': False},
#                  'xs:maxLength': {'@value': 30, '@fixed': False}}}},
#               {'@name': 'activa',
#                '@maxOccurs': 1,
#                '@minOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#               {'@name': 'pignorada',
#                '@minOccurs': 0,
#                '@maxOccurs': 1,
#                '@nillable': False,
#                'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                  'xs:enumeration': [{'@value': 'S'},
#                   {'@value': 'N'},
#                   {'@value': ''}]}}}]}}}}}},
#        {'@name': 'tipo_de_pago',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': '01 - Pago directo'},
#           {'$': '06 - Titular C/C OO.AA estatales'},
#           {'$': '30 - P.divisa OM. nacional P.F.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': ''},
#            {'@value': '01'},
#            {'@value': '06'},
#            {'@value': '30'}]}}},
#        {'@name': 'forma_de_pago',
#         '@minOccurs': 0,
#         '@maxOccurs': 1,
#         '@nillable': False,
#         'xs:annotation': {'xs:documentation': [{'$': '03 - Transferencia bancaria'},
#           {'$': '06 - Formalización'},
#           {'$': '30 - P.divisa OM. nacional P.F.'}]},
#         'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#           'xs:enumeration': [{'@value': ''},
#            {'@value': '03'},
#            {'@value': '06'},
#            {'@value': '30'}]}}}]}}}}}}

# %%
aaa
# Out:
# {'@xmlns:xs': 'http://www.w3.org/2001/XMLSchema',
#  '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#  '@finalDefault': [],
#  '@blockDefault': [],
#  '@attributeFormDefault': 'unqualified',
#  '@elementFormDefault': 'unqualified',
#  'xs:element': {'@name': 'destinatarios',
#   '@abstract': False,
#   '@nillable': False,
#   'xs:complexType': {'@mixed': False,
#    'xs:sequence': {'@maxOccurs': 'unbounded',
#     '@minOccurs': 1,
#     'xs:element': {'@name': 'destinatario',
#      '@maxOccurs': 1,
#      '@minOccurs': 1,
#      '@nillable': False,
#      'xs:complexType': {'@mixed': False,
#       'xs:sequence': {'@maxOccurs': 1,
#        '@minOccurs': 1,
#        'xs:element': [{'@name': 'cod_destinatario',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#         {'@name': 'destinatario_pago',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 255, '@fixed': False}}}},
#         {'@name': 'nif',
#          '@maxOccurs': 1,
#          '@minOccurs': 1,
#          '@nillable': False,
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:minLength': {'@value': 1, '@fixed': False},
#            'xs:maxLength': {'@value': 30, '@fixed': False}}}},
#         {'@name': 'clasificacion_pagos',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': '11 - Estado'},
#            {'$': '12 - OOAA'},
#            {'$': '15 - Pagos al exterior'},
#            {'$': '2 - CCAA'},
#            {'$': '3 - Ayuntamientos'},
#            {'$': '4 - Resto'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': ''},
#             {'@value': '11'},
#             {'@value': '12'},
#             {'@value': '15'},
#             {'@value': '2'},
#             {'@value': '3'},
#             {'@value': '4'}]}}},
#         {'@name': 'clasificacion_ac',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': '0 - Sin clasificar'},
#            {'$': '11 - Estado'},
#            {'$': '12 - Organismos Autónomos'},
#            {'$': '13 - Empresas Públicas e Instituciones'},
#            {'$': '14 - MINECO (ES127003, ES127004, ES127007)'},
#            {'$': '15 - TGSS-FOGASA'},
#            {'$': '16 - SEPE'},
#            {'$': '2 - CC.AA.'},
#            {'$': '3 - CC.LL'},
#            {'$': '4 - Otros'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': ''},
#             {'@value': '0'},
#             {'@value': '11'},
#             {'@value': '12'},
#             {'@value': '13'},
#             {'@value': '14'},
#             {'@value': '15'},
#             {'@value': '16'},
#             {'@value': '2'},
#             {'@value': '3'},
#             {'@value': '4'}]}}},
#         {'@name': 'persona_de_contacto',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:complexType': {'@mixed': False,
#           'xs:sequence': {'@maxOccurs': 1,
#            '@minOccurs': 1,
#            'xs:element': [{'@name': 'nombre',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 255, '@fixed': False}}}},
#             {'@name': 'direccion',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#             {'@name': 'provincia',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#             {'@name': 'municipio',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#             {'@name': 'correo_corporativo',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#             {'@name': 'telefono_1',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 15, '@fixed': False}}}},
#             {'@name': 'telefono_2',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 15, '@fixed': False}}}},
#             {'@name': 'cargo',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#             {'@name': 'codigo_postal',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 5, '@fixed': False}}}},
#             {'@name': 'ciudad',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 10, '@fixed': False}}}},
#             {'@name': 'correo_e',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 200, '@fixed': False}}}},
#             {'@name': 'fax',
#              '@minOccurs': 0,
#              '@maxOccurs': 1,
#              '@nillable': False,
#              'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                'xs:minLength': {'@value': 0, '@fixed': False},
#                'xs:maxLength': {'@value': 25, '@fixed': False}}}}]}}},
#         {'@name': 'cuentas_corrientes',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:complexType': {'@mixed': False,
#           'xs:sequence': {'@maxOccurs': 'unbounded',
#            '@minOccurs': 1,
#            'xs:element': {'@name': 'cuenta_corriente',
#             '@maxOccurs': 1,
#             '@minOccurs': 1,
#             '@nillable': False,
#             'xs:complexType': {'@mixed': False,
#              'xs:sequence': {'@maxOccurs': 1,
#               '@minOccurs': 1,
#               'xs:element': [{'@name': 'cod_banco',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 0, '@fixed': False},
#                   'xs:maxLength': {'@value': 6, '@fixed': False}}}},
#                {'@name': 'ordinal_bancario',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 0, '@fixed': False},
#                   'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#                {'@name': 'iban',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 0, '@fixed': False},
#                   'xs:maxLength': {'@value': 40, '@fixed': False}}}},
#                {'@name': 'bic',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 0, '@fixed': False},
#                   'xs:maxLength': {'@value': 20, '@fixed': False}}}},
#                {'@name': 'nif',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:minLength': {'@value': 0, '@fixed': False},
#                   'xs:maxLength': {'@value': 30, '@fixed': False}}}},
#                {'@name': 'activa',
#                 '@maxOccurs': 1,
#                 '@minOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:enumeration': [{'@value': 'S'}, {'@value': 'N'}]}}},
#                {'@name': 'pignorada',
#                 '@minOccurs': 0,
#                 '@maxOccurs': 1,
#                 '@nillable': False,
#                 'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#                   'xs:enumeration': [{'@value': 'S'},
#                    {'@value': 'N'},
#                    {'@value': ''}]}}}]}}}}}},
#         {'@name': 'tipo_de_pago',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': '01 - Pago directo'},
#            {'$': '06 - Titular C/C OO.AA estatales'},
#            {'$': '30 - P.divisa OM. nacional P.F.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': ''},
#             {'@value': '01'},
#             {'@value': '06'},
#             {'@value': '30'}]}}},
#         {'@name': 'forma_de_pago',
#          '@minOccurs': 0,
#          '@maxOccurs': 1,
#          '@nillable': False,
#          'xs:annotation': {'xs:documentation': [{'$': '03 - Transferencia bancaria'},
#            {'$': '06 - Formalización'},
#            {'$': '30 - P.divisa OM. nacional P.F.'}]},
#          'xs:simpleType': {'xs:restriction': {'@base': 'xs:string',
#            'xs:enumeration': [{'@value': ''},
#             {'@value': '03'},
#             {'@value': '06'},
#             {'@value': '30'}]}}}]}}}}}}}

# %%
for xsd_component in schema.iter():
    print(type(xsd_component))
        
    print("-----")
# Out:
# <class 'xmlschema.validators.schema.XMLSchema10'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----
# <class 'xmlschema.validators.elements.XsdElement'>
# -----

# %%
for xsd_component in schema.iter():
    if 'XMLSchema10' in str(type(xsd_component))  :
        pass
    else:
        #print(type(xsd_component))
        print(xsd_component.name)# , xsd_component.is_emptiable())
        #print(xsd_component.is_emptiable())
        '''
        print(list(xsd_component.iterchildren()))
        print(len(list(xsd_component.iterchildren())))
        print(xsd_component.parent)
        print(dir(xsd_component))
        #print(xsd_component.get_type)'''
        #print("-----")
# Out:
# destinatarios
# destinatario
# cod_destinatario
# destinatario_pago
# nif
# clasificacion_pagos
# clasificacion_ac
# persona_de_contacto
# nombre
# direccion
# provincia
# municipio
# correo_corporativo
# telefono_1
# telefono_2
# cargo
# codigo_postal
# ciudad
# correo_e
# fax
# cuentas_corrientes
# cuenta_corriente
# cod_banco
# ordinal_bancario
# iban
# bic
# nif
# activa
# pignorada
# tipo_de_pago
# forma_de_pago

# %%
for xsd_component in schema.iter():
    if "XsdGroup" in str(type(xsd_component)):
        print(dir(xsd_component))
        print(xsd_component.name)
        
        print("-----")
