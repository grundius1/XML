# %%
import os
import csv
import pandas as pd
import re

# %%
mainfolder = "P:/Regulacion/49 Encargo MinHac 20-22/08 FSUE-DANA/02 Archivos de trabajo/BENEFICIARIOS FSUE DANA"
mainfolder= "C:/Users/bllanos/Desktop/Simulacion_dana"

# %%
beneficiarios = os.listdir(mainfolder)
beneficiarios
# Out:
# ['ABANILLA',
#  'ABARÁN',
#  'AENA',
#  'AGULLENT',
#  'ALBAIDA',
#  'ALBATERA',
#  'ALCAUCÍN-RENUNCIA',
#  'ALCÁZARES',
#  'ALCÓNTAR-JRL',
#  'ALGORFA',
#  'ALHAURÍN DE LA TORRE',
#  'ALMANSA',
#  'ALMERÍA',
#  'ALMORADÍ',
#  'ALQUERIA DE AZNAR',
#  'AP CARTAGENA',
#  'ARBOLEAS',
#  'ARCHENA',
#  'ARCHIDONA',
#  'BAZA',
#  'BENIEL',
#  'BIENSERVIDA-RENUNCIA',
#  'BIGASTRO',
#  'BLANCA',
#  'CAMPOS DEL RÍO',
#  'CARTAGENA',
#  'CASTILLA LA MANCHA',
#  'CASTTRIL-JRL',
#  'CHAUCHINA',
#  'CIEZA',
#  'COCENTAINA',
#  'CONF.HIDRO.JÚCAR-EBB',
#  'CONF.HIDRO.SEGURA-MAC',
#  'COX',
#  'COÍN',
#  'CREVILLENT',
#  'CUEVAS DEL CAMPO',
#  'CULLAR',
#  'data_blp',
#  'DAYA NUEVA',
#  'DENIA',
#  'DGCMTM y AU',
#  'DP ALBACETE',
#  'DP ALMERÍA',
#  'DP GRANADA',
#  'DP MÁLAGA',
#  'FUENTE-ÁLAMO',
#  'GALLARDOS',
#  'GENERALITAT VALENCIANA-EBB',
#  'GRANADA',
#  'HELLÍN',
#  'HOYA GONZALO-JRL',
#  'HUESCAR',
#  'JACARILA',
#  'JUNTA ANDALUCÍA-JOG',
#  'L-OLLERIA-JRL',
#  'LOJA',
#  'LORCA',
#  'LORCHA',
#  'LORQUÍ',
#  'MINISTERIO DEFENSA-EBB',
#  'MOLINA DEL SEGURA',
#  'MOLINICOS',
#  'MONACHIL-JRL',
#  'NERPIO',
#  'NIJAR-MAC',
#  'NOVELDA-EBB',
#  'OJÓS-JRL',
#  'OLULA DEL RÍO',
#  'ONTINYENT',
#  'ONTUR',
#  'ORIHUELA-MAC',
#  'OTOS',
#  'PARCENT',
#  'PILAR DE LA HORADADA',
#  'PINOS GENIL-JRL',
#  'PUEBLA DE DON FADRIQUE',
#  'PUERTO LUMBRERAS',
#  'PULPÍ',
#  'PURCHENA',
#  'REDOVÁN',
#  'REGIÓN DE MURCIA',
#  'RENFE',
#  'RINCÓN DE LA VICTORIA',
#  'RIOJA',
#  'SAN FULGENCIO',
#  'SAN JAVIER',
#  'SANTOMERA',
#  'SERÓN',
#  'TABERNO',
#  'TORRE PACHECO',
#  'TORRES DE COTILLAS',
#  'TOTANA-JRL',
#  'TÍJOLA',
#  'ULEA',
#  'UNIÓN',
#  'URRACAL',
#  'VALLADA',
#  'VILLANUEVA DEL RIO SEGURA',
#  'VIVEROS-JRL',
#  'VÉLEZ',
#  'ZURGENA']

# %%
def organismosdic(folder):
        path = os.path.join(mainfolder,"data_blp/ORGANISMOS.csv")
        dic = {}
        with open(path,encoding="utf8") as f:
            f.readline()
            for line in f.readlines():
                fields = line.split(";")
                try:
                    dic[fields[1]].append((fields[0],fields[2]))
                except KeyError:
                    dic.update({fields[1]:[(fields[0],fields[2].strip())]})
        for k,v in dic.items():
            if len(v) > 1:
                dic.update({k:list(set(v))})
        return dic

# %%
organismos = organismosdic(mainfolder)
#organismos

# %%
def new_organismos(destination_folder, folder, organismo):
    file = os.path.join(destination_folder,folder,"organismos_subir.csv")
    with open(file ,"a") as f:
        if os.path.getsize(file) > 0:
            f.write(f"{organismo};{organismos[organismo][1]};F2020;PRI;5;1;ES;;;;S\n")
        else:
            f.write("NIF;nombre;aplicación;naturaleza;subnaturaleza;clasificacion;persona contacto-pais;persona contacto-provincia;persona contacto-NUT;persona contacto-municipio;rol_adjudicatario\n")
            f.write(f"{organismo};{organismos[organismo][1]};F2020;PRI;5;1;ES;;;;S\n")

# %%
def buscador_organismos(NIF):
    print(NIF)
    print("---")
    '''
    try:
        print(organismos[NIF])
    except KeyError:
        new_organismos(mainfolder,"data_blp",NIF)
    print("---")
    '''

# %%
aytos = ["","CUEVAS DEL CAMPO"]

# %%
lista = []
if aytos == "All" or aytos[0]== "":
        for beneficiario in beneficiarios:
            #print(beneficiario,os.listdir(os.path.join(mainfolder,beneficiario)))
            if "Justificacion_FSUE-DANA.xlsx" in os.listdir(os.path.join(mainfolder,beneficiario)):
                #print(beneficiario,os.listdir(os.path.join(mainfolder,beneficiario)))
                path = os.path.join(mainfolder,beneficiario,"Justificacion_FSUE-DANA.xlsx")
                lista.append((beneficiario,path))
else:
    for ayto in aytos:
        print(ayto)
        r = re.compile(f"(?i){ayto}")
        lista += list(filter(r.findall, beneficiarios)) # Read Note below
        #print(aytos)
    
    for benef in enumerate(lista):
        print(benef)
        lista[benef[0]] = os.path.join(mainfolder,benef[1],"Justificacion_FSUE-DANA.xlsx")
    '''
    for beneficiario in beneficiarios:
        if beneficiario in aytos:
            if "Justificacion_FSUE-DANA.xlsx" in os.listdir(os.path.join(mainfolder,beneficiario)):
                path = os.path.join(mainfolder,beneficiario,"Justificacion_FSUE-DANA.xlsx")
                lista.append(path)
    '''
#print(lista)

# %%
for item in lista:
    print(item)
    transacciones = pd.read_excel(item[1], sheet_name= "2. DATOS BÁSICOS FACTURAS")
    transacciones.dropna(thresh=5,inplace=True)
    transacciones.columns = transacciones.iloc[0]
    transacciones.drop(transacciones.index[0],inplace=True)
    transacciones.reset_index(inplace=True,drop=True)
    display(transacciones)
    buscador_organismos(transacciones[["NIF Proveedor","Proveedor"]].to_dict(orient="records"))
# Out:
# ('ABANILLA', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ABANILLA\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                                  NaN         52
# 1                                  NaN         63
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            69672.5                           57580.58
# 1                           18124.17                           14978.65
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           34836.25
# 1                                            9062.08
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           28790.29
# 1                                            7489.32
#
# 7   Fecha pago factura                    Descriptivo  \
# 0  2020-04-20 00:00:00  Certificación nº 1 marzo 2020
# 1  2020-09-02 00:00:00    Certificación nº 2 y última
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
# 1  a) Restablecimiento del funcionamiento de las ...
#
# 7                         Proveedor NIF Proveedor Número operación contable  \
# 0  ISETEC SERVICIOS INTEGRALES S.L.     B73900896                       NaN
# 1  ISETEC SERVICIOS INTEGRALES S.L.     B73900896                       NaN
#
# 7        Fecha factura Observaciones
# 0  2020-03-11 00:00:00           NaN
# 1  2020-06-22 00:00:00           NaN
# 0    B73900896
# 1    B73900896
# Name: NIF Proveedor, dtype: object
# ---
# 0    ISETEC SERVICIOS INTEGRALES S.L.
# 1    ISETEC SERVICIOS INTEGRALES S.L.
# Name: Proveedor, dtype: object
# ---
# ('ABARÁN', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ABARÁN\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                                    1         14
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            4208.38                               3478
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            3995.74
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            3302.26
#
# 7   Fecha pago factura                         Descriptivo  \
# 0  2020-02-17 00:00:00  LIMPIEZA CON MAQUINARIA Y VEHICULO
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  d) Limpieza de las zonas siniestradas, incluid...
#
# 7                    Proveedor NIF Proveedor Número operación contable  \
# 0  VERTEDERO DE RCDS ABARAN SL     B73889032               22020100686
#
# 7        Fecha factura Observaciones
# 0  2020-02-01 00:00:00           NaN
# 0    B73889032
# Name: NIF Proveedor, dtype: object
# ---
# 0    VERTEDERO DE RCDS ABARAN SL
# Name: Proveedor, dtype: object
# ---
# ('AGULLENT', 'C:/Users/bllanos/Desktop/Simulacion_dana\\AGULLENT\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7  Código Expte de Contratación/Encargo Nº factura  \
# 0                                   NaN   2 000149
# 1                                   NaN   2 000184
# 2                                   NaN      19224
# 3                                   NaN          2
# 4                                   NaN          1
# ..                                  ...        ...
# 57                                  NaN         13
# 58                                  NaN     440233
# 59                                  NaN       2174
# 60                                  NaN          7
# 61                                  NaN         55
#
# 7  Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                              164.92                         136.297521
# 1                                 140                         115.702479
# 2                              194.81                                161
# 3                              837.64                         692.264463
# 4                               568.7                              470.0
# ..                                ...                                ...
# 57                              193.6                                160
# 58                            1099.89                              909.0
# 59                             891.77                                737
# 60                             457.38                                378
# 61                            3523.52                               2912
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                              164.92
# 1                                                 140
# 2                                              194.81
# 3                                              837.64
# 4                                               568.7
# ..                                                ...
# 57                                              193.6
# 58                                            1099.89
# 59                                             891.77
# 60                                             457.38
# 61                                            3523.52
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
#
# 7    Fecha pago factura                                        Descriptivo  \
# 0   2020-02-21 00:00:00               FRA. 2 000149 REPARACIONS FONTANERIA
# 1   2020-02-21 00:00:00               FRA. 2 000184 REPARACIONS FONTANERIA
# 2   2020-02-21 00:00:00                        FRA. 019224 TREBALLS FERRER
# 3   2020-02-21 00:00:00                FRA. EMIT- 2 REPARACIONS ENLLUMENAT
# 4   2020-02-27 00:00:00                             FRA. 1 TREBALLS FUSTER
# ..                  ...                                                ...
# 57  2020-05-26 00:00:00                   FRA. 13 SERVEI CONTENIDORS OBRES
# 58  2020-05-26 00:00:00            FRA. 440233 MATERIALS: HIDROPER FB GRIS
# 59  2020-05-26 00:00:00  FRA.FV-VA19/02174 Extra Limpieza Arrastres, SE...
# 60  2020-02-27 00:00:00  FRA. FV20/0007 HORES DE LA MÀQUINA I DELS CAMI...
# 61  2020-06-11 00:00:00                      FRA. 55 TREBALLS TALA DE PINS
#
# 7         Concepto de gasto (seleccionar de la lista)  \
# 0   a) Restablecimiento del funcionamiento de las ...
# 1   a) Restablecimiento del funcionamiento de las ...
# 2   a) Restablecimiento del funcionamiento de las ...
# 3   a) Restablecimiento del funcionamiento de las ...
# 4   a) Restablecimiento del funcionamiento de las ...
# ..                                                ...
# 57  a) Restablecimiento del funcionamiento de las ...
# 58  a) Restablecimiento del funcionamiento de las ...
# 59  a) Restablecimiento del funcionamiento de las ...
# 60  a) Restablecimiento del funcionamiento de las ...
# 61  a) Restablecimiento del funcionamiento de las ...
#
# 7                                     Proveedor NIF Proveedor  \
# 0                ALBERT GUTIERREZ WALTER GERMAN     48287107X
# 1                ALBERT GUTIERREZ WALTER GERMAN     48287107X
# 2                        TERUEL HERREROS ISIDRO     75060747V
# 3       INSTALACIONES ELECTRICAS SOLER PONS, SL     B96833496
# 4                       CASANOVA JUAN FRANCISCO     52712498V
# ..                                          ...           ...
# 57                   CANO GABALDON MIGUEL ANGEL     52715123C
# 58              INDUSTRIAS QUIMICAS KIMINOR, SL     B09534405
# 59  CIA VALENCIANA INTEGRACION Y DESARROLLO, SL     B96887864
# 60                     NAVARRO NACHER, SALVADOR     52714256G
# 61                     NAVARRO NACHER, SALVADOR     52714256G
#
# 7  Número operación contable        Fecha factura Observaciones
# 0               220200000399  2019-10-05 00:00:00           NaN
# 1               220200000403  2019-12-09 00:00:00           NaN
# 2               220200000429  2019-12-27 00:00:00           NaN
# 3               220200000450  2020-01-02 00:00:00           NaN
# 4               220200000742  2020-01-09 00:00:00           NaN
# ..                       ...                  ...           ...
# 57              220200002230  2020-03-24 00:00:00           NaN
# 58              220200002235  2020-04-15 00:00:00           NaN
# 59              220200002238  2019-10-08 00:00:00           NaN
# 60              220200000749  2020-01-20 00:00:00           NaN
# 61              220200002701  2020-04-30 00:00:00           NaN
#
# [62 rows x 14 columns]
# 0     48287107X
# 1     48287107X
# 2     75060747V
# 3     B96833496
# 4     52712498V
#         ...
# 57    52715123C
# 58    B09534405
# 59    B96887864
# 60    52714256G
# 61    52714256G
# Name: NIF Proveedor, Length: 62, dtype: object
# ---
# 0                  ALBERT GUTIERREZ WALTER GERMAN
# 1                  ALBERT GUTIERREZ WALTER GERMAN
# 2                          TERUEL HERREROS ISIDRO
# 3         INSTALACIONES ELECTRICAS SOLER PONS, SL
# 4                         CASANOVA JUAN FRANCISCO
#                          ...
# 57                     CANO GABALDON MIGUEL ANGEL
# 58                INDUSTRIAS QUIMICAS KIMINOR, SL
# 59    CIA VALENCIANA INTEGRACION Y DESARROLLO, SL
# 60                       NAVARRO NACHER, SALVADOR
# 61                       NAVARRO NACHER, SALVADOR
# Name: Proveedor, Length: 62, dtype: object
# ---
# ('ALBATERA', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ALBATERA\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo        Nº factura  \
# 0                       FACT-2019-2738  19SM1010/1000482
# 1                       FACT-2019-2949                28
# 2                       FACT-2019-2499                20
# 3                       FACT-2019-2538       H19-01/0776
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            1995.44                            1814.04
# 1                              181.5                                150
# 2                             1706.1                               1410
# 3                             676.39                                559
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            1995.44
# 1                                              181.5
# 2                                             1706.1
# 3                                             676.39
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            1814.04
# 1                                                150
# 2                                               1410
# 3                                                559
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2020-01-17 00:00:00  - Limpieza de arrastres de tierra ocasionados ...
# 1  2020-01-23 00:00:00     - Arreglo camino por lluvias torrenciales Dana
# 2  2019-11-29 00:00:00                - Arreglo de caminos y quitar barro
# 3  2019-11-29 00:00:00           -Arreglo parking cementerio lluvias Dana
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  d) Limpieza de las zonas siniestradas, así com...
# 1  d) Limpieza de las zonas siniestradas, así com...
# 2  d) Limpieza de las zonas siniestradas, así com...
# 3  d) Limpieza de las zonas siniestradas, así com...
#
# 7                   Proveedor NIF Proveedor Número operación contable  \
# 0     SERVICIOS DE LEVANTE SA     A46109062              220201000043
# 1  EXCAVACIONES GUTIPER, S.L.     B53081907              220201000193
# 2  EXCAVACIONES GUTIPER, S.L.     B53081907              220190010985
# 3            HORMAR XXI, S.L.     B54016571              220190010888
#
# 7        Fecha factura Observaciones
# 0  2019-11-30 00:00:00           NaN
# 1  2019-12-11 00:00:00           NaN
# 2  2019-10-21 00:00:00           NaN
# 3  2019-10-31 00:00:00           NaN
# 0    A46109062
# 1    B53081907
# 2    B53081907
# 3    B54016571
# Name: NIF Proveedor, dtype: object
# ---
# 0       SERVICIOS DE LEVANTE SA
# 1    EXCAVACIONES GUTIPER, S.L.
# 2    EXCAVACIONES GUTIPER, S.L.
# 3              HORMAR XXI, S.L.
# Name: Proveedor, dtype: object
# ---
# ('ALCÁZARES', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ALCÁZARES\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7  Código Expte de Contratación/Encargo Nº factura  \
# 0                             8853/2019   Emitida1
# 1                             8853/2019   Emitida3
# 2                              867/2020      EMI.8
# 3                              867/2020  EMITIDA12
# 4                             8001/2019    Emit-44
# ..                                  ...        ...
# 68                           10314/2019    Emit-14
# 69                            6152/2020  A31770554
# 70                            4132/2020    Emit-99
# 71                            4132/2020   Emit-100
# 72                            4132/2020   Emit-110
#
# 7  Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            27358.92                           22610.68
# 1                            20054.93                           16574.32
# 2                            23428.02                           19362.02
# 3                            23428.02                           19362.02
# 4                              8888.4                            7345.79
# ..                                ...                                ...
# 68                             5263.5                               4350
# 69                           70460.84                            58232.1
# 70                            5948.12                             4915.8
# 71                           37242.98                           30779.32
# 72                            1898.64                            1569.12
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            13679.46
# 1                                            10027.47
# 2                                            11714.01
# 3                                            11714.01
# 4                                              4444.2
# ..                                                ...
# 68                                            2631.75
# 69                                           35230.42
# 70                                            1487.03
# 71                                            9310.75
# 72                                             474.66
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            11305.34
# 1                                             8287.16
# 2                                                9681
# 3                                                9681
# 4                                             3672.89
# ..                                                ...
# 68                                               2175
# 69                                           29116.05
# 70                                            1228.95
# 71                                            7694.83
# 72                                             392.28
#
# 7    Fecha pago factura                                        Descriptivo  \
# 0   2020-02-11 00:00:00  Parcheo de asfalto de varias calles del munici...
# 1   2020-04-06 00:00:00  Parcheo de asfalto de varias calles del munici...
# 2   2020-07-15 00:00:00  Obra:Parcheo de varias calles del municipio Ac...
# 3   2020-12-17 00:00:00  Obra:Parcheo de varias calles del municipio Ac...
# 4   2019-12-27 00:00:00  OFICINA DE TURISMO; Parte Informática necesari...
# ..                  ...                                                ...
# 68  2020-01-08 00:00:00  Reparación del muro de piedra de la Rambla, de...
# 69  2021-05-10 00:00:00  Retirada de Lodos y limpieza del aparcamiento ...
# 70  2021-01-04 00:00:00  Obra de colector de pluviales en calle Manuel ...
# 71  2021-01-04 00:00:00  Obra de colector de pluviales en calle Manuel ...
# 72  2021-05-17 00:00:00  Obra de colector de pluviales en calle Manuel ...
#
# 7         Concepto de gasto (seleccionar de la lista)  \
# 0   a) Restablecimiento del funcionamiento de las ...
# 1   a) Restablecimiento del funcionamiento de las ...
# 2   a) Restablecimiento del funcionamiento de las ...
# 3   a) Restablecimiento del funcionamiento de las ...
# 4   a) Restablecimiento del funcionamiento de las ...
# ..                                                ...
# 68  c) Aseguramiento de las infraestructuras de pr...
# 69  d) Limpieza de las zonas siniestradas, así com...
# 70  c) Aseguramiento de las infraestructuras de pr...
# 71  c) Aseguramiento de las infraestructuras de pr...
# 72  c) Aseguramiento de las infraestructuras de pr...
#
# 7                                  Proveedor NIF Proveedor  \
# 0                      ASFALTOS RIENDA, S.L.    B-05518758
# 1                      ASFALTOS RIENDA, S.L.    B-05518758
# 2                      ASFALTOS RIENDA, S.L.    B-05518758
# 3                      ASFALTOS RIENDA, S.L.    B-05518758
# 4                  FRANCISCO SIMARRO RABADÁN    22947858-E
# ..                                       ...           ...
# 68                JOSÉ ANTONIO SIMARRO VIDAL    23038815-Z
# 69           LIMPIEZA DE TUBOS NAVARRO, S.L.    B-53740221
# 70   TRANSPORTES Y TIRURADOS DE MURCIA, S.L.    B-30367205
# 71  TRANSPORTES Y TRITURADOS DE MURCIA, S.L.    B-30367205
# 72  TRANSPORTES Y TRITURADOS DE MURCIA, S.L.    B-30367205
#
# 7  Número operación contable        Fecha factura Observaciones
# 0         2020.2.0001140.000  2020-01-07 00:00:00           NaN
# 1         2020.2.0002358.000  2020-02-03 00:00:00           NaN
# 2         2020.2.0005125.000  2020-05-30 00:00:00           NaN
# 3         2020.2.0009969.000  2020-10-16 00:00:00           NaN
# 4         2019.2.0010036.000  2019-11-25 00:00:00           NaN
# ..                       ...                  ...           ...
# 68        2019.2.0010518.000  2019-12-18 00:00:00           NaN
# 69        2021.2.0003423.000  2021-04-09 00:00:00           NaN
# 70        2020.2.0010970.000  2020-11-11 00:00:00           NaN
# 71        2020.2.0010971.000  2020-12-11 00:00:00           NaN
# 72        2021.2.0003623.000  2021-03-02 00:00:00           NaN
#
# [73 rows x 14 columns]
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 0     B-05518758
# 1     B-05518758
# 2     B-05518758
# 3     B-05518758
# 4     22947858-E
#          ...
# 68    23038815-Z
# 69    B-53740221
# 70    B-30367205
# 71    B-30367205
# 72    B-30367205
# Name: NIF Proveedor, Length: 73, dtype: object
# ---
# 0                        ASFALTOS RIENDA, S.L.
# 1                        ASFALTOS RIENDA, S.L.
# 2                        ASFALTOS RIENDA, S.L.
# 3                        ASFALTOS RIENDA, S.L.
# 4                    FRANCISCO SIMARRO RABADÁN
#                         ...
# 68                  JOSÉ ANTONIO SIMARRO VIDAL
# 69             LIMPIEZA DE TUBOS NAVARRO, S.L.
# 70     TRANSPORTES Y TIRURADOS DE MURCIA, S.L.
# 71    TRANSPORTES Y TRITURADOS DE MURCIA, S.L.
# 72    TRANSPORTES Y TRITURADOS DE MURCIA, S.L.
# Name: Proveedor, Length: 73, dtype: object
# ---
# ('ALCÓNTAR-JRL', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ALCÓNTAR-JRL\\Justificacion_FSUE-DANA.xlsx')
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                                  NaN         31
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                               3025                               2500
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                                605
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                                500
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2020-05-06 00:00:00  colocacion y arreglo de dos postel en Barriada...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0   restablecimiento de e infraestructuras y equi...
#
# 7                   Proveedor NIF Proveedor Número operación contable  \
# 0  ESTEBAN PIZARRO VALDIVIESO     52513617V             2202000000781
#
# 7 Fecha factura                                      Observaciones
# 0   10/10/20219  DAÑOS DANA . Forma parte de otra factura de ma...
# 0    52513617V
# Name: NIF Proveedor, dtype: object
# ---
# 0    ESTEBAN PIZARRO VALDIVIESO
# Name: Proveedor, dtype: object
# ---
# ('ALGORFA', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ALGORFA\\Justificacion_FSUE-DANA.xlsx')
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                          22019003518     00 169
# 1                          22020000538      00 46
# 2                          22020003412        003
# 3                          22020003412       0047
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           17732.09                           14654.62
# 1                            1433.73                             1184.9
# 2                               3872                               3200
# 3                            1360.23                            1124.16
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           17732.09
# 1                                            1433.73
# 2                                               3872
# 3                                             971.24
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           14654.62
# 1                                             1184.9
# 2                                               3200
# 3                                             802.68
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2020-02-25 00:00:00  CÉSPED, PIEDRA MAMPOSTERIA, M3 DE HORMIGÓN, SA...
# 1  2020-05-15 00:00:00  RETIRADA DE TELAS VIEJAS Y BORDILLO A VERTEDER...
# 2  2021-03-08 00:00:00  REDACCION DE PROYECTO DE LAS OBRAS DE REPARACI...
# 3  2021-08-04 00:00:00  DIRECCION DE OBRA Y C.S.S. DE LAS OBRAS DE REP...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
# 1  a) Restablecimiento del funcionamiento de las ...
# 2  a) Restablecimiento del funcionamiento de las ...
# 3  a) Restablecimiento del funcionamiento de las ...
#
# 7                     Proveedor NIF Proveedor Número operación contable  \
# 0                Preserbol S.L.     B54629217              220200000821
# 1                Preserbol S.L.     B54629217              220200002634
# 2  Cauce Proyectos y Obras S.A.     A03378668              220210001027
# 3  Cauce Proyectos y Obras S.A.     A03378668              220210004414
#
# 7        Fecha factura                                      Observaciones
# 0  2019-11-17 00:00:00  El Nº de operación contable corresponde a la f...
# 1  2020-03-31 00:00:00  El Nº de operación contable corresponde a la f...
# 2  2021-01-05 00:00:00  El Nº de operación contable corresponde a la f...
# 3  2021-05-24 00:00:00  El Nº de operación contable corresponde a la f...
# 0    B54629217
# 1    B54629217
# 2    A03378668
# 3    A03378668
# Name: NIF Proveedor, dtype: object
# ---
# 0                  Preserbol S.L.
# 1                  Preserbol S.L.
# 2    Cauce Proyectos y Obras S.A.
# 3    Cauce Proyectos y Obras S.A.
# Name: Proveedor, dtype: object
# ---
# ('ALHAURÍN DE LA TORRE', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ALHAURÍN DE LA TORRE\\Justificacion_FSUE-DANA.xlsx')
# 7     Código Expte de Contratación/Encargo  Nº factura  \
# 0   Decreto de emergencia nº 5273 25/09/19          29
# 1   Decreto de emergencia nº 5273 25/09/19           1
# 2   Decreto de emergencia nº 5273 25/09/19           2
# 3   Decreto de emergencia nº 5273 25/09/19         115
# 4   Decreto de emergencia nº 5273 25/09/19          68
# 5                        2019/PGAS00004359       29036
# 6                        2019/PGAS00005481           1
# 7                        2019/PGAS00005482         139
# 8                          2019 CONT-00085  FE20/00754
# 9                          2019 CONT-00085         827
# 10                         2019 CONT-00085         859
#
# 7  Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           113436.21                       93748.933884
# 1                            63948.58                       52850.066116
# 2                           141701.62                       117108.77686
# 3                            38011.25                       31414.256198
# 4                             5408.59                        4469.909091
# 5                            45050.84                       37232.099174
# 6                            48031.25                       39695.247934
# 7                            29075.13                       24029.033058
# 8                            28203.49                       23308.669421
# 9                            81890.83                       67678.371901
# 10                           10994.04                        9085.983471
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                             24402.3
# 1                                        24796.532981
# 2                                        54945.847019
# 3                                        11986.412995
# 4                                         1705.537005
# 5                                            22525.42
# 6                                            24015.63
# 7                                            14537.57
# 8                                           14101.745
# 9                                           40945.415
# 10                                            5497.02
#
# 7  Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                        20167.190083
# 1                                        20493.002464
# 2                                        45409.790925
# 3                                         9906.126443
# 4                                         1409.534714
# 5                                        18616.049587
# 6                                        19847.628099
# 7                                        12014.520661
# 8                                        11654.334711
# 9                                         33839.18595
# 10                                        4542.991736
#
# 7        Fecha pago factura  \
# 0       2020-03-20 00:00:00
# 1   20/03/2020 Y 28/12/2020
# 2   20/03/2020 Y 28/12/2020
# 3       2019-12-23 00:00:00
# 4       2020-12-28 00:00:00
# 5       2020-01-07 00:00:00
# 6       2020-03-20 00:00:00
# 7       2020-06-10 00:00:00
# 8       2020-11-19 00:00:00
# 9       2020-12-14 00:00:00
# 10      2020-12-14 00:00:00
#
# 7                                         Descriptivo  \
# 0   REPARACIÓN DE DIVERSOS CAMINOS RURALES EN LA Z...
# 1   REPARACIÓN DE DIVERSOS CAMINOS RURALES EN OTRA...
# 2                                                 NaN
# 3   REPARACIÓN DE MUROS Y CERRAMIENTOS DE COLEGIOS...
# 4                                                 NaN
# 5   REPARACIÓN REDES ELÉCTRICAS CALLE MEZQUITA CRU...
# 6   REPARACION CAMINO ESTORNINO Y CAMINO A VIVEROS...
# 7              REPARACION CAMINO DEL CERRO DEL AGUILA
# 8   REPARACION DE LOS CAMINOS DE MENAYA Y COMENDAD...
# 9                                                 NaN
# 10                                                NaN
#
# 7         Concepto de gasto (seleccionar de la lista)  \
# 0   a) Restablecimiento del funcionamiento de las ...
# 1   a) Restablecimiento del funcionamiento de las ...
# 2   a) Restablecimiento del funcionamiento de las ...
# 3   a) Restablecimiento del funcionamiento de las ...
# 4                                                 NaN
# 5   a) Restablecimiento del funcionamiento de las ...
# 6   a) Restablecimiento del funcionamiento de las ...
# 7   a) Restablecimiento del funcionamiento de las ...
# 8   a) Restablecimiento del funcionamiento de las ...
# 9                                                 NaN
# 10                                                NaN
#
# 7                         Proveedor NIF Proveedor  \
# 0   CARLOS JAVIER GUTIERREZ GARRIDO    25713687-D
# 1   CARLOS JAVIER GUTIERREZ GARRIDO    25713687-D
# 2                               NaN           NaN
# 3         CONSTRUCCIONES SERON S.L.    B-29439361
# 4                 RIALSA OBRAS S.L.    B-92182500
# 5     GRUPO INEDA ELECTRICIDAD S.L.    B-92255520
# 6      EXCAVACIONES ESPECIALES S.L.    B-92542364
# 7           ANTONIO MORENO CALDERON    25704497-L
# 8                 RIALSA OBRAS S.L.    B-92182500
# 9                               NaN           NaN
# 10                              NaN           NaN
#
# 7       Número operación contable        Fecha factura  \
# 0                   2020 22006501  2019-10-28 00:00:00
# 1   2020 22006502 Y 2020 22027704  2020-01-06 00:00:00
# 2   2020 22006503 Y 2020 22027705  2020-03-02 00:00:00
# 3                   2019 22032367  2019-11-25 00:00:00
# 4                   2019 22032541  2019-12-05 00:00:00
# 5                   2020 26000345  2019-12-18 00:00:00
# 6                   2020 22006367  2020-02-13 00:00:00
# 7                   2020 22012265  2020-04-23 00:00:00
# 8                   2020 22023222  2020-10-13 00:00:00
# 9                   2020 22025926  2020-11-11 00:00:00
# 10                  2020 22025927  2020-11-19 00:00:00
#
# 7                                       Observaciones
# 0         ESTA OBRA DE EMERGENCIA CONSTA DE 1 FACTURA
# 1   ESTA OBRA DE EMERGENCIA CONSTA DE 2 FACTURAS D...
# 2                                                 NaN
# 3   ESTA ES UNA FACTURA DE UN CONTRATISTA, DE LAS ...
# 4   ESTA ES UNA FACTURA DE UN CONTRATISTA, DE LAS ...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 0     25713687-D
# 1     25713687-D
# 2            NaN
# 3     B-29439361
# 4     B-92182500
# 5     B-92255520
# 6     B-92542364
# 7     25704497-L
# 8     B-92182500
# 9            NaN
# 10           NaN
# Name: NIF Proveedor, dtype: object
# ---
# 0     CARLOS JAVIER GUTIERREZ GARRIDO
# 1     CARLOS JAVIER GUTIERREZ GARRIDO
# 2                                 NaN
# 3           CONSTRUCCIONES SERON S.L.
# 4                   RIALSA OBRAS S.L.
# 5       GRUPO INEDA ELECTRICIDAD S.L.
# 6        EXCAVACIONES ESPECIALES S.L.
# 7             ANTONIO MORENO CALDERON
# 8                   RIALSA OBRAS S.L.
# 9                                 NaN
# 10                                NaN
# Name: Proveedor, dtype: object
# ---
# ('ALMANSA', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ALMANSA\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                              572392P   012/2020
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            20642.6                              17060
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            4541.08
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            4541.08
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2020-12-11 00:00:00  REPARACIÓN CANALES DE LA CUBIERTA DE LA ESCUEL...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
#
# 7                   Proveedor NIF Proveedor Número operación contable  \
# 0  GREENOVA MONTEIBÉRICO S.L.     B02537256       2020-09-25 00:00:00
#
# 7        Fecha factura Observaciones
# 0  2020-09-28 00:00:00           NaN
# 0    B02537256
# Name: NIF Proveedor, dtype: object
# ---
# 0    GREENOVA MONTEIBÉRICO S.L.
# Name: Proveedor, dtype: object
# ---
# ('ALMORADÍ', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ALMORADÍ\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo    Nº factura  \
# 0                            7511/2020  ONDD-21-0076
# 1                            7511/2020  ONDD-21-0082
# 2                            2905/2020    2014500566
# 3                            2905/2020    2014500567
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           72858.94                              60214
# 1                          255241.01                          210942.98
# 2                           37837.76                           32270.88
# 3                           69365.43                            57326.8
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           36429.47
# 1                                          127620.05
# 2                                           37837.76
# 3                                           69365.43
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                              30107
# 1                                          105471.49
# 2                                           32270.88
# 3                                            57326.8
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2021-07-29 00:00:00  REPOSICIÓN DE ALCANTARILLADO, SANEAMIENTO Y\nB...
# 1  2021-09-03 00:00:00  REPOSICIÓN DE ALCANTARILLADO, SANEAMIENTO Y\nB...
# 2  2021-01-18 00:00:00  Posición:PRIMERA CERTIFICACION REPOSICION\nDE ...
# 3  2021-01-18 00:00:00  SEGUNDA CERTIFICACION REPOSICION\nDE ALCANTARI...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
# 1  a) Restablecimiento del funcionamiento de las ...
# 2  a) Restablecimiento del funcionamiento de las ...
# 3  a) Restablecimiento del funcionamiento de las ...
#
# 7                                          Proveedor NIF Proveedor  \
# 0  ORTHEM SERVICIOS Y ACTUACIONES\nAMBIENTALES, S...     A73089120
# 1  ORTHEM SERVICIOS Y ACTUACIONES\nAMBIENTALES, S...     A73089120
# 2  HIDRAQUA GESTIÓN INTEGRALDE AGUAS DE\nLEVANTE,S.A   ESA53223764
# 3  HIDRAQUA GESTIÓN INTEGRALDE AGUAS DE\nLEVANTE,S.A   ESA53223764
#
# 7 Número operación contable        Fecha factura Observaciones
# 0       2021.2.000.7175.000  2021-07-14 00:00:00           NaN
# 1       2021.2.000.7657.000  2021-08-11 00:00:00           NaN
# 2       2020.2.00.11545.000  2020-09-17 00:00:00           NaN
# 3       2020.2.00.11547.000  2020-09-17 00:00:00           NaN
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 0      A73089120
# 1      A73089120
# 2    ESA53223764
# 3    ESA53223764
# Name: NIF Proveedor, dtype: object
# ---
# 0    ORTHEM SERVICIOS Y ACTUACIONES\nAMBIENTALES, S...
# 1    ORTHEM SERVICIOS Y ACTUACIONES\nAMBIENTALES, S...
# 2    HIDRAQUA GESTIÓN INTEGRALDE AGUAS DE\nLEVANTE,S.A
# 3    HIDRAQUA GESTIÓN INTEGRALDE AGUAS DE\nLEVANTE,S.A
# Name: Proveedor, dtype: object
# ---
# ('ALQUERIA DE AZNAR', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ALQUERIA DE AZNAR\\Justificacion_FSUE-DANA.xlsx')
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                              2020071    2020071
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            9508.01                            7857.86
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            3709.88
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            3065.19
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2020-07-02 00:00:00  Trabajos realizados en el saneo de blandones,\...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
#
# 7                                 Proveedor NIF Proveedor  \
# 0  PROMOCIONES Y CONSTRUCCIONES VOPRAM S.L.     B03724465
#
# 7 Número operación contable        Fecha factura Observaciones
# 0               20201532210  2020-05-08 00:00:00           NaN
# 0    B03724465
# Name: NIF Proveedor, dtype: object
# ---
# 0    PROMOCIONES Y CONSTRUCCIONES VOPRAM S.L.
# Name: Proveedor, dtype: object
# ---
# ('AP CARTAGENA', 'C:/Users/bllanos/Desktop/Simulacion_dana\\AP CARTAGENA\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                           PC19-00961   EMIT-392
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           16558.85                              13685
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           16558.85
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                              13685
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2019-11-29 00:00:00  Reparación de incidencias por motivos metereol...
#
# 7        Concepto de gasto (seleccionar de la lista)        Proveedor  \
# 0  d) Limpieza de las zonas siniestradas, así com...  IBERLEC S.COOP.
#
# 7 NIF Proveedor Número operación contable        Fecha factura Observaciones
# 0     F30731517                    437067  2019-10-21 00:00:00           NaN
# 0    F30731517
# Name: NIF Proveedor, dtype: object
# ---
# 0    IBERLEC S.COOP.
# Name: Proveedor, dtype: object
# ---
# ('ARBOLEAS', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ARBOLEAS\\Justificacion_FSUE-DANA.xlsx')
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                             440/2019   490-2019
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                              11385                            9409.19
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           10995.28
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            9087.01
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2020-01-02 00:00:00  REPARACION DE EMERGENCIA DEL MURO DE CONTENCIO...
#
# 7        Concepto de gasto (seleccionar de la lista)              Proveedor  \
# 0  a) Restablecimiento del funcionamiento de las ...  ANGEL GRANADOS GARCIA
#
# 7 NIF Proveedor Número operación contable        Fecha factura Observaciones
# 0    75222226J               220190007355  2019-12-19 00:00:00           NaN
# 0    75222226J
# Name: NIF Proveedor, dtype: object
# ---
# 0    ANGEL GRANADOS GARCIA
# Name: Proveedor, dtype: object
# ---
# ('ARCHENA', 'C:/Users/bllanos/Desktop/Simulacion_dana\\ARCHENA\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo  Nº factura  \
# 0                              90/2020  2020/00077
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            6433.59                            5848.72
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            6433.59
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                            5848.72
#
# 7   Fecha pago factura    Descriptivo  \
# 0  2020-05-30 00:00:00  TRANSFERENCIA
#
# 7        Concepto de gasto (seleccionar de la lista)      Proveedor  \
# 0  d) Limpieza de las zonas siniestradas, así com...  BANALVA, S.L.
#
# 7 NIF Proveedor Número operación contable        Fecha factura Observaciones
# 0     B30522213                      2930  2020-03-09 00:00:00           NaN
# 0    B30522213
# Name: NIF Proveedor, dtype: object
# ---
# 0    BANALVA, S.L.
# Name: Proveedor, dtype: object
# ---
# ('BENIEL', 'C:/Users/bllanos/Desktop/Simulacion_dana\\BENIEL\\Justificacion_FSUE-DANA.xlsx')
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                                    1   20013049
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           10977.12                               9072
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           10977.12
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                               9072
#
# 7   Fecha pago factura                                 Descriptivo  \
# 0  2021-03-15 00:00:00  GRUPO ELECTROGENO GSW 45P Y LTS ACP GENSET
#
# 7        Concepto de gasto (seleccionar de la lista)             Proveedor  \
# 0  a) Restablecimiento del funcionamiento de las ...  PRAMAC IBÉRICA S.A.U
#
# 7 NIF Proveedor Número operación contable        Fecha factura Observaciones
# 0     A50204395           202120000873000  2020-12-15 00:00:00           NaN
# 0    A50204395
# Name: NIF Proveedor, dtype: object
# ---
# 0    PRAMAC IBÉRICA S.A.U
# Name: Proveedor, dtype: object
# ---
# ('BIGASTRO', 'C:/Users/bllanos/Desktop/Simulacion_dana\\BIGASTRO\\Justificacion_FSUE-DANA.xlsx')
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 7 Código Expte de Contratación/Encargo Nº factura  \
# 0                             885/2021      20216
# 1                             888/2021      20215
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                           47063.63                           38895.56
# 1                           14074.72                              11632
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                           47063.63
# 1                                           14074.72
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                           38895.56
# 1                                              11632
#
# 7   Fecha pago factura                                        Descriptivo  \
# 0  2021-07-28 00:00:00  REPARACIÓN DE PISCINA CUBIERTA EN EL POLIDEPOR...
# 1  2021-07-28 00:00:00  REPARACIÓN PISCINA Y VESTUARIOS ZONA RECREATIV...
#
# 7        Concepto de gasto (seleccionar de la lista)  \
# 0  a) Restablecimiento del funcionamiento de las ...
# 1  a) Restablecimiento del funcionamiento de las ...
#
# 7                    Proveedor NIF Proveedor Número operación contable  \
# 0  CONSTRUCCIONES GASARCA S.L.     B53760773              220210004896
# 1  CONSTRUCCIONES GASARCA S.L.     B53760773              220210004897
#
# 7        Fecha factura Observaciones
# 0  2021-07-22 00:00:00           NaN
# 1  2021-07-20 00:00:00           NaN
# 0    B53760773
# 1    B53760773
# Name: NIF Proveedor, dtype: object
# ---
# 0    CONSTRUCCIONES GASARCA S.L.
# 1    CONSTRUCCIONES GASARCA S.L.
# Name: Proveedor, dtype: object
# ---
# ('BLANCA', 'C:/Users/bllanos/Desktop/Simulacion_dana\\BLANCA\\Justificacion_FSUE-DANA.xlsx')
# ...
# 45  2021-04-16 00:00:00              REPRACIÓN INSTALACIONES MUNICIPALES
# 46  2020-05-20 00:00:00       TRABAJOS RESTABLECIMIENTO INFRAESTRUCTURAS
# 47  2020-08-20 00:00:00        TRABAJOS RESTABLECIMIENT INFRAESTRUCTURAS
# 48  2021-08-13 00:00:00          TRABAJOS RESTABLECIMIENTO INSTALACIONES
# 49  2021-03-03 00:00:00          TRABAJOS RESTABLECIMIENTO INSTALACIONES
#
# 7         Concepto de gasto (seleccionar de la lista)  \
# 0   a) Restablecimiento del funcionamiento de las ...
# 1   a) Restablecimiento del funcionamiento de las ...
# 2   a) Restablecimiento del funcionamiento de las ...
# 3   a) Restablecimiento del funcionamiento de las ...
# 4   a) Restablecimiento del funcionamiento de las ...
# 5   a) Restablecimiento del funcionamiento de las ...
# 6   a) Restablecimiento del funcionamiento de las ...
# 7   a) Restablecimiento del funcionamiento de las ...
# 8   a) Restablecimiento del funcionamiento de las ...
# 9   a) Restablecimiento del funcionamiento de las ...
# 10  a) Restablecimiento del funcionamiento de las ...
# 11  a) Restablecimiento del funcionamiento de las ...
# 12  a) Restablecimiento del funcionamiento de las ...
# 13  a) Restablecimiento del funcionamiento de las ...
# 14  a) Restablecimiento del funcionamiento de las ...
# 15  a) Restablecimiento del funcionamiento de las ...
# 16  a) Restablecimiento del funcionamiento de las ...
# 17  a) Restablecimiento del funcionamiento de las ...
# 18  a) Restablecimiento del funcionamiento de las ...
# 19  a) Restablecimiento del funcionamiento de las ...
# 20  a) Restablecimiento del funcionamiento de las ...
# 21  a) Restablecimiento del funcionamiento de las ...
# 22  a) Restablecimiento del funcionamiento de las ...
# 23  a) Restablecimiento del funcionamiento de las ...
# 24  a) Restablecimiento del funcionamiento de las ...
# 25  a) Restablecimiento del funcionamiento de las ...
# 26  a) Restablecimiento del funcionamiento de las ...
# 27  a) Restablecimiento del funcionamiento de las ...
# 28  a) Restablecimiento del funcionamiento de las ...
# 29  a) Restablecimiento del funcionamiento de las ...
# 30  a) Restablecimiento del funcionamiento de las ...
# 31  a) Restablecimiento del funcionamiento de las ...
# 32  a) Restablecimiento del funcionamiento de las ...
# 33  a) Restablecimiento del funcionamiento de las ...
# 34  a) Restablecimiento del funcionamiento de las ...
# 35  a) Restablecimiento del funcionamiento de las ...
# 36  a) Restablecimiento del funcionamiento de las ...
# 37  a) Restablecimiento del funcionamiento de las ...
# 38  a) Restablecimiento del funcionamiento de las ...
# 39  a) Restablecimiento del funcionamiento de las ...
# 40  a) Restablecimiento del funcionamiento de las ...
# 41  a) Restablecimiento del funcionamiento de las ...
# 42  a) Restablecimiento del funcionamiento de las ...
# 43  a) Restablecimiento del funcionamiento de las ...
# 44  a) Restablecimiento del funcionamiento de las ...
# 45  a) Restablecimiento del funcionamiento de las ...
# 46  a) Restablecimiento del funcionamiento de las ...
# 47  a) Restablecimiento del funcionamiento de las ...
# 48  a) Restablecimiento del funcionamiento de las ...
# 49  a) Restablecimiento del funcionamiento de las ...
#
# 7                                 Proveedor NIF Proveedor  \
# 0                        ELECTRO GRANADA SL     B18323626
# 1                        ELECTRO GRANADA SL     B18323627
# 2                           MAQUI INDAL SL      B04487377
# 3                  COMERCIAL MORENO 2000 SL     B18934831
# 4                                NUVALSU SL    B73645285
# 5                       LUIS MAESO MARTINEZ     52523171A
# 6                 JOSE MARIA IBARRA MOLINA      52519565P
# 7                       LUIS MAESO MARTINEZ     52523171A
# 8                 JOSE MARIA IBARRA MOLINA      52519565P
# 9                  COMERCIAL MORENO 2000 SL     B18938431
# 10                 COMERCIAL MORENO 2000 SL     B18938431
# 11                 COMERCIAL MORENO 2000 SL     B18938431
# 12               FRANCISCO MIRAVETE SORIANO     52526334S
# 13                   ANTONIO ORTIZ MONTALVO     76142382P
# 14                  ESTEFANIA FALLA JIMENEZ     15516744R
# 15  ECOREFORMAS JUAN MARTINEZ EXTREMERA SLU     B23778830
# 16                 COMERCIAL MORENO 2000 SL     B18938431
# 17               FRANCISCO MIRAVETE SORIANO     52526334S
# 18  ECOREFORMAS JUAN MARTINEZ EXTREMERA SLU     B23778830
# 19                   ANTONIO ORTIZ MONTALVO     76142382P
# 20                  HORMIGONES ALMANZORA SA     A04109005
# 21          TRANSPORTES CASTRIL LIBRILLA SL     B30355184
# 22                 COMERCIAL MORENO 2000 SL     B18938431
# 23               FRANCISCO MIRAVETE SORIANO     52526334S
# 24                 COMERCIAL MORENO 2000 SL     B18938431
# 25               FRANCISCO MIRAVETE SORIANO     52526334S
# 26                      JOSE ROBLES SANCHEZ     52523550Z
# 27                               NUVALSU SL    B73645285
# 28                       ELECTRO GRANADA SL     B18323626
# 29                 COMERCIAL MORENO 2000 SL     B18938431
# 30                   MANOLO CASANOVA GARCIA     52527237K
# 31                        MIGUEL AZOR ORTIZ     45717027L
# 32                          MAQUI INDAL SL      B04487377
# 33                JOSE MARIA IBARRA MOLINA      52519565P
# 34                       ELECTRO GRANADA SL     B18323626
# 35                 COMERCIAL MORENO 2000 SL     B18938431
# 36                                VADIAZ SL     B23299274
# 37                      LUIS MAESO MARTINEZ     52523171A
# 38                       ELECTRO GRANADA SL     B18323626
# 39                JOSE MARIA IBARRA MOLINA      52519565P
# 40                      LUIS MAESO MARTINEZ     52523171A
# 41                 COMERCIAL MORENO 2000 SL     B18938431
# 42                 COMERCIAL MORENO 2000 SL     B18938431
# 43                 COMERCIAL MORENO 2000 SL     B18938432
# 44                  COSME MARTINEZ MARTINEZ     24187070V
# 45                  HORMIGONES ALMANZORA SA     A04109005
# 46          TRANSPORTES CASTRIL LIBRILLA SL     B30355184
# 47                 ALFONSO DEL OLMO IRUELA      52524397X
# 48                          MAQUI INDAL SL      B04487377
# 49            FUNDICION DUCTIL FABREGAS SAU     A58574518
#
# 7  Número operación contable        Fecha factura         Observaciones
# 0               220200004044  2020-12-15 00:00:00                   NaN
# 1               220200004046  2020-11-13 00:00:00                   NaN
# 2               220200000366  2019-09-02 00:00:00                   NaN
# 3               220200004048  2020-12-31 00:00:00                   NaN
# 4               220200002586  2020-07-14 00:00:00  ABONADO FRACCIONADO
# 5               220200004018  2020-10-06 00:00:00                   NaN
# 6               220200003809  2020-12-18 00:00:00                   NaN
# 7               220200003596  2020-10-06 00:00:00                   NaN
# 8               220200003520  2020-11-26 00:00:00                   NaN
# 9               220200004056  2020-12-31 00:00:00                   NaN
# 10              220200002653  2020-08-31 00:00:00                   NaN
# 11              220200002653  2020-07-31 00:00:00                   NaN
# 12              220200002432  2020-07-30 00:00:00                   NaN
# 13              220200002412  2020-07-22 00:00:00                   NaN
# 14              220200002564  2020-10-19 00:00:00                   NaN
# 15              220200001996  2020-08-04 00:00:00                   NaN
# 16              220200001950  2020-05-15 00:00:00                   NaN
# 17              220200001958  2020-05-30 00:00:00                   NaN
# 18              220200001992  2020-07-06 00:00:00                   NaN
# 19              220200000967  2020-05-11 00:00:00                   NaN
# 20              220200000961  2020-02-14 00:00:00                   NaN
# 21              220200000815  2020-01-20 00:00:00                   NaN
# 22              220200000510  2020-02-15 00:00:00                   NaN
# 23              220200000344  2020-01-30 00:00:00                   NaN
# 24              220200000332  2020-01-15 00:00:00                   NaN
# 25              220200000364  2020-02-28 00:00:00                   NaN
# 26              220200000316  2020-01-22 00:00:00                   NaN
# 27              220200004251  2019-09-30 00:00:00                   NaN
# 28              220200004052  2019-11-15 00:00:00                   NaN
# 29              220200004047  2019-11-15 00:00:00                   NaN
# 30              220200004136  2019-11-12 00:00:00                   NaN
# 31              220200004048  2019-11-15 00:00:00                   NaN
# 32              220200004068  2019-12-02 00:00:00                   NaN
# 33              220200004058  2019-11-12 00:00:00                   NaN
# 34              220200004036  2019-09-30 00:00:00                   NaN
# 35              220200004229  2019-10-31 00:00:00                   NaN
# 36              220200004225  2019-09-26 00:00:00                   NaN
# 37              220200002793  2019-10-04 00:00:00                   NaN
# 38              220200000192  2021-01-29 00:00:00                   NaN
# 39              220200000682  2021-03-12 00:00:00                   NaN
# 40              220200000634  2021-11-17 00:00:00                   NaN
# 41              220200000678  2021-03-15 00:00:00                   NaN
# 42              220200000881  2021-03-15 00:00:00                   NaN
# 43              220200000883  2021-03-15 00:00:00                   NaN
# 44              220200000917  2021-01-11 00:00:00                   NaN
# 45              220200000879  2021-02-28 00:00:00                   NaN
# 46              220200000813  2020-01-20 00:00:00                   NaN
# 47              220200001974  2020-07-16 00:00:00                   NaN
# 48              220200002388  2020-09-01 00:00:00                   NaN
# 49              220200004022  2020-10-22 00:00:00                   NaN
# C:\Users\bllanos\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 0      B18323626
# 1      B18323627
# 2      B04487377
# 3      B18934831
# 4     B73645285
# 5      52523171A
# 6      52519565P
# 7      52523171A
# 8      52519565P
# 9      B18938431
# 10     B18938431
# 11     B18938431
# 12     52526334S
# 13     76142382P
# 14     15516744R
# 15     B23778830
# 16     B18938431
# 17     52526334S
# 18     B23778830
# 19     76142382P
# 20     A04109005
# 21     B30355184
# 22     B18938431
# 23     52526334S
# 24     B18938431
# 25     52526334S
# 26     52523550Z
# 27    B73645285
# 28     B18323626
# 29     B18938431
# 30     52527237K
# 31     45717027L
# 32     B04487377
# 33     52519565P
# 34     B18323626
# 35     B18938431
# 36     B23299274
# 37     52523171A
# 38     B18323626
# 39     52519565P
# 40     52523171A
# 41     B18938431
# 42     B18938431
# 43     B18938432
# 44     24187070V
# 45     A04109005
# 46     B30355184
# 47     52524397X
# 48     B04487377
# 49     A58574518
# Name: NIF Proveedor, dtype: object
# ---
# 0                          ELECTRO GRANADA SL
# 1                          ELECTRO GRANADA SL
# 2                             MAQUI INDAL SL
# 3                    COMERCIAL MORENO 2000 SL
# 4                                  NUVALSU SL
# 5                         LUIS MAESO MARTINEZ
# 6                   JOSE MARIA IBARRA MOLINA
# 7                         LUIS MAESO MARTINEZ
# 8                   JOSE MARIA IBARRA MOLINA
# 9                    COMERCIAL MORENO 2000 SL
# 10                   COMERCIAL MORENO 2000 SL
# 11                   COMERCIAL MORENO 2000 SL
# 12                 FRANCISCO MIRAVETE SORIANO
# 13                     ANTONIO ORTIZ MONTALVO
# 14                    ESTEFANIA FALLA JIMENEZ
# 15    ECOREFORMAS JUAN MARTINEZ EXTREMERA SLU
# 16                   COMERCIAL MORENO 2000 SL
# 17                 FRANCISCO MIRAVETE SORIANO
# 18    ECOREFORMAS JUAN MARTINEZ EXTREMERA SLU
# 19                     ANTONIO ORTIZ MONTALVO
# 20                    HORMIGONES ALMANZORA SA
# 21            TRANSPORTES CASTRIL LIBRILLA SL
# 22                   COMERCIAL MORENO 2000 SL
# 23                 FRANCISCO MIRAVETE SORIANO
# 24                   COMERCIAL MORENO 2000 SL
# 25                 FRANCISCO MIRAVETE SORIANO
# 26                        JOSE ROBLES SANCHEZ
# 27                                 NUVALSU SL
# 28                         ELECTRO GRANADA SL
# 29                   COMERCIAL MORENO 2000 SL
# 30                     MANOLO CASANOVA GARCIA
# 31                          MIGUEL AZOR ORTIZ
# 32                            MAQUI INDAL SL
# 33                  JOSE MARIA IBARRA MOLINA
# 34                         ELECTRO GRANADA SL
# 35                   COMERCIAL MORENO 2000 SL
# 36                                  VADIAZ SL
# 37                        LUIS MAESO MARTINEZ
# 38                         ELECTRO GRANADA SL
# 39                  JOSE MARIA IBARRA MOLINA
# 40                        LUIS MAESO MARTINEZ
# 41                   COMERCIAL MORENO 2000 SL
# 42                   COMERCIAL MORENO 2000 SL
# 43                   COMERCIAL MORENO 2000 SL
# 44                    COSME MARTINEZ MARTINEZ
# 45                    HORMIGONES ALMANZORA SA
# 46            TRANSPORTES CASTRIL LIBRILLA SL
# 47                   ALFONSO DEL OLMO IRUELA
# 48                            MAQUI INDAL SL
# 49              FUNDICION DUCTIL FABREGAS SAU
# Name: Proveedor, dtype: object
# ---
# ('CHAUCHINA', 'C:/Users/bllanos/Desktop/Simulacion_dana\\CHAUCHINA\\Justificacion_FSUE-DANA.xlsx')
# 7 Código Expte de Contratación/Encargo      Nº factura  \
# 0                            1158/2019  20190115609154
#
# 7 Importe total de factura (con IVA) Importe total de factura (sin IVA)  \
# 0                            3102.44                               2564
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (con IVA)**  \
# 0                                            3102.43
#
# 7 Importe de la factura a imputar al Fondo de Solidaridad (sin IVA)**  \
# 0                                               2564
#
# 7   Fecha pago factura            Descriptivo  \
# 0  2019-12-04 00:00:00  obra menor y limpieza
#
# 7        Concepto de gasto (seleccionar de la lista)               Proveedor  \
# 0  a) Restablecimiento del funcionamiento de las ...  Enrique Garcia Berrido
#
# 7 Número operación contable     Fecha de encargo Observaciones
# 0              220190008568  2019-10-31 00:00:00    ver celdas
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-65ea6b44012c> in <module>
#       7     transacciones.reset_index(inplace=True,drop=True)
#       8     display(transacciones)
# ----> 9     transacciones[["NIF Proveedor","Proveedor"]].apply(buscador_organismos)
#      10
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['NIF Proveedor'] not in index"
